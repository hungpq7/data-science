# %% [markdown]
# # Streamlit: Data App
# https://chatgpt.com/c/6985bc18-2b24-839f-aff4-aeff927c1251

# %% [markdown]
# ## 1. Motivation
# - turn python code into interactive web apps without writing HTML, CSS, or JavaScript
# - ship demo, prototypes, poc quickly
# - mental model: write python scripts, run them, see the output in a web app
# - comparison:
#     - gradio deploy from HF space, support notebooks, mental model: wraps functions as interface
#     - streamlit from github + streamlit cloud, mental model: write scripts as apps

# %% [markdown]
# ## 2. Streamlit

# %% [markdown]
# ## 3. Gradio

# %% [markdown]
# - https://share.streamlit.io/
# - https://data-chilly.streamlit.app/
