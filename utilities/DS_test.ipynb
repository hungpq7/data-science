# %% [markdown]
# # A. Data Science overview

# %% [markdown]
# **A01**. *Nhận định nào sau đây là đúng về data science*
# - [ ] Data science xây dựng trên nền tảng bigdata
# - [ ] Data science tương đương statistics
# - [ ] Data science và AI có chung mục tiêu xuất phát điểm
# - [x] Không có khái niệm thống nhất duy nhất về Data science

# %% [markdown]
# **A02**. Theo quan điểm của Jim Gray, mô hình (paradigm) nào sau đây không phải mô hình khoa học
# - [ ] Mô hình thí nghiệm
# - [ ] Mô hình suy luận lý thuyết
# - [ ] Mô hình định hướng dựa trên dữ liệu
# - [x] Mô hình xác suất

# %% [markdown]
# **A03**. Các sản phẩm nào sau đây là **không** đúng về sản phẩm DS của các hãng công nghệ lớn
# - [ ] Google phát triển Alphafold
# - [ ] Microsoft phát triển ResNet
# - [ ] Google phát triển InceptionNet
# - [x] Facebook phát triển MobileNet

# %% [markdown]
# **A04**. Thuật ngữ "data science" được sử dụng lần đầu tiên:
# - [ ] Bởi Jeff Wu, sử dụng như lý thyết xác suất
# - [x] Vào những năm 80s, sử dụng như thống kê
# - [ ] Sử dụng như giới thiệu hướng tiếp cận mới cho AI
# - [ ] Vào những năm 40s của thế ký 20, bởi Alan Turing

# %% [markdown]
# **A05**. Map reduce được giới thiệu lần đầu bởi công ty nào
# - [ ] Facebook
# - [ ] Data Bricks
# - [x] Google
# - [ ] Yahoo

# %% [markdown]
# **A06**. Hadoop được phát hàng lần đầu bởi công ty nào
# - [x] Yahoo
# - [ ] Facebook
# - [ ] Data Bricks
# - [ ] Google

# %% [markdown]
# **A07**. Hadoop được giới thiệu lần đầu vào năm nào
# - [ ] 2014
# - [ ] 2000
# - [ ] 2008
# - [x] 2006

# %% [markdown]
# **A08**. Ai được xem là cha đẻ của Deep learning
# - [ ] Andrew Ng
# - [ ] Ian Goodfellow
# - [x] Geoffrey Hinton
# - [ ] Alan Turing

# %% [markdown]
# **A09**. Nhận định nào sau đây là **không** đúng
# - [x] Pandas, Numpy, Sklearn cùng được phát triển bởi NumFocus
# - [ ] Dask được thiết kế trên nền tảng Pandas
# - [ ] Pandas được xây dựng trên nền tảng Numpy
# - [ ] Sklearn là ám chỉ Sciy Toolkit, là một phần mở rộng cho Scipy

# %% [markdown]
# **A10**. Tensorflow version 2 được nâng cấp gì so với version 1
# - [ ] Keras execution
# - [x] Eager execution
# - [ ] Parallel execution
# - [ ] Graph execution

# %% [markdown]
# **A11**. *Nhận định nào là đúng về artifitial neural networks (ANN)*
# - [ ] ANN được phát triển và mở rộng từ những năm 2006
# - [ ] ANN là deep learning
# - [ ] ANN chỉ hoạt động với big data
# - [x] ANN là một dạng representation learning

# %% [markdown]
# **A12**. Năm 2017, phần mềm Alpha Go đánh bại kiện tướng nào
# - [x] Ke Jie
# - [ ] Lee Se-dol
# - [ ] Greg Kohs
# - [ ] Fan Hui

# %% [markdown]
# **A13**. *Đâu không phải là một trong các nguyên nhân dẫn đến mùa đông AI*
# - [ ] Thiếu hụt phương pháp luận
# - [ ] Khả năng tính toán máy móc yếu
# - [ ] Suy thoái kinh tế
# - [x] Lo ngại mối đe dọa của AI với con người

# %% [markdown]
# **A14**. *Nhận định nào là đúng về AutoML*
# - [ ] Xoay quanh việc tự động hóa tối ưu tham số mô hình
# - [x] Hướng đến cho phép domain expert có thể triển khai học máy cho đa đạng các bài toán của mình
# - [ ] Được sinh ra nhằm thay thế đội ngũ Data scientist
# - [ ] Là một hệ sinh thái no-code, các domain expert có thể sử dụng để thực hiện ML

# %% [markdown]
# **A15**. *Các xu hướng nào sau đây là không đúng trong DS*
# - [ ] Xu hướng mở rộng ứng dụng dữ liệu lớn
# - [ ] Xu hướng mở rộng ứng dụng thuật toán học sâu
# - [x] Xu hướng thay thế con người trong xây dựng mô hình
# - [ ] Xu hướng tính toán chính xác sang tính toán xấp xỉ

# %% [markdown]
# **A16**. So sánh khả năng tính toán của GPU và CPU
# - [ ] CPU không thể thực hiện tính toán song song trong khi GPU có thể
# - [ ] CPU được thiết kế tối ưu cho các nhiệm vụ tuần tự, GPU tối ưu cho các tính toán song song
# - [ ] Khi sử dụng GPU thì không cần CPU
# - [ ] CPU phù hợp huấn luyện thuật toán học máy truyền thống, GPU phù hợp huấn luyện thuật toán học sâu

# %% [markdown]
# **A17**. Mô tả nào sau đây là một mẫu đối nghịch (adversarial example) với tấn công Fast Gradient Signed Method (FGSM)?
# - [ ] Tăng hoặc giảm độ sáng của một ảnh một ngưỡng phù hợp
# - [ ] Xoay ảnh một góc phù hợp
# - [ ] Cộng vào một nhiễu phù hợp
# - [ ] Phóng to đến một ngưỡng phù hợp

# %% [markdown]
# **A18**. So sánh nào là đúng về Spark và Dask?
# - [ ] Dask là dự án được phát triển sau spark
# - [ ] Dask được thực thi trên python interpreter, spark có thể chạy trên python interpreter (pyspark) hoặc JVM (scala)
# - [ ] Dask được phát triển để tích hợp với GPU NVIDIA
# - [ ] Spark có thể triển khai trên hàng trăm cluster, dask chỉ có thể chạy trên một cluster có nhiều nhân.

# %% [markdown]
# **A19**. Trong số các thuật toán sau, thuật toán nào ra đời sớm nhất?
# - [ ] KNN
# - [ ] Adaboost
# - [ ] Logistics
# - [ ] Multi-layer perceptron

# %% [markdown]
# # B. Data at Viettel

# %% [markdown]
# **B01**. Bạn thấy đồng nghiệp A của mình sử dụng dữ liệu để kiểm tra hành vi di chuyển của một khách hàng do KH đó có khiếu nại liên quan, đơn vị CSKH có PYC kiểm tra dữ liệu. Bạn nên làm gì?
# - [ ] Đề nghị A mã hóa số liệu
# - [x] Để A thực hiện công việc của mình
# - [ ] Báo cáo A vi phạm ATTT với trưởng đơn vị
# - [ ] Báo cáo A vi phạm ATTT với phòng ATTT

# %% [markdown]
# **B02**. Biểu mẫu BM06b trong quy trình PTDL có nội dùng gì?
# - [ ] Kết quả xây dựng mô hình
# - [ ] Xác định các mô hình học máy cần triển khai
# - [x] Kết quả tối ưu tham số
# - [ ] Xác định giải pháp xây dựng mô hình

# %% [markdown]
# **B03**. Bạn nghi ngờ người yêu của mình ngoại tình và muốn kiểm tra lịch sử cuộc gọi của người yêu mình, bạn nên làm thế nào?
# - [ ] Báo cáo trưởng đơn vị xin cấp quyền
# - [ ] Nhờ team BI report kiểm tra
# - [ ] Kiểm tra dữ liệu nhưng cần mã hóa
# - [x] Không thực hiện kiểm tra trên dữ liệu Viettel

# %% [markdown]
# **B04**. Bảng `r_c360_interact` chứa thông tin về
# - [ ] Tương tác của TB với nhau
# - [x] Tương tác của TB với ussd và MyViettel
# - [ ] Tương tác của TB với My Viettel
# - [ ] Tương tác của TB với SMS

# %% [markdown]
# **B05**. Bảng `f_vas_mps_package_daily` chứa dữ liệu về
# - [x] Đăng ký gói VAS trên hệ thống MPS của thuê bao trả trước và trả sau
# - [ ] Đăng ký gói MPS trên hệ thống VAS của thuê bao trả trước và trả sau
# - [ ] Tiêu dùng gói VAS trên hệ thống MPS của thuê bao trả trước và trả sau
# - [ ] Tiêu dùng gói VAS trên hệ thống MPS của thuê bao trả trước

# %% [markdown]
# **B06**. Dữ liệu quét kết nối từ trạm BTS đến máy điện thoại, nếu máy mở thì trả về một số thông tin gọi là dữ liệu gì?
# - [x] Register
# - [ ] Checking
# - [ ] Roaming
# - [ ] Connecting

# %% [markdown]
# **B07**. Bạn cần dữ liệu người dùng đang sử dụng các gói cước nào, bảng nào sau đây chưa thông tin bạn cần?
# - [x] f_cp360_rel_sub_product
# - [ ] f_vas_mps_package_daily
# - [ ] f_sub_info_d
# - [ ] f_profile_c360_full

# %% [markdown]
# **B08**. Thông tin nào sau đây là đúng
# - [ ] Dữ liệu location phát sinh thoại là không đáng tin cậy
# - [x] Dữ liệu location phát sinh SMS là không đáng tin cậy
# - [ ] Dữ liệu location phát sinh data là không đáng tin cậy
# - [ ] Dữ liệu location register ngoài 2 khung giờ 9h và 21h là không đáng tin cậy

# %% [markdown]
# **B09**. Bảng nào chứa thông tin chặn khách hàng quảng cáo
# - [x] f_cus360_sms_deny_197_199
# - [ ] f_profile_c360_full
# - [ ] f_c360_tuong_tac_vien_thog
# - [ ] f_customer_complain

# %% [markdown]
# **B10**. Bạn cần tìm kiếm lịch sử người dùng truy cập internet theo phiên, bảng dữ liệu nào có dữ liệu này cho bạn?
# - [ ] f037_url_detail_day
# - [ ] f_data_package_daily
# - [x] f003_mpre_data
# - [ ] f_detail_url_https

# %% [markdown]
# **B11**. Bảng nào chứa thông tin lịch sử nghe, gọi, nhắn tin của các thuê bao với nhau
# - [ ] f_ipcc_call_d
# - [ ] f_profile_c360_full
# - [x] f_c360_tuong_tac_vien_thog
# - [ ] f_call_out_d

# %% [markdown]
# **B12**. Khả năng xác định vị trí của người dùng bằng dữ liệu viễn thông như thế nào?
# - [x] ~150m nội thành đến ~500m ngoại thành
# - [ ] ~10m nội thành đến 150m ngoại thành
# - [ ] Lưu trữ toàn bộ thông tin vị trí khi người dùng có mở máy
# - [ ] Các cell có phạm vi ~10m, trạm BTS có phạm vi ~150m

# %% [markdown]
# **B13**. Để đánh giá mức độ ảnh hưởng của việc truyền thông dẫn đến thay đổi hành vi khách hàng hay không, cần so sánh các tập nào?
# - [x] TG với HO-H
# - [ ] TG với HO
# - [ ] TG với MHO
# - [ ] TG với BAU

# %% [markdown]
# **B14**. Người bạn tên A của bạn có nhờ bạn kiểm tra lịch sử cuộc gọi của anh ấy. Bạn nên làm gì?
# - [ ] A được quyền kiểm tra dữ liệu của chính mình, vì vậy bạn có thể hỗ trợ anh A
# - [ ] Bạn có thể hỗ trợ nhưng cần mã hóa kết quả và gửi cho A
# - [x] Bạn không hỗ trợ được A
# - [ ] Bạn báo cáo việc A nhờ lấy dữ liệu với trưởng đơn vị

# %% [markdown]
# **B15**. Biểu mẫu BM12 trong quy trình PTDL có nội dùng gì?
# - [ ] Kết quả xây dựng mô hình
# - [ ] Kết quả tối ưu tham số
# - [ ] Kết quả EDA
# - [x] Giả thuyết và kiểm định

# %% [markdown]
# **B16**. Bảng `f_sub_info_d` có thông tin về các TB nào?
# - [ ] Trả trước
# - [ ] Trả trước, trả sau
# - [x] Trả trước, trả sau, dcom
# - [ ] Trả trước, trả sau, dcom, FTTH

# %% [markdown]
# **B17**. Dữ liệu đầy đủ đăng ký toàn bộ các gói VAS cần tra cứu từ bảng dữ liệu nào?
# - [ ] f_vfsfree_package_daily
# - [x] f023_mpre_vas
# - [ ] F_vas_mps_package_daily
# - [ ] f_data_package_daily

# %% [markdown]
# **B18**. Trong trường hợp nào không thể xác định được vị trí của người dùng
# - [ ] Người dùng không nhắn tin
# - [ ] Người dùng không gọi điện
# - [ ] Người dùng không truy cập data
# - [x] Người dùng tắt nguồn

# %% [markdown]
# **B19**. Trong một cuộc trao đổi với khách hàng là một đơn vị kinh doanh của Viettel. Bạn được đề nghị cung cấp số liệu về doanh thu và lưu lượng data của một huyện. Bạn nên hành xử như thế nào?
# - [ ] Cung cấp số liệu cho đơn vị kinh doanh đó, vì họ là người nội bộ trong Viettel
# - [ ] Cung cấp thông tin cho đơn vị kinh doanh vì đây là dữ liệu tổng hợp, không vi phạm thông tin cá nhân của khách hàng.
# - [ ] Chỉ cung cấp thông tin về lưu lượng data và không cung cấp thông tin về doanh thu. Vì doanh thu là thông tin nhạy cảm.
# - [ ] Hỏi ý kiến quản lý hoặc đề nghị đơn vị kinh doanh ký PYC cung cấp số liệu đến VBI report

# %% [markdown]
# **B20**. Bạn vừa nghỉ việc tại công ty cũ và gia nhập Viettel. Bài toán bạn đang phụ trách có nhiều điểm tương đồng với một hệ thống bạn đã làm việc trước đó tại công ty cũ. Hành xử nào sau đây của bạn là phù hợp?
# - [ ] Coi như không biết, không có kinh nghiệm về bài toán này và thực hiện nghiên cứu lại từ đầu, vì các giải pháp của dự án cũ là thuộc sở hữu của công ty cũ.
# - [ ] Được sử dụng mọi nguồn thông tin, thiết kế mà không có văn bản pháp lý nào ràng buộc giữ bí mật. Đặc biệt khai thác các điểm yếu của hệ thống cũ để xây dựng hệ thống mới cạnh tranh vượt trội hơn.
# - [ ] Sử dụng kinh nghiệm và tri thức bản thân về bài toán này (bao gồm tri thức học được khi triển khai dự án tại công ty cũ) để triển khai dự án mới. Không tiết lộ thiết kế hoặc đặc điểm của hệ thống tại công ty cũ.
# - [ ] Sử dụng lại thiết kế của dự án tại công ty cũ để triển khai dự án mới, tuy nhiên loại bỏ ra các yếu tố nhạy cảm, bí mật kinh doanh của công ty cũ.

# %% [markdown]
# **B21**. Biểu mẫu BM04 trong quy trình PTDL có nội dùng gì?
# - [ ] Kết quả xây dựng mô hình
# - [ ] Xác định các mô hình học máy cần triển khai
# - [ ] Kết quả tối ưu tham số
# - [ ] Xác định giải pháp xây dựng mô hình

# %% [markdown]
# **B22**. Để đánh giá mức độ hiểu quả của việc lựa chọn TB theo model và không sử dụng model, cần so sánh giữa các tập nào?
# - [ ] MHO với TG
# - [ ] TG với CG
# - [ ] TG với HO
# - [ ] TG với BAU

# %% [markdown]
# **B23**. Trong số các loại dữ liệu sau, dữ liệu nào là nhạy cảm và cần được mã hóa?
# - [ ] Số chứng minh nhân dân
# - [ ] Tên khách hàng
# - [ ] Số lượng cuộc gọi
# - [ ] Vị trí khách hàng

# %% [markdown]
# **B24**. Thuê bao 3K3D là thuê bao gì?
# - [ ] Thuê bao phát sinh tiêu dùng gốc tối thiểu 3K, có log register tối thiểu 3 ngày
# - [ ] Thuê bao phát sinh tổng tiêu dùng tối thiểu 3K, có log register tối thiểu 3 ngày
# - [ ] Thuê bao phát sinh tổng tiêu dùng tối thiểu 3K, có log register tối thiểu 3 ngày trên hạ tầng 3G
# - [ ] Thuê bao phát sinh tổng tiêu dùng tối thiểu 3K, có log register tối thiểu 3 ngày trên hạ tầng 4G

# %% [markdown]
# **B25**. Cước roaming là gì?
# - [ ] Cước gọi ngoại mạng
# - [ ] Cước gọi cho thuê bao feature phone
# - [ ] Cước gọi chuyển vùng quốc tế
# - [ ] Cước gọi đến thuê bao cố định

# %% [markdown]
# **B26**. Điều kiện nào sau đây không loại bỏ thuê bao được phép truyền thông quảng cáo qua kênh SMS?
# - [ ] Thuê bao chặn 197
# - [ ] Thuê bao chặn 199
# - [ ] Thuê bao do-not-call theo danh sách của bộ TT&TT
# - [ ] Thuê bao đủ 13 tin quảng cáo

# %% [markdown]
# # C. Statistics and Probability

# %% [markdown]
# **C01**. X và Y là 2 biến ngẫu nhiên. X có giá trị trung bình là 5, phương sai là 4. Y có giá trị trung bình là 7, phương sai là 9. Hãy cho biến giá trị trung bình của biến ngẫu nhiên Z với Z = X+Y
# - [ ] 5
# - [ ] 4.833
# - [ ] 2
# - [x] 12

# %% [markdown]
# **C02**. Các số đếm thường tuân theo quy luật phân phối Poisson. Tuy nhiên trong nhiều trường hợp ta kỳ vọng phân phối ở dạng phân phối chuẩn để tiện tính toán và phân tích.
# Biến ngẫu nhiên X đang ở phân phối Poisson, giải pháp nào sau đây có thể chuyển hóa phân phối này thành sấp xỉ phân phối chuẩn?
# - [x] Lấy căn bậc 2 của X
# - [ ] Lấy bình phương của X
# - [ ] Lấy sai phân của X
# - [ ] Cộng X với một giá trị số lớn hơn 0

# %% [markdown]
# **C03**. Để xác định sản lượng cá trong hồ, người ta bắt lên 1000 con cá, sau đó đánh dấu và thả lại chúng xuống hồ. Sau một thời gian đánh lên 400 con cá thì thấy 80 con có đánh dấu. Với độ tin cậy 95%, xác định số cá tối thiểu có trong hồ.
# - [ ] 200.8
# - [ ] 180.0
# - [x] 160.8
# - [ ] 120.6

# %% [markdown]
# **C04**. Cho biến ngẫu nhiên X, có phân phối lệch trái. Nhận định nào sau đây là đúng về các chỉ số thống kê của X?
# - [ ] mean = median
# - [x] mean < median
# - [ ] mean > median
# - [ ] mean > 0

# %% [markdown]
# **C05**. Trước tổng tuyển cử, phỏng vấn ngẫu nhiên 3000 cử tri thì 1630 cử tri nói sẽ bầu cho ứng viên X. Với độ tin cậy 95%, ứng viên X sẽ dành được tỷ lệ khoảng bao nhiêu % phiếu bầu?
# - [x] 0.5255083851904552
# - [ ] 0.528373108999132
# - [ ] 0.5316743621500835
# - [ ] 0.5191511727828596

# %% [markdown]
# **C06**. *Các trạm bơm A, B, C làm việc độc lập với nhau để bơm nước từ E đến F. Xác suất để mỗi trạm gặp sự cố sau một thời gian hoạt động là 1%, 2%, 3%.Xác suất để vùng F mất nước là bao nhiêu?*
#
# <img src='attachment:feaab93a-cffa-42a0-8773-b01a7840dd59.png' style='height:100px'>
#
# - [ ] 0.030199999999999998
# - [ ] 0.010194
# - [x] 0.030194
# - [ ] 0.0102

# %% [markdown]
# **C07**. Mô tả nào sau đây là đúng về phương pháp lấy mẫu stratified sampling
# - [ ] Chia tập dữ liệu thành các cụm theo các mô hình phân cụm. Lấy mẫu ra từ các cụm đó
# - [ ] Chia tập dữ liệu dải thành các quan sát theo danh sách. Lần lượt lấy ra các quan sát ở các thứ bậc xác định.
# - [ ] Chọn ngẫu nhiên theo một danh sách giả random cho trước
# - [x] Chia tập dữ liệu thành các nhóm theo tiêu chí xác định. Lấy mẫu tương ứng từ các nhóm đó theo tỷ lệ mục tiêu

# %% [markdown]
# **C08**. Tỷ lệ thuê bao có tăng tiêu dùng duy trì ổn định ở mức 15%. Để dự đoán một thuê bao có gia tăng tiêu dùng hay không, bạn xây dựng mô hình học máy và nhận thấy mô hình có true-positive rate (TPR) là 80% và true-negative rate (TNR) là 60%.
# Chọn ra 100k thuê bao được dự đoán có tăng tiêu dùng, bình quân số lượng thuê bao không tăng tiêu dùng là bao nhiêu?
# - [ ] 68449
# - [x] 73913
# - [ ] 31551
# - [ ] 26086

# %% [markdown]
# **C09**. Bạn thực hiện A/B testing để kiểm nghiệm hiệu quả của việc truyền thông bán gói. Hai tập thuê bao A và B được lựa chọn ngẫu nhiên, không trùng nhau và đồng chất. Tập A được truyền thông bán gói, tập B không được truyền thông.
# Thu thập thông tin sau triển khai, trong số 500k TB của tập A thì có 3.058 TB phản hồi, trong số 80k TB của tập B thì có 448 TB phản hồi.
# Với mức ý nghĩa 5%, có thể kết luận chương trình tác động có hiệu quả hay không?
# - [ ] Chưa đủ dữ liệu để kết luận
# - [ ] Có thể kết luận chương trình hiệu quả vì 3058/500k > 448/80k
# - [x] Có thể kết luận chương trình hiệu quả theo tiêu chuẩn kiểm định
# - [ ] Không thể kết luận chương trình hiệu quả => chương trình không hiệu quả theo tiêu chuẩn kiểm định

# %% [markdown]
# **C10**. Một đoàn tàu vào ga gồm 4 toa, trong sân ga có 8 hành khách đang chờ lên tàu. Tính xác suất để mỗi toa có 2 hành khách.
# Biết rằng, mỗi toa còn ít nhất 8 chỗ trống, việc lên tàu của mỗi hành khách là ngẫu nhiên và độc lập nhau.
# - [x] 0.0384521484375
# - [ ] 0.076904296875
# - [ ] 0.009613037109375
# - [ ] 0.615234375

# %% [markdown]
# **C11**. Giả sử $X$ có hàm phân phối liên tục $F(x)$. Xác định hàm phân phối của $Y = F(X)$.
# - [x] $F_Y(y)=
# \begin{cases}
#     0 & {\text{if }}y\leq 0\\
#     y & {\text{if }}0<y\leq 1\\
#     1 & {\text{if }}y\geq 1
# \end{cases}
# $
# - [ ] $F_Y(x)=F(x^2)$
# - [ ] $F_Y(x)=-1$
# - [ ] $F(x)=1-e^{-\lambda x}\;\;\text{for }x>0$

# %% [markdown]
# **C12**. Một tập dữ liệu được xác định là có khả năng cao có các quan sát ngoại lai (outlier), chỉ số nào sau đây là phù hợp để đánh giá xu hướng trung tâm của phân phối?
# - [ ] Mean
# - [x] Median
# - [ ] Standard deviation
# - [ ] Variance

# %% [markdown]
# **C13**. Trong một nhóm 40 người có 1 người bị nhiễm covid. Bạn dùng kit test để xác định người đó là ai. Để tiết kiệm, bạn xây dựng một chiến thuật test sao cho kỳ vọng số kit test là tối thiểu. Khi đó, kỳ vọng số kit test cần thiết để tìm ra được người nhiễm covid là bao nhiêu?
# Cho rằng độ chính xác của kit test là 100%, có thể gộp nhiều mẫu để xét nghiệm chung và số mẫu của mỗi người là không giới hạn (một người có thể được test lại nhiều lần).
# - [ ] 5.4
# - [ ] 40
# - [ ] 15.33
# - [ ] 8.4

# %% [markdown]
# **C14**. X là một biến ngẫu nhiên tuân theo quy luật phân phối chuẩn, Y là một biến ngẫu nhiên tuân theo quy luật phân phối Khi bình phương (Chi-square).
# Với Z = X+Y,
# Nhận định nào sau đây là đúng?
# - [ ] Z tuân theo quy luật Khi bình phương
# - [ ] Z tuân theo quy luật chuẩn
# - [ ] Z là phân phối lệch phải
# - [ ] Z là phân phối lệch trái

# %% [markdown]
# **C15**. Cho $P(A)=P(B)=P(A|B)=0.25$. Tính $P(B\bar{A})$
# - [ ] 0.0625
# - [ ] 0.1825
# - [ ] 0.75
# - [ ] 0.167

# %% [markdown]
# **C16**. Nhận định nào đúng về định lý giới hạn trung tâm?
# - [ ] Khi tăng số lượng mẫu thì phân phối tập mẫu tuân theo quy luật phân phối chuẩn
# - [ ] Khi tăng số lượng quan sát trong mẫu thì phân phối của mẫu hội tụ về phân phối chuẩn bất kể phân phối của tổng thể.
# - [ ] Khi tăng số lượng mẫu thì phương sai của mẫu tuân theo quy luật Khi bình phương (Chi-square)
# - [ ] Khi tăng số lượng mẫu thì trung bình các giá trị trung bình của mẫu gần bằng với trung bình của tổng thể

# %% [markdown]
# **C17**. Trên đường tròn bán kính R có một điểm A cố định, chọn ngẫu nhiên một điểm B. Tìm xác suất để cung AB không quá R.
# - [ ] 0.1592
# - [ ] 0.3183
# - [ ] 0.6366
# - [ ] 0.2618

# %% [markdown]
# **C18**. Bạn huấn luyện mô hình học máy và triển khai trên thực tế. Benchmark mô hình so sánh là 15% tỷ lệ phản hồi. Triển khai truyền thông trên 2500 thuê bao, số lượng tối thiểu thuê bao phản hồi phải đạt bao nhiêu để có thể kết luận mô hình của bạn tốt hơn benchmark (độ tin cậy 95%)?
# - [ ] 406
# - [ ] 347
# - [ ] 375
# - [ ] 412

# %% [markdown]
# **C19**. Sử dụng test nhanh để test covid thì thấy trong 2500 nhân viên một khu công nghiệp, có 358 mẫu cho kết quả test nhanh dương tính. Hỏi, kỳ vọng số người mắc covid là bao nhiêu? Biết rằng test nhanh có độ chính xác 95% với ca mắc, 90% với ca không mắc covid.
# - [ ] 300
# - [ ] 250
# - [ ] 127
# - [ ] 118

# %% [markdown]
# **C20**. Cho biết ý nghĩa của "mức ý nghĩa" alpha khi thực hiện suy diễn thống kê
# - [ ] Là mức mà giá trị của biến ngẫu nhiên gần như không vượt quá
# - [ ] Là sai lầm loại I của kết luận suy diễn
# - [ ] Là sai lầm loại II của kết luận suy diễn
# - [ ] Là khoảng phân vị mà dải phân phối của biễn ngẫu nhiên nằm trong khoảng

# %% [markdown]
# # D. Programming

# %% [markdown]
# **D01**. Cho các list: A = `[1,2,3]` và B = `['a','b','c']`. Hãy cho biết lệnh nào sau đây trả về C = `[1,'a',2,'b',3,'c']`
#
# ```python
# # script 1
# C = [i, j for i in A for j in B]
#
# # script 2
# C = [A[i] if j==1 else B[i] for i in range(3) for j in range(2)]
#
# # script 3
# C = [A[i] if j==0 else B[i] for i in range(3) for j in range(2)]
#
# # script 4
# C = [i, j for i in B for j in A]
# ```
#
# - [ ] script 1
# - [ ] script 2
# - [x] script 3
# - [ ] script 4

# %% [markdown]
# **D02**. Hãy lựa chọn nhận định đúng trong số các nhận định sau về global interpreter lock (GIL)
# - [x] GIL tạo ra rào cản cho việc chạy song song các tiến trình của python, vì nó yêu cầu chỉ 1 thread được chạy tại mỗi thời điểm
# - [x] GIL đảm bảo kết quả thực hiện các tiến trình cho ra kết quả đúng, đặc biệt với các phép toán có phụ thuộc thứ tự
# - [ ] GIL chỉ có ảnh hưởng với Cython, PyPy-STM, Jython interpreter, với các interpreter khác như IronPython thì không bị ảnh hưởng
# - [ ] Các python threads sử dụng chung một memory, vì vậy không thể bỏ qua GIL trong mọi hoàn cảnh để đảm bảo việc truy xuất và thay đổi dữ liệu trong memory là thread-safed

# %% [markdown]
# **D03**. Biết rằng, shape của các array đã có là: A<sub>(1,10)</sub>, B<sub>(1,5)</sub>, C<sub>(10,1)</sub>, D<sub>(5,10)</sub>, E<sub>(10,5)</sub>. Hãy cho biết phép tính nào sẽ cho ra kết quả là một array, có số chiều là 10x10
# - [x] A+C
# - [ ] B+D
# - [ ] D+E
# - [ ] Không có mảng nào

# %% [markdown]
# **D04**. Kết quả chạy đoạn lệnh sau là gì?
# ```python
# class Abc():
#     x = 5
#     def send(self, x):
#     return x**2
# t = Abc()
# t.send()
# ```
# - [ ] 5
# - [ ] 25
# - [x] ERROR
# - [ ] 2

# %% [markdown]
# **D05**. Kết quả in ra màn hình của đoạn lệnh sau là gì:
# ```python
# x = 'hello'
# k = (i for i in x)
# i = next(k)
# j = next(k)
# print(i==j)
# ```
# - [ ] ERROR
# - [ ] hello
# - [ ] True
# - [x] False

# %% [markdown]
# **D06**. RAM đang lưu 100Gb dữ liệu, biến df_train là một dataframe có dung lượng 10Gb.
# Thực thi lệnh: `del df_train`
# Sau khi thực thi, dụng lượng RAM đang lưu là bao nhiêu?
# - [ ] 90Gb
# - [ ] 110Gb
# - [ ] 10Gb
# - [x] 100Gb

# %% [markdown]
# **D07**. Thực thi đoạn lệnh sau, kết quả hiển thị là gì?
# ```python
# x = 5
# print(x>1 or x<2 and not x==5, x*x**(x-3)>200)
# ```
# - [ ] True True
# - [ ] Flase False
# - [x] True False
# - [ ] Flase True

# %% [markdown]
# **D08**. Cho biết đã thực thi các lệnh sau
# ```python
# import numpy as np
# ind = [1, 2, 3, 3]
# label = ['a','b', 'c']
# ```
# Để thu được biến x='a', lệnh nào sau đây cần thực thi
# - [ ] x = label[ ind==1]
# - [ ] x = label[ label==1]
# - [ ] x = label[ 1]
# - [ ] x = label[ -1]

# %% [markdown]
# **D09**. Kết quả in ra màn hình của câu lệnh sau là gì?
# ```python
# print(type( int(6.5) + True + bool("python")))
# ```
# - [ ] <class 'bool'>
# - [ ] <class 'int'>
# - [ ] <class 'str'>
# - [ ] Lỗi cú pháp

# %% [markdown]
# **D10**. Một lớp được thừa hưởng thuộc tính từ 2 lớp khác nhau được gọi là gì?
# - [ ] Kế thừa đa cấp (multilevel inheritance)
# - [ ] Đa kế thừa (multiple inheritance)
# - [ ] Kế thừa phân cấp (hierarchical inheritance)
# - [ ] Kế thừa (inheritance)

# %% [markdown]
# **D11**. Thực thi đoạn lệnh như hình trên thu được kết quả nào sau đây?
# ```python
# def fn():
#     try:
#         print('a')
#     finally:
#         print('b')
# ```
#
# - [ ] a
# - [ ] b
# - [ ] a b
# - [ ] b a

# %% [markdown]
# # E. Data manipulation

# %% [markdown]
# **E01**. Câu lệnh nào dưới đây trả về tên của nhân viên (employee) có lương cao nhất trong mỗi phòng
# (department)
# ```sql
# -- script 1
# SELECT Emp_Name,Dep_Code,Salary
# FROM Employee
# WHERE Employee.Salary = (Select Max(Salary) from Employee GROUP BY Dep_Code);
#
# -- script 2
# SELECT Emp_Name,Dep_Code,Salary
# FROM Employee
# WHERE Employee.Salary In (Select Max(Salary) from Employee GROUP BY Dep_Code HAVING Max(Salary));
#
# -- script 3
# SELECT Emp_Name,Dep_Code,Salary
# FROM Employee
# WHERE Employee.Salary In (Select Max(Salary) from Employee GROUP BY Dep_Code);
#
# -- script 4
# SELECT Emp_Name,Dep_Code,Salary
# FROM Employee
# WHERE Employee.Salary In (Select Salary from Employee GROUP BY Dep_Code HAVING Max(Salary));
# ```
#
# - [ ] script 1
# - [ ] script 2
# - [x] script 3
# - [ ] script 4

# %% [markdown]
# **E02**. Câu lệnh đúng để xem các bản ghi về khách hàng có số điện thoại
# - [x] SELECT * from customer where phone IS NOT NULL
# - [ ] SELECT * from customer where phone = NOT NULL
# - [ ] SELECT * from customer where phone NOT NULL
# - [ ] SELECT * from customer where HAVING phone NOT NULL

# %% [markdown]
# **E03**. Ngoài sử dụng distinct để lọc trùng dữ liệu thì còn cách nào khác?
# - [ ] Sử dụng Union
# - [ ] Sử dụng Minus
# - [ ] Sử dụng Having by
# - [x] Sử dụng Group by

# %% [markdown]
# **E04**. Trước khi drop 1 table trên Spark Thrift, ta cần thực hiện lệnh
# `alter table <table_name> set tblproperties('EXTERNAL'='FALSE')`
# Mục đích của lệnh này để làm gì?
# - [ ] Để chuyển về mode writable, mới có thể drop được table
# - [ ] Để chuyển về mode readonly, chỉ đọc, không chó phép ghi, mới có thể drop được table
# - [ ] Để di chuyển dữ liệu table về thư mục quản lý của Hive/Thrift thì mới drop được table
# - [x] Để khi drop table, dữ liệu được xóa trên HDFS

# %% [markdown]
# **E05**. Phân biệt UNION và UNION ALL
# - [ ] UNION ghép các bảng theo chiều dọc UNION ALL ghép các bảng theo chiều ngang
# - [ ] UNION giữ lại các bản ghi trùng lặp, UNION ALL bỏ đi các bản ghi lặp
# - [x] UNION ALL giữ lại các bản ghi trùng lặp, UNION bỏ đi các bản ghi lặp
# - [ ] UNION ALL ghép các bảng theo chiều dọc UNION ghép các bảng theo chiều ngang

# %% [markdown]
# **E06**. Xác định câu lệnh truy vấn mà trả về tất cả tên trong bảng Accounts chứa ký tự 'e', nhưng không phải là ký tự đầu tiên
# - [ ] SELECT * FROM Accounts WHERE Names LIKE ‘%e’
# - [ ] SELECT Name FROM Accounts WHERE Name RLIKE '[^e]'
# - [ ] SELECT Name FROM Accounts WHERE Name RLIKE 'e[^e]'
# - [x] SELECT Name FROM Accounts WHERE Name RLIKE '[^e]e'

# %% [markdown]
# **E07**. Cho bảng "table" như hình vẽ,
# Lệnh nào sau đây lấy được sản phẩm tốt nhất tương ứng từng thuê bao?
#
# <img src='attachment:c0305589-b49f-462c-9f41-710c7caf5306.png' style='height:150px'>
#
# ```sql
# -- script 1
# SELECT isdn
# FROM table
# WHERE score IN (SELECT MAX(score) FROM A)
#
# -- script 2
# SELECT *
# FROM (
#     SELECT isdn, product, ROW_NUMBER() OVER (PARTITION BY isdn ORDER BY score DESC) AS row_num
#     FROM table)
# WHERE row_num = 1
#
# -- script 3
# SELECT isdn
# FROM table
# WHERE product IN (SELECT MAX(product) FROM A)
#
# -- script 4
# SELECT isdn, product, ROW_NUMBER() OVER (PARTITION BY isdn ORDER BY score DESC) AS row_num
# FROM table
# WHERE row_num = 1
# ```
#
# - [ ] script 1
# - [x] script 2
# - [ ] script 3
# - [ ] script 4

# %% [markdown]
# **E08**. Cho 2 bảng A, B như hình.
# Thực thi câu lệnh sau
#
# ```sql
# insert overwrite table X
# select A.*, B.*
# from A left join B
# on A.key = B.key
# ```
#
# Bảng X có bao nhiêu row?
#
# <img src='attachment:a1641173-f90e-47d5-8194-5dfce1a619c1.png' style='height:150px'>
#
# - [ ] 10
# - [ ] 24
# - [x] 25
# - [ ] 80

# %% [markdown]
# **E09**. Theo chính sách của công ty, một số người không có lương sẽ được nhận một khoản thưởng của công ty.
# Giá trị các khoản thưởng phụ thuộc chức vụ từng nhân viên, và đã được tổng hợp sẵn trong bảng f_salary có metadata như sau:
# ```f_salary
# |- employee: string: mã nhân viên
# |- basic_salary: double: lương cơ bản
# |- bonus: double: thưởng thêm
# ```
# Lệnh nào sau đây truy xuất giá trị tiền thực nhận của từng nhân viên?
# - [ ] select nvl(salary, bonus) as thu_nhap from f_salary
# - [ ] select nvl(salary, bonus) as thu_nhap from f_salary where salary+bonus >0
# - [x] select nvl2(salary, bonus,0) as thu_nhap from f_salary
# - [ ] select salary + bonus as thu_nhap from f_salary

# %% [markdown]
# **E10**. Cho dataframe df như hình trên.
# Lệnh nào sau đây trả về dataframe tổng số sms lũy kế trong 7 giao dịch gần nhất chia theo từng type.
# Biết rằng đã thực thi các lệnh sau:
# ```python
# from pyspark.sql.window import Window
# from pyspark.sql import functions as F
# ```
# <img src='attachment:0a741a9a-efd3-41f3-813e-a9e9d545a7ba.png' style='height:200px'>
#
# ```python
# # script 1
# df2 = df.withColumn('rolling_average', F.sum("sms").over().partitionBy("type").orderBy("start_at").rowsBetween(-7, 0)
#
# # script 2
# w = (Window().partitionBy(F.col("type")).orderBy(F.col("start_at").cast('long')).rowsBetween(-7, 0))
# df2 = df.withColumn('rolling_average', F.sum("sms").over(w))
#
# # script 3
# w = Window(partition = 'type', order = 'start_at')
# df2 = df.withColumn('rolling_average', F.sum("sms").over(w))
#
# # script 4
# w = Window(partition = 'type', order = 'start_at', range = 'ROWS BETWEEN 7 preceding')
# df2 = df.withColumn('rolling_average', F.sum("sms").over(w))
# ```
#
# - [ ] script 1
# - [x] script 2
# - [ ] script 3
# - [ ] script 4

# %% [markdown]
# **E11**. Mệnh đề nào sau đây là đúng
# - [ ] Hàm RANK và DENSE_RANK đánh số thứ tự lần lượt. RANK đánh liên tục giá trị tăng dần, 2 dòng có chung giá trị tham chiếu thì có thể có RANK khác nhau, nhưng có DENSE_RANK giống nhau
# - [ ] Các dòng có giá trị lớn hơn thì có RANK lớn hơn, có DENSE_RANK nhỏ hơn
# - [ ] Các dòng có chung giá trị tham chiếu thì có RANK giống nhau, nhưng DENSE_RANK khác nhau
# - [x] Các dòng có chung giá trị tham chiếu thì có RANK và DENSE_RANK giống nhau

# %% [markdown]
# **E12**. Bảng table_a trỏ đến location có chứa dung lượng dữ liệu 10Gb.
# Tạo view sau:
# ```sql
# CREATE OR REPLACE VIEW tmp_half_of_a AS
# SELECT * FROM table_a WHERE rand(100) > 0.5
# ```
# Dung lượng của tmp_half_of_a là bao nhiêu?
# - [ ] 10Gb
# - [ ] 20Gb
# - [x] 0Gb
# - [ ] 5Gb

# %% [markdown]
# **E13**. Định dạng "map" trong spark tương đương với dạng dữ liệu nào trong python
# - [ ] list
# - [x] dict
# - [ ] tuple
# - [ ] set

# %% [markdown]
# **E14**. Nhận định nào sau đây là đúng?
# - [ ] Persist chỉ lưu trên ổ disk nên làm tăng đáng kể thời gian thực thi câu lệnh do phải giao tiếp với ổ cứng
# - [ ] Persist chỉ lưu trữ trên memory do đó bị hạn chế dung lượng. Có thể dẫn đến lỗi tràn bộ nhớ
# - [x] persist() là phương thức lưu caching dữ liệu tránh tính toán lại DAG
# - [ ] Chỉ nên sử dụng persist với bộ dữ liệu nhỏ

# %% [markdown]
# **E15**. Trường hợp nào sau đây là phù hợp nhất để bạn phải sử dụng đến từ khóa CASE?
# - [ ] Tính doanh thu bình quân trên từng đơn hàng
# - [ ] Gom nhóm doanh thu theo từng tháng
# - [x] Tính doanh thu của các đơn hàng có giá lớn hơn 10
# - [ ] Đếm số lượng đơn hàng sản suất trong 1 tháng xác định

# %% [markdown]
# **E16**. điền tên quận. Lệnh nào sau đây ghép quận và tỉnh thành một chuỗi duy nhất phù hợp?
# - [ ] select name, concat(district, ', ', province) as address from f_student
# - [x] select name, concat_ws(', ',district, province) as address from f_student
# - [ ] select name, concat(province, district) as address from f_student
# - [ ] select name,district + province as address from f_student

# %% [markdown]
# **E17**. Vai trò của SparkSession là gì?
# - [x] Là phương thức cho phép truy cập các chức năng của Spark
# - [ ] Khởi tạo một môi trường làm việc mới với danh sách các biến môi trường độc lập
# - [ ] Để tạo phiên làm việc với tài nguyên được cấp phát riêng phục vụ tính toán
# - [ ] Tạo phiên kết nối tới tài nguyên của Spark core để chuyển được lệnh về spark core thực thi

# %% [markdown]
# **E18**. Nhận định nào sau đây là đúng?
# - [x] Pyspark udf có để được sử dụng dưới dạng lệnh SQL
# - [ ] python udf chạy nhanh hơn pandas udf vì không phải convert định dạng dữ liệu thông qua Apache Arrow
# - [ ] parquet là một dạng định dạng của Apache Arrow
# - [ ] Khi khai báo udf trong pyspark, chỉ được sử dụng các cú pháp và định dạng của spark, không thể sử dụng hàm và định dạng dữ liệu của naitive python

# %% [markdown]
# **E19**. Giá trị NULL trong cột của biểu thức ON được xử lý thế nào khi tiến hành JOIN hai bảng
# - [ ] Các dòng có chứa giá trị NULL của bảng này chỉ kết hợp các dòng có giá trị NULL ở bảng còn lại
# - [ ] Các dòng có chứa giá trị NULL sẽ không được trả về trừ khi sử dụng OUTER JOIN
# - [ ] Các dòng có chứa giá trị NULL của bảng này kết hợp với tất cả các dòng bảng còn lại
# - [ ] Các dòng có chứa giá trị NULL của bảng này không kết hợp được với bất cứ dòng nào ở bảng còn lại

# %% [markdown]
# **E20**. Từ khóa nào sau đây là bắt buộc cần có khi thực thi một lệnh SQL
# - [ ] SELECT
# - [ ] FROM
# - [ ] WHERE
# - [ ] Không từ khóa nào

# %% [markdown]
# **E21**. Cho bảng thông tin của từng thuê bao có dạng:
# ```
# user_inf
# |- isdn: string: số điện thoại
# |- province: string: tỉnh thành
# ```
# Để phân tập cho A/B testing, bạn cần lấy 2 tập đồng chất, tổng số TB của 2 tập chiếm 10% tổng số TB, đảm bảo phân phối số thuê bao theo tỉnh thành là giống nhau.
# Lệnh nào sau đây là phù hợp với mục đích đó?
#
# ```sql
# -- script 1
# WITH tbl AS (
#     SELECT isdn, NTILE(20) OVER (PARTITION BY province ORDER BY RAND(10) AS tile
#     FROM user_inf)
# SELECT isdn, CASE WHEN tile =1 THEN 'A' ELSE 'B' END as user_group
# FROM tbl WHERE tile <= 2
#
# -- script 2
# WITH tbl AS (
#     SELECT isdn, NTILE(10) OVER (ORDER BY RAND(10) AS tile
#     FROM user_inf)
# SELECT isdn, CASE WHEN tile =2 THEN 'A' ELSE 'B' END as user_group
# FROM tbl WHERE tile <= 2
#
# -- script 3
# WITH tbl AS (
#     SELECT isdn, NTILE(10) OVER (PARTITION BY isdn ORDER BY RAND(100) AS tile
#     FROM user_inf)
# SELECT isdn, CASE WHEN tile =2 THEN 'A' ELSE 'B' END as user_group
# FROM tbl WHERE tile <= 2
#
# -- script 4
# WITH tbl AS (
#     SELECT isdn, NTILE(5) OVER (PARTITION BY province ORDER BY RAND(100) AS tile
#     FROM user_inf)
# SELECT isdn, CASE WHEN tile =2 THEN 'A' ELSE 'B' END as user_group
# FROM tbl WHERE tile <= 2
# ```
# - [ ] script 1
# - [ ] script 2
# - [ ] script 3
# - [ ] script 4

# %% [markdown]
# **E22**. Cho bảng Sinh_Vien như hình, khi thực thi câu lệnh sau, kết quả thu được các value nào?
# ```sql
# SELECT masv
# FROM Sinh_Vien WHERE makh IN
# (SELECT makh FROM Sinh_Vien WHERE masv IN
# (SELECT masv FROM Sinh_Vien WHERE ten = ’Phuong’))
# ```
# <img src='attachment:4d4d12f6-a064-4ff2-b298-9c4c8f39b495.png' style='height:150px'>
#
# - [ ] C02
# - [ ] C01
# - [ ] C01, C02
# - [ ] B01, B02, C01, C02

# %% [markdown]
# **E23**. Lựa chọn cấu hình lưu trữ persist (caching) nào sau đây cho tốc độ xử lý CPU cao nhất?
# - [ ] MEMORY_ONLY
# - [ ] DISK_ONLY
# - [ ] MEMORY_ONLY_SER
# - [ ] MEMORY_AND_DISK

# %% [markdown]
# **E24**. Đâu là một điểm yếu của pyspark?
# - [ ] Một số quá trình xử lý chậm hơn so với chương trình viết bằng scala
# - [ ] Sử dụng lazily evaluation nên khó triển khai khi hạ tầng có ít cluster
# - [ ] Xử lý phân tán có thể dẫn đến lỗi trong quá trình xử lý tại các máy thực thi hoặc khi reduce tổng hợp kết quả
# - [ ] Không thể triển khai các biến đổi với thư viện cơ bản python

# %% [markdown]
# **E25**. Nhận định nào là đúng về pandas Series
# - [ ] Là một pandas dataframe đặc biệt, chỉ có một cột hoặc 1 dòng
# - [ ] Là một pandas array 1 chiều
# - [ ] Chỉ nhận được các giá trị không thể sửa (Immutable)
# - [ ] Chỉ nhận được các giá trị có thể băm (hashable)

# %% [markdown]
# # F. Data visualization

# %% [markdown]
# **F01**. Error bar trên biểu đồ bar chart chứa những ý nghĩa nào?
# - [ ] Biểu diễn độ phân tán của dữ liệu xung quanh giá trị trung bình
# - [ ] Sự tin cậy của giá trị trung bình làm giá trị đại diện cho bộ dữ liệu
# - [ ] Chỉ ra khả năng có sự khác biệt giữa các bộ dữ liệu
# - [x] Tất cả đáp án trên

# %% [markdown]
# **F02**. Dữ liệu có thể trực quan hóa bằng những cách nào
# - [ ] Biểu đồ
# - [ ] Đồ thị
# - [ ] Bản đồ
# - [x] Tất cả các ý trên

# %% [markdown]
# **F03**. Đồ thị nào không phù hợp?
#
# <img src='attachment:762850c8-d6da-4e1b-a4fb-381145f05359.png' style='height:150px'>
#
# - [ ] Đồ thị dạng cột (bar)
# - [ ] Đồ thị dạng điểm (point)
# - [x] Đồ thị dạng đường (line)
# - [ ] Đồ thị nào cũng phù hợp

# %% [markdown]
# **F04**. Phương pháp tạo bảng màu như nào là tốt
# - [x] Giảm thiểu tối đa sự chồng chéo và tính không rõ ràng của màu sắc, chọn màu sắc có tính gợi ý nghĩa (như màu đỏ cho Viettel)
# - [ ] Màu nào thấy đẹp thì dùng miễn là có chú thích rõ ràng
# - [ ] Sử dụng các tông màu đẹp đã được sử dụng hiệu quả trong các bài trực quan hóa dữ liệu khác
# - [ ] Bảng màu càng nhiều mầu đa dạng thì càng có nhiều ý nghĩa.

# %% [markdown]
# **F05**. Biểu đồ nào sau đây ít phù hợp nhát để biểu diễn tổng doanh thu viễn thông cho 5 thành phố lớn trong 5 năm gần đây?
# - [ ] Bar chart
# - [ ] Line chart
# - [ ] Column chart
# - [x] Pie chart

# %% [markdown]
# **F06**. Những chữ cái trong box plot dưới đây biểu thị điều gì?
#
# <img src='attachment:cc82fc13-8341-4606-80a6-a576d1b88b76.png' style='height:300px'>
#
# - [ ] A = Mean, B = Upper Mean Quartile, C = Lower Mean Quartile, D = Inter Quartile Range, E = Minimum, and F = Outliers
# - [ ] A = Mean, B = Third Quartile, C = First Quartile, D = Inter Quartile Range, E = Minimum, and F = Outliers
# - [x] A = Median, B = Third Quartile, C = First Quartile, D = Inter Quartile Range, E = Minimum, and F = Outliers
# - [ ] A = Median, B = Third Quartile, C = Mean, D = Inter Quartile Range, E = Lower Quartile, and F = Outliers

# %% [markdown]
# **F07**. Khi cần biểu diễn nhiều trường dữ liệu timeseries cùng trên một biểu đồ, loại biểu đồ nào sau đây thích hợp nhất?
# - [x] Horizontal graph
# - [ ] Scatter plot
# - [ ] Box plot
# - [ ] Line graph

# %% [markdown]
# **F08**. Phương pháp thể hiện màu sắc khi trực quan dữ liệu như nào cho hiệu quả?
# - [x] Khi biểu diễn tính tuần tự của dữ liệu, sử dụng thang màu tuần tự tăng độ sáng, có thể cũng có tông sắc. Thông thường, các giá trị cao hơn ánh xạ tới các màu tối hơn. Sử dụng thang màu phân kỳ (diverging color scale) khi khi dữ liệu có “điểm giữa” có ý nghĩa. Sử dụng màu bão hòa cho các điểm cuối. Nên sử dụng tối thiểu màu càng tốt khoảng 3-9 màu
# - [ ] Sử dụng màu nào cũng được miễn là có chú thích rõ ràng.
# - [ ] Sử dụng màu theo xu thế, vừa mắt người thiết kế và có chú thích rõ ràng
# - [ ] Không có phương pháp nào cả, trực quan hóa dữ liệu là nghệ thuật trình diễn số liệu, càng nhiều màu càng tốt.

# %% [markdown]
# **F09**. Tập khách hàng được chia làm 3 nhóm nhỏ và cần đánh giá sự tăng trưởng của tổng số lượng khách hàng và số lượng khách hàng trên từng nhóm này qua các tháng trong năm, biểu đồ nào sau đây có thể thể hiện được mục đích trên?
# - [ ] Bubble chart
# - [ ] Scatter plots
# - [ ] Line chart
# - [x] Stacked bar chart

# %% [markdown]
# **F10**. Thông tin nào có thể còn thiếu khi biểu diễn bản đồ dưới đây:
#
# <img src='attachment:73e66e80-b22d-4967-9d96-dfa9aeede0e3.png' style='height:300px'>
# - [ ] Tiêu đề của bản đồ
# - [ ] Kích cỡ (size) của các điểm phân bố trên bản đồ
# - [ ] Filter để lựa chọn những thông tin cần thiết
# - [x] Tất cả các phương án trên

# %% [markdown]
# **F11**. Với một số dữ liệu đều dương nhưng có sự dao động lớn về giá trị (giả sử lượt truy cập vào website), dẫn đến dữ liệu sẽ được phân bố về một phía và làm cho biểu đồ khó đọc. Phương pháp xử lý ở đây là gì?
# - [ ] Sử dụng Logarithmic plot
# - [ ] Loại bỏ outlier
# - [ ] Line chart
# - [ ] Không bao gồm các đáp án trên

# %% [markdown]
# **F12**. Đối với dữ liệu liên tục hoặc timeseries, biểu đồ nào có thể thích hợp để biểu thị xu hướng dữ liệu?
# - [ ] Biểu đồ tròn (pie chart)
# - [ ] Biểu đồ dạng cột (bar chart)
# - [ ] Biểu đồ đường (line)
# - [ ] Không có phương án nào đúng

# %% [markdown]
# **F13**. Biểu đồ nào có thể biểu diễn tỷ lệ đóng góp của 5 nhóm vào tổng doanh thu hàng năm trong 5 năm gần nhất?
# - [ ] Pie chart
# - [ ] Clustered bar chart
# - [ ] Stacked column chart
# - [ ] Surface chart

# %% [markdown]
# **F14**. Phương pháp chọn kích cỡ bin (bin size) hiệu quả cho histogram là như nào?
# - [ ] Sử dụng luôn quantiles làm binsize
# - [ ] Càng nhỏ càng tốt, càng chi tiết được hành vi của mỗi nhóm theo cắt bin
# - [ ] Dựa theo cảm quan, chia không đều mỗi bin, sao cho kết quả là theo phân phối chuẩn
# - [ ] Đánh giá lọc bỏ, gom các outlier, sử dụng các phương pháp thống kê để đưa ra đề xuất số lượng bin, đánh giá lại với dữ liệu xem có phản ảnh hành vi chung của từng nhóm bin không.

# %% [markdown]
# # G. Machine Learning

# %% [markdown]
# **G01**. Quá khớp (overfit) là một hiện tượng hay gặp khi xây dựng mô hình học máy. Giải pháp nào sau đây không khắc phục được hiện tượng này?
# - [ ] Kết hợp (ensemble) nhiều mô hình
# - [ ] Bổ sung thêm dữ liệu training
# - [ ] Bổ sung thêm regularization vào mô hình
# - [x] Bổ sung thêm dữ liệu validation

# %% [markdown]
# **G02**. Cho biết hàm Focal loss cho mô hình binary classification có dạng như sau: $\text{FL}(p_t) = -\log(p_t)\,(1 - p_t)^\gamma$. So sánh với (balanced) cross entropy: $\text{CE}(p_t) = -\log⁡(p_t)$.
# Hãy cho biết Focal loss thường được sử dụng khi nào, vì sao?
# - [x] So với CE, đạo hàm của FL nhạy cảm hơn với các quan sát dễ dự báo, nên phù hợp hơn với các tập dữ liệu mất cân bằng
# - [ ] Giá trị của FL nhỏ hơn CE, và sấp xỉ bằng CE tại các cực xác suất p_t (0 và 1), nên FL phù hợp với các tập dữ liệu có outlier
# - [ ] Đạo hàm của FL nhạy cảm hơn với các quan sát dễ đự báo, nên phù hợp với các tập dữ liệu có outlier, vì outlier không tác động nhiều đến đạo hàm
# - [ ] So với CE, FL tập trung hơn vào các trường hợp khó dự báo nên phù hợp cho các tập dữ liệu mất cân bằng

# %% [markdown]
# **G03**. Khi xây dựng mô hình học máy, với bộ dữ liệu 700k quan sát. Bạn chia tập dữ liệu này thành tập train và validation với tỷ lệ 70:30 và huấn luyện trên tập train. Khi đánh giá theo phương pháp hold-out, bạn nhận thấy giá trị hàm mất mát trong quá trình validation nhỏ hơn so với giá trị hàm mất mát trong quá trình train.
# Nguyên nhân nào sau đây là một giải thích hợp lý?
# - [ ] Vì dữ liệu tập validation là unseen data, trong quá trình huấn luyện mô hình chưa từng được huấn luyện với dữ liệu này, nên giá trị hàm mất mát trên tập validation nhỏ hơn
# - [ ] Việc chia tập huấn luyện lớn hơn tập validation, dẫn đến giá trị hàm mất mát lớn hơn
# - [x] Mô hình đang áp dụng một số regularization chỉ có ảnh hưởng trong quá trình train nhưng không có ảnh hưởng trong quá trình validation (như dropout,...)
# - [ ] Phương pháp hold-out dẫn đến đánh giá không chính xác, cần thay thế phương pháp đánh giá bằng cross-validation

# %% [markdown]
# **G04**. Để mô hình học máy đạt hiệu quả cao, người ta cần tối ưu siêu tham số (hyperparameters) của mô hình. Làm sao để thực hiện được điều đó?
# - [ ] Trên miền tìm kiếm (searching space), tìm kiếm siêu tham số cho mô hình có giá trị hàm mất mát tối ưu nhỏ nhất trên tập train
# - [x] Trên miền tìm kiếm (searching space), tìm kiếm siêu tham số cho mô hình có giá trị hàm mất mát tối ưu nhỏ nhất trên tập validation
# - [ ] Trên miền tìm kiếm (searching space), tìm kiếm siêu tham số cho mô hình có giá trị hàm mất mát tối ưu nhỏ nhất trên tập test
# - [ ] Trên miền tìm kiếm (searching space), tìm kiếm siêu tham số cho mô hình có chênh lệch giá trị hàm mất mát tối ưu giữa tập train và tập validation nhỏ nhất

# %% [markdown]
# **G05**. Bạn đang xây dựng mô hình học máy để bất thường trong tiêu dùng của người dùng. Trong đó, mức độ bất thường của người dùng sẽ được đánh giá dựa trên quan sát và học hỏi hành vi của đa số người dùng, và xác định các người dùng có hành vi bất thường so với những người dùng khác.
# Đây là một bài toán gì?
# - [ ] Suppervised learning
# - [x] Unsupervised learning
# - [ ] Self learning
# - [ ] Semi-supervised learning

# %% [markdown]
# **G06**. Định lý không có bữa trưa miễn phí (No Free Lunch Theorem, Wolpert, 1996) trong học máy có ý nghĩa gì?
# - [x] Không có thuật toán học máy nào là luôn tốt hơn so với các thuật toán khác
# - [ ] Không có mô hình học máy nào có thể vượt qua năng lực con người
# - [ ] Không có bữa trưa nào là miễn phí
# - [ ] Không có mô hình học máy nào có thể học chính xác tuyệt đối dữ liệu

# %% [markdown]
# **G07**. Bạn đang xây dựng một mô hình dự đoán điểm số của sinh viên. Trong đó, các sinh viên sẽ được chấm các điểm theo tứ tự giảm dần là A, B, C, D. Các sinh viên có điểm số A sẽ được đánh giá cao hơn so với cá sinh viên có điểm B, điểm B cao hơn C,...
# Giải pháp xây dựng mô hình nào sau đây là hợp lý cho bài toán của bạn?
# - [ ] Vì đầu ra là có thứ tự, xây dựng mô hình regression với các nhãn A, B, C, D
# - [x] Xây dựng mô hình classification, với các nhãn A, B, C, D
# - [ ] Xây dựng mô hình clustering tìm kiếm cụm A, B, C, D
# - [ ] Xây dựng mô hình reinforcement learning với các state A, B, C, D

# %% [markdown]
# **G08**. TF-IDF giải quyết vấn đề gì của Bag of Word?
# - [ ] Loại bỏ các common words không đặc trưng cho văn bản
# - [ ] Nhận diện tốt hơn các common words đặc trưng cho văn bản
# - [ ] Loại bỏ các rare words không đặc trưng cho văn bản
# - [x] Nhận diện tốt hơn các rare words đặc trưng cho văn bản

# %% [markdown]
# **G09**. Nhận định nào sau đây về local learning và boostrap aggregating (bagging) là đúng?
# - [x] Khi dự đoán, bagging kết hợp kết quả dự đoán của nhiều mô hình thành phần, còn local learning thì không
# - [ ] Local learning và bagging cùng có các model thành phần học trên một phần sample của tập dữ liệu, nhưng local learning cho phép nhiều model học cùng trên 1 tập, còn bagging thì không
# - [ ] Local learning là tên gọi chung cho phương pháp chia nhỏ dữ liệu và cho nhiều mô hình học trên một phần dữ liệu. Local learning chia làm 2 nhóm lấy mẫu có hoàn lại (Bagging) và lấy mẫu không hoàn lại (Pasting)
# - [ ] Local learning không có tính khái quát trên tổng thể dữ liệu, không triển khai được trên môi trường dữ liệu lớn. Bagging khắc phục được nhược điểm này

# %% [markdown]
# **G10**. Xây dựng 3 mô hình k-NN: mô hình M1 với $k=1$, mô hình M2 với $k=2$, mô hình M3 với $k=3$.
# Thời gian training 3 mô hình lần lượt là $t_1$, $t_2$, $t_3$.
# Nhận định nào sau đây là đúng
# - [ ] $t_1 > t_2 > t_3$
# - [ ] $t_1 > t_2 = t_3$
# - [ ] $t_1 < t_2 < t_3$
# - [x] $t_1 \sim t_2 \sim t_3$

# %% [markdown]
# **G11**. Đâu là nhận định đúng về boosting model
# - [ ] Các mô hình boosting luôn cho hiệu quả tốt hơn các mô hình bagging
# - [x] Các mô hình boosting nhằm giảm bias của một mô hình có bias cao, chấp nhận việc tăng thêm của variance nhưng có thể gia tăng hiệu quả tổng thể của mô hinh
# - [ ] Các mô hình boosting cần có các weeklearner là các mô hình ổn định, hội tụ, vì vậy decision tree và các biến thể là weeklearner phù hợp duy nhất
# - [ ] Khi triển khai mô hình boosting, các mô hình sau sẽ hiệu chỉnh lại mô hình trước, mô hình sau cùng là mô hình có năng lực khái quát khóa cao nhất và được sử dụng để đưa ra dự đoán

# %% [markdown]
# **G12**. Trong số các thuật toán sau, thuật toán nào thuộc nhóm Online learning
# - [ ] C4.5 decision tree
# - [ ] Kernel PCA
# - [ ] Kmeans
# - [x] Multilayer Perceptron

# %% [markdown]
# **G13**. Nhận định nào sau đây là đúng về transfer learning?
# - [ ] Khi triển khai transfer learning, cần tìm kiếm bộ dữ liệu source domian có nhiều điểm khác biệt so với target domain để tránh overfit
# - [ ] Trong một mạng neural, các layer càng ở cuối (càng gần target) là các layer thể hiện tính khái quát cao nhất của thông tin khi truyền qua mạng. Khi triển khai transfer learning cần freeze các layer này.
# - [ ] Khi triển khai transfer learning, kết quả của các mô hình pre-trained sẽ được kết hợp cho các mô hình học máy mới theo dạng voting
# - [x] Khi triển khai transfer learning, kết quả của các mô hình pre-trained sẽ là đặc trưng cho các mô hình học máy mới

# %% [markdown]
# **G14**. Khi thực hiện bài toán xây dựng mô hình phân loại email rác, bạn xây dựng mô hình học máy Support vector machine và sử dụng AUC để đánh giá hiệu quả mô hình. Trong quá trình tối ưu tham số, bạn phân chia tập train và tập validation có tỷ lệ 70:30. Kết quả đánh giá trên 2 tập là AUC_train = 50, AUC_validation = 49.5 .
# Nhận định nào sau đây là đúng
# - [ ] Mô hình có dấu hiệu overfit, do mô hình có độ phức tạp quá lớn, cần giảm độ phức tạp của mô hình và đánh giá thêm
# - [ ] Mô hình đang hoạt động tốt.
# - [x] Mô hình có dấu hiệu underfit, cần điều chỉnh tăng độ phức tạp của mô hình và đánh giá thêm
# - [ ] Mô hình có dấu hiệu bias, do bậc tự do của mô hình quá lớn, cần giảm bậc tự do của mô hình

# %% [markdown]
# **G15**. Phương pháp áp dụng triển khai mô hình colaborative filtering được gọi là gì
# - [x] Low rank matrix factorization
# - [ ] High rank matrix factorization
# - [ ] Dense matrix factorization
# - [ ] Sparse matrix factorization

# %% [markdown]
# **G16**. Khi xây dựng mô hình học máy, người ta thường chia dữ liệu thành các tập train, validation, test. Đánh giá năng lực khai quát hóa của mô hình được thực hiện trên tập test. Dữ liệu huấn luyện trực tiếp mô hình chỉ có tập train. Vậy, vì sao không sử dụng đánh giá trên tập validation để đánh giá năng lực khái quát hóa của mô hình?
# - [ ] Dữ liệu quá lớn không thể đánh giá, cần tách thành tập test có quy mô nhỏ hơn để thực hiện đánh giá độc lập
# - [ ] Tập validation thường có dữ liệu nhỏ và không đủ để đánh giá một cách đáng tin cậy
# - [ ] Tập validation có chứa dữ liệu có tương quan với tập train cao, dẫn đến hiện tượng data leakage và trở nên không đáng tin cậy
# - [x] Việc dùng tập validation tối ưu siêu tham số có xu hướng khiến mô hình overfit với tập validation

# %% [markdown]
# **G17**. Huấn luyện một mô hình Decision tree với tập training có 1 triệu dòng mất trung bình 0.5 giờ. Nếu vẫn sử dụng mô hình và thiết bị đó huấn luyện với tập training có 5 triệu dòng thì thời gian training sẽ khoảng bao nhiêu giờ?
# - [ ] 2
# - [ ] 2.5
# - [x] 2.79
# - [ ] 2.24

# %% [markdown]
# **G18**. Khi huấn luyện một mô hình học máy nhằm phân loại thư rác, bạn nhận thấy hiện tượng AUC của tập train rất cao sấp sỉ 100%. Việc điều chỉnh độ phức tạp của mô hình không có tác dụng thay đổi hiệu quả của mô hình. Bạn đang có khả năng gặp phải hiện tượng gì?
# - [x] Data leakage
# - [ ] Overfiting
# - [ ] Underfiting
# - [ ] Mô hình hoạt động tốt

# %% [markdown]
# **G19**. Robust regression là nhánh mô hình được thiết kế nhằm khắc phục các hạn chế của các mô hình truyền thống nhạy cảm với outlier.
# Hãy đánh giá và cho biết hàm mất mát nào sau đây là thuộc robust regression?
# - [x] Huber loss
# - [ ] MSE
# - [ ] Dice loss
# - [ ] Tversky loss

# %% [markdown]
# **G20**. Bạn đang xây dựng mô hình học máy để bất thường trong tiêu dùng của người dùng. Trong đó, mức độ bất thường của người dùng sẽ được đánh giá dựa trên quan sát và học hỏi hành vi của đa số người dùng, và xác định các người dùng có hành vi bất thường so với những người dùng khác.
# Đây là một bài toán gì?
# - [ ] Suppervised learning
# - [x] Unsupervised learning
# - [ ] Self learning
# - [ ] Semi-supervised learning

# %% [markdown]
# **G21**. Trong thuật toán Bayesian optimization, để lựa chọn giá thử tiếp theo ta dựa trên điều gì?
# - [ ] Lựa chọn điểm có entropy thấp nhất trong hàm phân phối của hàm loss ước lượng
# - [ ] Lựa chọn điểm mà hàm loss ước lượng có phương sai cao nhất
# - [x] Lựa chọn điểm mà acquisition function đạt giá trị lớn nhất
# - [ ] Lựa chọn điểm có maginal likelihood của giá trị hàm loss ước lượng cao nhất

# %% [markdown]
# **G22**. Bạn đang xây dựng phân loại ngành hàng cho sản phẩm của một sàn thương mại điện tử đồng hồ. Mỗi sản phẩm có thể được phân loại vào nhiều nhóm sản phẩm, ví dụ, một chiếc đồng hồ có thể được phân là đồng hồ điện tử, đồng hồ dây da, đồng hồ mặt kính Sapphire,...
# Đây là một bài toán gì?
# - [ ] Phân loại đa lớp (multiclass classification)
# - [ ] Hồi quy đa lớp (multiclass regression)
# - [x] Phân loại đa nhãn (multilabel classification)
# - [ ] Hồi quy đa nhãn (multilabel regression)

# %% [markdown]
# **G23**. Khi xây dựng mô hình học máy có giám sát, một số đặc trưng đặc biệt bạn xác định có tương quan rất cao với nhãn, tuy nhiên chúng lại là các đặc trưng không thể xác định tại thời điểm dự đoán, chỉ xác định được trong giai đoạn training. Dẫn đến kết quả mô hình training và validation rất tốt, nhưng khi dự đoán thực tế, các đặc trưng đặc biệt kia đều bị không xác định (N/A, null, unknow) dẫn đến hiệu quả thực tế của mô hình không được cao. Hãy cho biết đây là vấn đề gì
# - [x] Data leakage
# - [ ] Overfiting
# - [ ] Data cần được clean
# - [ ] Data error

# %% [markdown]
# **G24**. Bạn sử dụng độ quan trọng hoán vị của đặc trưng (permutation feature importance) để đánh giá các feature nào là ảnh hưởng lớn tới biến phụ thuộc của một mô hình Random forest regression.
# Bạn nhận thấy 2 feature X1 và X2 có tương quan với nhau là 0.9.
# Nhận định nào sau đây là đúng?
# - [ ] Các giá trị chỉ số feature importance sẽ rất lớn
# - [x] Đặc trưng X1 nếu là quan trọng vẫn có thể có feature importance thấp
# - [ ] Các chỉ số feature importance sẽ lớn gấp đôi nếu 1 trong 2 feature là quan trọng
# - [ ] Thứ tự feature importance tính theo permutation và dựa trên impurity decrease là giống nhau

# %% [markdown]
# **G25**. Cho biết ý nghĩa của Normalised Discounted cumulative gain (nDCG) khi đánh giá hiệu quả khuyến nghị của một hệ recommendation
# - [ ] Cho biết rating của các item có gần với rating thực đến mức nào
# - [x] Cho biết sự phù hợp trong thứ tự sắp xếp item
# - [ ] Cho biết tính chính xác khi phân loại sản phẩm nên recommend với không nên recommend
# - [ ] Cho biết lợi nhuận (gain) của các sản phẩm khuyến nghị

# %% [markdown]
# **G26**. Để mô hình học máy đạt hiệu quả cao, người ta cần tối ưu siêu tham số (hyperparameters) của mô hình. Làm sao để thực hiện được điều đó?
# - [ ] Trên miền tìm kiếm (searching space), tìm kiếm siêu tham số cho mô hình có giá trị hàm mất mát tối ưu nhỏ nhất trên tập train
# - [x] Trên miền tìm kiếm (searching space), tìm kiếm siêu tham số cho mô hình có giá trị hàm mất mát tối ưu nhỏ nhất trên tập validation
# - [ ] Trên miền tìm kiếm (searching space), tìm kiếm siêu tham số cho mô hình có giá trị hàm mất mát tối ưu nhỏ nhất trên tập test
# - [ ] Trên miền tìm kiếm (searching space), tìm kiếm siêu tham số cho mô hình có chênh lệch giá trị hàm mất mát tối ưu giữa tập train và tập validation nhỏ nhất

# %% [markdown]
# **G27**. Bạn huấn luyện mô hình dự đoán điểm nghẽn mạng của hệ thống. Cho bảng confusion matrix như hình, hãy tính giá trị accuracy của mô hình
#
# ||Thực tế<br />nghẽn mạng|Thực tế<br />không nghẽn
# |:-:|:-:|:-:
# |**Dự đoán<br />nghẽn mạng**|150|50
# |**Dự đoán<br />không nghẽn**|260|758
# - [ ] 0.75
# - [ ] 0.5769
# - [x] 0.7455
# - [ ] 0.9381

# %% [markdown]
# **G28**. Chọn phương án xử lý missing rating trong ma trận ultility matrix tương ứng với thuật toán là đúng
# - [x] ALS bỏ qua các giá trị NULL
# - [ ] User-based CF bỏ qua các giá trị NULL
# - [ ] SVD bỏ qua các giá trị NULL
# - [ ] WALS bỏ qua các giá trị NULL

# %% [markdown]
# **G29**. Thực hiện ensemble theo hướng bagging k weak learners thu được mô hình A. Gọi v là trung bình sai số của các weark learner, và c là trung bình hiệp phương sai của các cặp tạo bởi sai số của các weak learner. Hàm mất mát là mean square error.
# Nhận định nào sau đây là đúng
# - [ ] Khi c = v, sai số của A thấp hơn sai số của các weak learner và giảm tuyến tính khi k tăng
# - [ ] Khi c = v, sai số của A cao hơn sai số của các weak learner và giảm phi tuyến khi k tăng
# - [x] Khi c = 0, sai số của A thấp hơn sai số của các weak learner và giảm tuyến tính khi k tăng
# - [ ] Khi c = 0, sai số của A cao hơn sai số của các weak learner và giảm phi tuyến khi k tăng

# %% [markdown]
# **G30**. Trong thuật toán k-d tree, k mang ý nghĩa gì?
# - [x] Số chiều
# - [ ] Kích thước cây
# - [ ] Độ sâu cây
# - [ ] Số lượng note

# %% [markdown]
# **G31**. Nhận định nào sau đây là đúng về LightGBM
# - [ ] LightGBM tương tự với Randomforest nhưng tối ưu hơn cho việc chạy song song trên GPU
# - [ ] LightGBM do Facebook phát triển
# - [x] LightGBM huẩn luyện cây theo leaf-wise thay vì level-wise
# - [ ] LightGBM phù hợp với các mô hình có variance cao và bias cao

# %% [markdown]
# **G32**. Trong các dạng dữ liệu sau, dạng nào phù hợp với phân cụm dựa trên thuật toán gaussian mixture model (GMM)?
# - [ ] Dạng xoắn ốc
# - [x] Dạng elip/ hình cầu
# - [ ] Dạng đan chéo
# - [ ] Dạng các cụm bao bọc lẫn nhau

# %% [markdown]
# **G33**. Nhận định nào sau đây về local learning và boostrap aggregating (bagging) là đúng?
# - [x] Khi dự đoán, bagging kết hợp kết quả dự đoán của nhiều mô hình thành phần, còn local learning thì không
# - [ ] Local learning và bagging cùng có các model thành phần học trên một phần sample của tập dữ liệu, nhưng local learning cho phép nhiều model học cùng trên 1 tập, còn bagging thì không
# - [ ] Local learning là tên gọi chung cho phương pháp chia nhỏ dữ liệu và cho nhiều mô hình học trên một phần dữ liệu. Local learning chia làm 2 nhóm lấy mẫu có hoàn lại (Bagging) và lấy mẫu không hoàn lại (Pasting)
# - [ ] Local learning không có tính khái quát trên tổng thể dữ liệu, không triển khai được trên môi trường dữ liệu lớn. Bagging khắc phục được nhược điểm này

# %% [markdown]
# **G34**. Khi phân tích khám phá dữ liệu của bộ dữ liệu ung thư, bạn phát hiện trong tập dữ liệu gồm 700k người, thì có 572 người bị ung thư. Huấn luyện mô hình này với mô hình logistics, nhãn 1 là người bị ung thư, nhãn 0 là người không bị ung thư, bạn nhận thấy hiệu quả mô hình không được cao.
# Làm sao để cải thiện hiệu quả của mô hình này?
# - [ ] Thay đổi mô hình logistics bằng một mô hình linear regression
# - [x] Vẫn huấn luyện mô hình với logistics, nhưng bổ sung class weight với nhãn 0:1 lần lượt là 0.5:10
# - [ ] Huấn luyện mô hình với hàm mất mát Huber
# - [ ] Loại bỏ một cách ngẫu nhiên một lượng quan sát có nhãn 1

# %% [markdown]
# **G35**. *Xây dựng mô hình KNN bằng thuật toán K-D tree, bạn cần tìm điểm gần nhất với 1 điểm target point. Nếu điểm tối ưu hiện thời (current best) ở nhánh trái của cây, nhận định nào sau đây là đúng?*
# - [ ] Nếu khoảng cách từ điểm tốt nhất của nhánh phải đến target point lớn khoảng cách từ current best của nhánh trái, thì toàn bộ nhánh phải bị cắt bỏ
# - [ ] Nêu khoảng cách từ current best đến target point ngắn hơn khoảng cách từ target point đến bờ phân chia thì nhánh phải bị cắt bỏ
# - [ ] Nêu khoảng cách từ current best đến target point ngắn hơn khoảng cách từ target point đến bờ phân chia thì nhánh trái bị cắt bỏ
# - [ ] Nếu khoảng cách từ điểm tốt nhất của nhánh phải đến target point lớn khoảng cách từ current best của nhánh trái, thì toàn bộ nhánh trái bị cắt bỏ

# %% [markdown]
# **G36**. Hãy phân biệt implicit và explicit rating khi thiết lập hệ thống khuyến nghị
# - [ ] Explicit rating là đánh giá do người dùng chủ động chấm điểm, implicit là do hệ thống tự động chấm điểm
# - [ ] Explicit là đánh giá dạng thích/không thích, implicit là đánh giá có thể nhiều hơn 2 giá trị nhị phân
# - [ ] Explicit là giá trị rời rạc, implicit là giá trị liên tục
# - [x] Explicit và implicit đều phản ánh mức độ thích của người dùng, explicit là người dùng có ý thức được việc thể hiện mức độ thích, implicit thì không

# %% [markdown]
# **G37**. Bạn đang thiết kế hệ thống học máy vận hành. Bộ dữ liệu quá khứ rất lớn đòi hỏi chi phí tính toán lớn và liên tục được bổ sung thêm theo thời gian.
# Làm sao để xây dựng hệ thống có thể học được toàn bộ dữ liệu quá khứ và cập nhật liên tục với dữ liệu bổ sung?
# - [ ] Xây dựng hệ thống streaming data và mô hình batch learning
# - [ ] Xây dựng hệ thống reinforcement learning
# - [x] Xây dựng hệ thống online learning
# - [ ] Không thể xây dựng

# %% [markdown]
# **G38**. Các mô hình black box và mô hình white box được hiểu như thế nào trong học máy?
# - [ ] Black box là mô hình xây dựng dựa trên thuật toán phức tạp, white box là mô hình có thuật toán đơn giản
# - [ ] Black box là mô hình không có tham số, white box là các mô hình có tham số
# - [ ] Blackbox là mô hình có hiệu quả cao, whitebox là mô hình có hiệu quả thấp
# - [x] Blackbox là mô hình khó giải thích, white box là mô hình dễ giải thích cách hoạt động của model

# %% [markdown]
# **G39**. Nhận xét nào sau đây là đúng về đánh đổi bias - variance
# - [ ] Các mô hình có bias cao thì luôn có variance cao
# - [ ] Các mô hình có bias cao thì luôn có variance thấp
# - [x] Bias và variance là 2 nguồn sai số của một mô hình dự đoán
# - [ ] Mô hình có bias thấp là dấu hiệu của underfit, độ phức tạp của model thấp

# %% [markdown]
# **G40**. Siêu tham số (hyperparameter) của một mô hình học máy được hiểu là gì?
# - [ ] Là các tham số thay đổi khi thực hiện quá trình học thông qua việc tối ưu hàm mất mát
# - [ ] Là các tham số mặc định của mô hình, được sử dụng để các thuật toán khởi tạo không gian tìm kiếm khi tối ưu hàm mất mát
# - [ ] Là các tham số quan trọng, có ảnh hưởng lớn của một thuật toán, được học và cập nhật bằng việc tối ưu hàm mất mát
# - [ ] Là các cài đặt mô hình do người xây dựng mô hình thiết lập để điều khiến hành vi mô hình học máy

# %% [markdown]
# **G41**. Nhận định nào sau đây là đúng về phương pháp cross validation (CV) khi xây dựng mô hình học máy
# - [ ] CV thường được sử dụng cho các tập dataset lớn, nhằm đánh giá chính xác hiệu quả của mô hình
# - [ ] k-fold, hold-out là các cách tiếp cận khi đánh giá mô hình theo phương pháp CV
# - [ ] Khi đánh giá CV, một điểm dữ liệu thuộc tập train của vòng đánh giá này có thể thuộc tập validation của vòng đánh giá khác
# - [ ] Out-of-bag (OOB) là một kỹ thuật đánh giá mô hình theo phương pháp CV

# %% [markdown]
# **G42**. Khi xây dựng mô hình học máy dự đoán giá nhà, bạn dự đoán rằng giá các nhà bạn đang chuẩn bị dự đoán có thể nằm ngoài phạm vi giá của các nhà trong tập dữ liệu training.
# Làm sao để thiết kế mô hình học máy dự đoán được một cách chính xác nhất giá nhà?
# - [ ] Không thể thiết kế, vì các căn nhà có giá nằm ngoài phạm vi dữ liệu training thì dữ liệu training không có tính chất đại diện, không thể dự đoán
# - [ ] Xây dựng một mô hình out-of-sample (như linear regression)
# - [ ] Xây dựng mô hình in-sample model (như random forest)
# - [ ] Xây dựng một mô hình classification

# %% [markdown]
# **G43**. Khi xây dựng mô hình học máy hồi quy, với y_pred là giá trị dự đoán, y_true là giá trị thực tế của biến phụ thuộc.
# - Gọi sai số bias của mô hình là: `bias = E[ y_pred ] - y_true`
# - gọi phương sai giá trị dự đoán của mô hình là: `variance = VAR(y_pred)`
# - và sai số bình phương bình quân mean squared error (MSE) là: `MSE = E(y_true - y_pred)^2`
#
# Hãy cho biết mối quan hệ của bias, variance với MSE
# - [ ] MSE = bias^2*variance
# - [ ] MSE = bias^2 + variance
# - [ ] MSE = bias^2 - variance
# - [ ] MSE = bias + variance^2

# %% [markdown]
# **G44**. Stopwords trong tiền xử lý dữ liệu văn bản có đặc điểm nào?
# - [ ] Tần suất xuất hiện lớn
# - [ ] Mang ý nghĩa kết thúc câu, đoạn văn, ngắt nghỉ
# - [ ] Từ có ý nghĩa đặc trưng cao, mang nhiều ý nghĩa của một nhóm lĩnh vực
# - [ ] Là các từ dài

# %% [markdown]
# **G45**. Trong bài toán phân tích sống sót (survival analysis), Censoring là vấn đề gì?
# - [ ] Là vấn đề dữ liệu bị lệch về một phía của phân phối
# - [ ] Là hiện tượng đa số quan sát có thời gian tồn tại thấp
# - [ ] Là vấn đề một số quan sát không biết chính xác thời gian survival
# - [ ] Là vấn đề tương quan của sống sót và chết

# %% [markdown]
# **G46**. Nhận xét nào sau đây là hợp lý khi nói về hình vẽ?
#
# <img src='attachment:e7fe8ea2-8d80-4445-b3c7-4d6f523b556a.png' style='height:200px'>
#
# - [ ] Đường cam biểu thị Gini impurity, đường xanh thể hiện entropy
# - [ ] Đường cam biểu thị entropy, đường xanh thể hiện Gini impurity
# - [ ] Cả 2 đường đều thể hiện entropy
# - [ ] Cả 2 đường đều là entropy hoặc gini, tùy thuộc tham số mô hình

# %% [markdown]
# **G47**. Mô hình Decision tree và tree-based model bị ảnh hưởng khi dữ liệu có outlier như thế nào?
# - [ ] Các mô hình sử dụng ID3 ít nhạy cảm với outlier do rẽ nhánh theo biến categorical, các mô hình CART nhạy cảm với outlier do phải xác định ngưỡng phân chia trong từng feature
# - [ ] Các mô hình decision tree sử dụng ID3 và các mô hình bagging từ tree-based ít nhạy cảm với outlier. Các mô hình CART hoặc boosting nhạy cảm với outlier
# - [ ] Tất cả các mô hình đều nhạy cảm với outlier do mô hình dễ bị overfit
# - [ ] Mô hình ít bị ảnh hưởng do outlier gây ít ảnh hưởng lên ngưỡng rẽ nhánh của cây

# %% [markdown]
# **G48**. Metrics nào sau đây không thể sử dụng để tính khoảng cách khi huấn luyện mô hình KNN?
# - [ ] Chebyshev distance
# - [ ] Manhattan distance
# - [ ] Minkowski distance
# - [ ] Tất cả đều có thể sử dụng

# %% [markdown]
# **G49**. Huấn luyện một mô hình Naive Bayes cho một bộ dữ liệu có n feauture và 1 label, trong đó các feature và label đều dạng biến nhị phân. Số lượng tham số cần để biểu diễn mô hình NB là?
# - [ ] n
# - [ ] 2n+1
# - [ ] 2n
# - [ ] n+1

# %% [markdown]
# **G50**. Bạn huấn luyện 3 mô hình với độ chính xác đều là 60% và thực hiện ensemble chúng. Trong trường hợp tối ưu nhất, độ chính xác cao nhất model ensemble có thể đạt được là bao nhiêu?
# - [ ] 1
# - [ ] 0.78
# - [ ] 0.8
# - [ ] 0.5

# %% [markdown]
# **G51**. So sánh 2 chiến thuật tìm kiếm tham số tối ưu Randomized search và Grid search?
# - [ ] Grid search có tốc độ nhanh hơn
# - [ ] Randomzied search phù hợp hơn khi có quá nhiều trường hợp cần thử
# - [ ] Grid search tìm kiếm tham số tối ưu, trong khi randomized search tìm kiếm ngẫu nhiên
# - [ ] Grid search duyệt tuần tự, randomized search duyệt ngẫu nhiên

# %% [markdown]
# **G52**. Trong thuật toán Upper Confidence Bound (UCB), mô hình sẽ lựa chọn phương án nào có:
# - [ ] Giá tối đa từng đạt được trong lịch sử là lớn nhất
# - [ ] Giá trị trung bình của các lựa chọn trong lịch sử là lớn nhất
# - [ ] Giá trị kỳ vọng của lợi nhuận trong tương lai là lớn nhất
# - [ ] Ngưỡng cận trên của khoảng tin cậy lớn nhất

# %% [markdown]
# **G53**. Nhận định nào sau đây là đúng?
# - [ ] L1 (Lasso) và L2 (Ridge) regularization đều làm giảm độ lớn của bộ tham số giúp mô hình tránh overfiting
# - [ ] Khi tăng cường độ của L1 (Lasso) regularization, giá trị tham số giảm dần nhưng không bằng 0
# - [ ] L2 (Ridge) có tác động mạnh hơn so với L1 (Lasso) trong việc chống overfitting
# - [ ] L1 (Lasso) có khả năng hỗ trợ tốt cho mô hình khi hoạt động với dữ liệu có outlier

# %% [markdown]
# **G54**. Ví dụ nào sau đây sử dụng hướng tiếp cận Data-centric tối ưu hiệu quả của model?
# - [ ] Thay đổi bước tiền xử lý dữ liệu và normalised thay vì tối ưu tham số mô hình
# - [ ] Thu thập thêm dữ liệu của nhãn có độ chính xác thấp
# - [ ] Thay đổi đầu ra để chọn lựa nhãn khác phù hợp hơn
# - [ ] Xây dựng mô hình online-learning để mô hình có thể học được với dữ liệu bổ sung liên tục

# %% [markdown]
# **G55**. Trong trường hợp nào sau đây, việc sử dụng mô hình colaborative filtering có thể đạt được hiệu quả?
# - [ ] Bạn crawl dữ liệu bài báo mình cần từ một website, và muốn xây dựng mô hình khuyến nghị các bài viết mình muốn đọc
# - [ ] Bạn cần xây dựng mô hình khuyến nghị sản phẩm handmade, trong đó mỗi sản phẩm đều khác nhau và bán 1 lần cho 1 khách hàng.
# - [ ] Bạn cần xây dựng mô hình tối ưu ghép cặp người phù hợp chat chit/hẹn hò
# - [ ] Bạn muốn xây dựng mô hình dự đoán giá lãi suất ngân hàng nào tốt nhất trong tháng sau

# %% [markdown]
# # H. Deep Learning

# %% [markdown]
# **H01**. Cho mạng fully connected như hình trên, các note đều có bias. Hãy cho biết số lượng tham số có thể huấn luyện (trainable parameters) của mô hình
#
# <img src='attachment:eb54a823-42e6-464c-935d-d09212d431d5.png' style='height:250px'>
#
# - [ ] 33792
# - [ ] 25344
# - [ ] 25480
# - [x] 33928

# %% [markdown]
# **H02**. Đâu là là giải pháp để hạn chế hiện tượng gradient vanishing trong một mạng Neural networks?
# - [ ] Tăng số lượng note trên mỗi layer
# - [x] Thay đổi khởi tạo tham số của mạng phù hợp
# - [ ] Giảm số lượng note trên mỗi layer
# - [ ] Thay đổi hàm kích hoạt của layer cuối cùng

# %% [markdown]
# **H03**. Nhận định nào sau đây là đúng về mạng AutoEncoder?
# - [x] Cấu trúc decoder trong AutoEncoder sẽ không cần sử dụng nữa sau khi hoàn tất huấn luyện
# - [ ] AutoEncoder là mô hình cần có nhãn để hoạt động
# - [ ] AutoEncoder sử dụng SGD là optimizer tối ưu hàm mất mát
# - [ ] AutoEncoder giúp tự động hóa việc huấn luyện mô hình học sâu

# %% [markdown]
# **H04**. Trong quá trình prediction (quá trình infer kết quả dự đoán), layer BatchNormalization sẽ thực hiện như thế nào?
# - [ ] Tính mean và stdev của mỗi batch dự đoán và normalise
# - [ ] Tính mean và stdev của toàn bộ tập test và normalise
# - [x] Tính mean và stdev của bộ training và normalise bộ test
# - [ ] Không normalise dữ liệu test

# %% [markdown]
# **H05**. Cho mô hình với 3 input $x, y, z$ có giá trị lần lượt $-2, 5, -4$. $q$ và $f$ xác định bởi: $q = x+y$ và $f = q*z$
# Tính đạo hàm riêng của F lần lượt theo $x, y, z$
#
# <img src='attachment:3e2e7d10-e4f8-4258-951d-0b9c0f208451.png' style='height:150px'>
#
# - [ ] $(-3,4,4)$
# - [ ] $(4,4,3)$
# - [x] $(-4,-4,3)$
# - [ ] $(3,-4,-4)$

# %% [markdown]
# **H06**. Đâu là một vấn đề của mạng học sâu khi huẩn luyện với hàm kích hoạt ReLU
# - [ ] Tính đạo hàm khó khăn với các giá trị âm
# - [x] Một số neuron có thể trở nên bất hoạt, luôn trả về 0
# - [ ] Nếu khởi tạo tham số đều nhỏ hơn 0 thì mạng sẽ không thể học được
# - [ ] Không thể sử dụng cho layer cuối cùng

# %% [markdown]
# **H07**. Chức năng của momentum khi tối ưu hàm loss nào sau đây là đúng
# - [x] Tăng tốc hội tụ của quá trình tối ưu
# - [ ] Hạn chế sự bùng nổ đạo hàm
# - [ ] Vượt qua các điểm tĩnh (saddle point)
# - [ ] Duy trì ổn định cho tốc độ học (learning rate)

# %% [markdown]
# **H08**. Dropout trong Neural Network có hiệu lực tương tự như phương pháp nào sau đây?
# - [ ] Boosting
# - [x] Bagging
# - [ ] Stacking
# - [ ] Không phương pháp nào

# %% [markdown]
# **H09**. Mạng CNN có kiến trúc như sau:
#
# $$\text{Input}(28x28) \Rightarrow \text{Conv2D} (\text{filters}=2, 3x3, \text{strides}=1, \text{pading} = \text{'same'}) => \text{Flatten} => \text{sigmoid}$$
#
# Số lượng tham số của mô hình là?
# (các note đều có bias)
# - [ ] 1625
# - [ ] 795
# - [x] 1589
# - [ ] 1373

# %% [markdown]
# **H10**. Bạn có một bộ dữ liệu tài chính, có tính chất timeseries. Mô hình nào sau đây không phù hợp để sử dụng huấn luyện nhiệm vụ này?
# - [x] PCA
# - [ ] RNN
# - [ ] CNN
# - [ ] Cả CNN và PCA

# %% [markdown]
# **H11**. Đâu là thách thức cho thuật toán deep learning?
# - [ ] Đặc thù dữ liệu
# - [ ] Giao tiếp GPU và CPU
# - [ ] Dung lượng bộ nhớ của GPU
# - [x] Tất cả ý trên

# %% [markdown]
# **H12**. Nhận định nào sau đây là đúng?
# - [ ] Mạng NN có thể tự học việc bỏ qua outlier, nên không cần thiết loại bỏ outlier
# - [ ] Luôn cần thêm activation function, nếu không mạng không thể học
# - [x] Mạng sâu hơn xu hướng có khả năng khái quát hóa tốt hơn
# - [ ] Mạng NN không cần normalised dữ liệu

# %% [markdown]
# **H13**. Thuật toán nào sau đây là feature learning
# - [x] CNN
# - [ ] SVM
# - [ ] Logistics
# - [ ] RandomForest

# %% [markdown]
# **H14**. Nhận định nào sau đây là đúng?
# - [ ] Newton's method sử dụng second order differentiation, AdaGrad sử dụng first order differentiation
# - [x] Newton's method sử dụng first order differentiation, AdaGrad sử dụng second order differentiation
# - [ ] Newton's method và AdaGrad đều sử dụng first order differentiation
# - [ ] Newton's method và AdaGrad đều sử dụng second order differentiation

# %% [markdown]
# **H15**. Phương pháp nào sau đây có thể làm giảm overfitting trên một mạng Neural network
# - [ ] Thay đổi hàm kích hoạt
# - [x] Bổ sung thêm dữ liệu
# - [ ] Tăng số lượng note ở hidden layer
# - [ ] Thay đổi khởi tạo tham số

# %% [markdown]
# **H16**. Cho đồ thị tính toán như hình.
# Với các giá trị (a, b) = (1, 5).
# Tính đạo hàm riêng của e theo b
#
# <img src='attachment:c405515b-79de-48f7-810f-55cc91efa2bc.png' style='height:150px'>
#
# - [ ] 6
# - [ ] 2
# - [ ] 7
# - [ ] 12

# %% [markdown]
# **H17**. Max-norm regularization là một kỹ thuật sử dụng trong mạng neural nets để chống overfitting bằng cách giới hạn norm bậc 2 của bộ tham số mô hình. Nhận định nào sau đây là đúng?
# - [ ] Max-norm cộng vào hàm loss giá trị bộ weights => mô hình có xu hướng chọn bộ weights có giá trị nhỏ hơn
# - [ ] Max-norm không tác động vào hàm loss, mà chỉ tác động bộ weights sau khi mô hình hoàn tất huấn luyện
# - [ ] Max-norm giới hạn giá trị tối đa của một tham số, trong quá trình huấn luyện mỗi khi giá trị tham số vượt quá giá trị tối đa thì sẽ bị đặt lại về ngưỡng tối đa
# - [ ] Max-norm lựa chọn các giá trị bộ trọng số bằng cách lấy giá trị lớn nhất mà chúng đạt được trong quá trình training

# %% [markdown]
# **H18**. Khi huấn luyện mô hình với stochastic gradient descent, nhận định nào sau đây là đúng?
# - [ ] Mô hình hoạt động tốt nhất với khi bộ dữ liệu là iid
# - [ ] Không cần shuffle dữ liệu vì toàn bộ epoch sẽ được đưa vào mô hình và cộng vào gradient
# - [ ] Không cần huấn luyện nhiều epoch vì chỉ cần 1 epoch mô hình đã quan sát được tất cả bộ dữ liệu
# - [ ] Mô hình luôn cần Batchnormalization layer nếu không các giá trị sau mỗi layer trở nên quá lớn và không thể hội tụ

# %% [markdown]
# **H19**. Trong quá trình prediction (quá trình infer kết quả dự đoán), layer Dropout sẽ thực hiện như thế nào?
# - [ ] Ngẫu nhiên loại bỏ đi một số lượng node trong mạng theo tỷ lệ được cấu hình
# - [ ] Giữ nguyên trạng thái bật-tắt node cuối cùng khi kết thúc quá trình training
# - [ ] Giữ trạng thái bật cho tất cả các node
# - [ ] Giữ trạng thái bật cho tất cả các node nhưng chia giá trị bộ weight sao cho tổng bộ weight trong quá trình train và infer là giống nhau

# %% [markdown]
# **H20**. Bạn thiết kế một mạng NN 2 lớp như hình, tất cả hàm kích hoạt là sigmoid và bạn chọn SGD là optimizer. Khởi tạo giá trị tham số, bias của mô hình là 0, thực hiện fowart propagate giá trị của X vào. Giá trị đầu ra y khi đó bằng bao nhiêu?
#
# <img src='attachment:a64cf2ac-6de4-46d7-bb52-7a17d81ac592.png' style='height:150px'>
#
# - [ ] -1
# - [ ] 0
# - [ ] 0.5
# - [ ] 1

# %% [markdown]
# **H21**. Mạng CNN với các thông số như hình. Hình ảnh đầu vào có kích thước (nH, nW , nC) = (10, 10, 1), sử năm filter với kích thước (4x4) padding "valid" và stride (2, 2). Output của mạng này có kích thước (nH, nW , nc) lần lượt bằng bao nhiêu?
#
# <img src='attachment:91de2746-385b-4c52-a1f9-046dd76ef071.png' style='height:100px'>
#
# - [ ] (5, 5, 4)
# - [ ] (4, 4, 4)
# - [ ] (5, 5, 5)
# - [ ] (4, 4, 5)

# %% [markdown]
# **H22**. Vì sao khi cộng vào một noise nhỏ vào ảnh để tạo ra một mẫu đối nghịch (adversarial example), dù giá trị của noise nhỏ nhưng lại có thể tạo ra những thay đổi lớn trong kết quả dự đoán?
# - [ ] Vì mạng NN thường nhạy cảm với các giá trị nhỏ, đặc biệt do hàm relu thường được sử dụng, khi thêm một giá trị nhỏ có thể thay đổi dấu và kích hoạt hàm
# - [ ] Vì số chiều của ảnh thường lớn, nên khi mạng tổng hợp fowart propagation có thể cộng dồn các giá trị nhỏ của noise để tạo thành một thay đổi lớn
# - [ ] Do mạng NN thường có cách batch normalization layer, khi normalise sẽ làm tăng giá trị của các noise nhỏ
# - [ ] Do mạng NN không có batch normalization sẽ không giới hạn giá trị đầu ra của layer, khiến layer có thể tăng lên đến ngưỡng gây thay đổi dự đoán

# %% [markdown]
# **H23**. Nhận xét nào sau đây là đúng, với điều kiện learning rate là tối ưu?
# - [ ] Khi hàm mất mát là hàm lồi, Gradient descent (GD) đảm bảo tối ưu hội tụ điến nghiệm toàn cục (global), trong khi Stochastic gradient descent ( SGD) không đảm bảo được điều đó
# - [ ] SGD luôn đảm bảo quá trình tối ưu nhanh và hội tụ đến nghiệm tối ưu toàn cục
# - [ ] Mini batch GD luôn đảm bảo quá trình tối ưu nhanh và hội tụ đến nghiệm tối ưu toàn cục
# - [ ] Khi hàm mất mát là hàm lồi, Gradient descent và SGD đảm bảo hội tụ điến nghiệm toàn cục (global)

# %% [markdown]
# **H24**. Xây dựng một mạng Variational Auto encoder gồm 3 layer: layer input I, hidden layer H và ouput layer O, nhận định nào sau đây là đúng?
# - [ ] Số node của H lớn hơn số node của I
# - [ ] Số node của H có thể lớn hơn hoặc nhỏ hơn số node của I
# - [ ] Số node của O lớn hơn số node của I
# - [ ] Số node của I lớn hơn số node của H

# %% [markdown]
# **H25**. Nhận định nào là đúng về tensorflow?
# - [ ] Tensorflow 2.0 không còn sử dụng graph computation
# - [ ] Tensorflow 2.0 không còn sử dụng tf session
# - [ ] Tensorflow 2.0 không còn sử dụng tensor
# - [ ] Tensorflow 2.0 không còn sử dụng functional API

# %% [markdown]
# **H26**. Đâu là ưu điểm của LSTM so với Vanilla RNN?
# - [ ] Khắc phục được hiện tượng gradient vanishing
# - [ ] Khắc phục được hiện tượng gradient exploding
# - [ ] Có khả năng ghi nhớ thông tin chuỗi dài hơn
# - [ ] Có khả năng chống overfitting tốt hơn

# %% [markdown]
# # I. Big Data

# %% [markdown]
# **I01**. Trên Spark UI, khi các job đang thực thi, bạn nhìn thấy có phần màu xanh nhạt bên cạnh màu xanh đậm. Ý nghĩa của phần xanh nhạt này chỉ gì?
#
# <img src='attachment:91752725-3a89-4b82-8feb-023ba0c3df61.png' style='height:150px'>
#
# - [x] Các task đang thực hiện
# - [ ] Các job ETL đang thực hiện
# - [ ] Các relation ETL đang thực hiện
# - [ ] Các step ETL đang thực hiện

# %% [markdown]
# **I02**. Một block dữ liệu lưu trên HDFS, với block size mặc định là 128MB, replication = 3, dữ liệu thực tế đã lưu vào block này là 50MB. Hỏi, dung lượng bộ nhớ vật lý thực tế dùng để lưu block dữ liệu này là bao nhiêu?
# - [ ] 150
# - [x] 384
# - [ ] 267
# - [ ] 50

# %% [markdown]
# **I03**. Trong cơ chế MapReduce, quá trình Map stage có chức năng là gì
# - [ ] Chia nhỏ dữ liệu và lưu trữ phân tán
# - [ ] Ghép các dữ liệu theo cơ chế key - function, tìm kiếm các dữ liệu thỏa mãn điều kiện và áp dụng function lên chúng
# - [ ] Là giai đoạn lưu trữ dữ liệu
# - [x] Chia nhỏ dữ liệu và thực thi các phép biến đổi trên các phần dữ liệu đã chia

# %% [markdown]
# **I04**. Bốn đối tượng chính của dữ liệu quan hệ là?
# - [x] form, table, query, report
# - [ ] form, table, database, query, report
# - [ ] form, sort, table, query
# - [ ] form, column, row, report

# %% [markdown]
# **I05**. Đâu là nhận định đúng về cơ chế cache và checkpoint (trong Spark)?
# - [ ] Checkpoint sẽ bị hủy sau khi kết thúc phiên làm việc, còn cache thì không
# - [ ] Checkpoint được dùng để lưu trữ dữ liệu nhỏ, cache được sử dụng để lưu trữ dữ liệu lớn
# - [x] Cache có thể lưu vào memory hoặc disk, còn checkpoint chỉ có thể lưu vào disk
# - [ ] Checkpoint có thể lưu trữ quá trình sinh dữ liệu (DAG), cache thì không

# %% [markdown]
# **I06**. Trong thuật toán Rack Awareness của Hadoop, các dữ liệu sẽ được lưu trữ như thế nào?
# - [ ] Cố gắng lưu trữ các replica vào 1 Rack để tăng tốc độ network
# - [ ] Cố gắng phân mảnh nhất có thể replica vào các Rack khác nhau
# - [ ] Đặt các replica vào chung 1 datanote
# - [x] Đặt không quá 2 replica trên cùng một Rack

# %% [markdown]
# **I07**. Nhận định nào sau đây là đúng về Spark
# - [ ] Là framework được xây dựng để lưu trữ dữ liệu lớn
# - [ ] Được viết bằng Java và chạy trên JVM (java virtual machine)
# - [x] Có thể chạy trên máy local
# - [ ] Là công nghệ được phát triển để tận dụng tài nguyên GPU

# %% [markdown]
# **I08**. Tính chất nào sau đây là đúng về RDD
# - [ ] RDD là bộ dữ liệu phân vùng tập trung
# - [x] RDD là bộ sưu tập phân vùng dữ liệu bất biến
# - [ ] Thực hiện lazy evaluation, thực hiện load và biến đổi dữ liệu ngay khi tạo dựng RDD
# - [ ] RDD có thể mất mát trong quá trình thực thi và không thể khôi phục lại

# %% [markdown]
# **I09**. Đặc điểm nào là đúng khi tổ chức dữ liệu theo chuẩn BCNF (Boyce–Codd normal form)
# - [ ] Tối ưu hóa tốc độ tính toán và truy xuất dữ liệu
# - [ ] Tối ưu hóa lưu trữ tiết kiệm bộ nhớ, tránh lưu trữ dữ liệu thừa
# - [ ] Tránh mất đồng bộ dữ liệu, mất mát dữ liệu
# - [ ] Tối ưu tương tác và hiệu năng năng sử dụng cho các hạ tầng phân tích

# %% [markdown]
# **I10**. HDFS lưu trữ theo mô hình master (namenode) - slave (datanode), nhận định nào về chức năng của 2 cấu phần này dưới đây là không đúng?
# - [ ] Master là một datanote đặc biệt với khả năng giao tiếp với các datanote khác
# - [ ] Master lưu trữ metadata, slave lưu trữ dữ liệu thực tế
# - [ ] Master assign lệnh thực thi cho slave
# - [ ] Master lưu trữ các thông tin về địa chỉ, số block, cấu hình của slave

# %% [markdown]
# **I11**. Thông thường FIFO schedule là chế độ lập lịch mặc định của Spark. Khi cấu hình lập lịch FIFO schedule, các task sẽ được Spark xử lý như thế nào
# - [ ] Các task gọi trước được thực thi trước nhưng không sử dụng toàn bộ worker, các task sau sẽ được thực thi ngay khi task trước đang thực thi
# - [ ] Spark tự tối ưu để các task nhẹ vẫn được thực thi song song trong khi các task nặng đang thực thi
# - [ ] Các task gọi sau sẽ được thực thi trước
# - [ ] Các task gọi trước sẽ được thực thi trước

# %% [markdown]
# # K. Mathematics

# %% [markdown]
# **K01**. Cho vector v = [0, 1, 2, 2], giá trị norm bậc 1 của vector trên là bao nhiêu?
# - [x] 5
# - [ ] 9
# - [ ] -9
# - [ ] 12

# %% [markdown]
# **K02**. Cho ma trận A có các eigenvector hợp thành ma trận V, tương ứng với mỗi eigenvector là một eigenvalue hợp thành vector lambda.
# Phân tích nào trong hình trên là phân tích ma trận A đúng?
# - [x] $A=V\cdot\text{diag}(\lambda)\cdot V^{-1}$
# - [ ] $A=V^{-1}\cdot\text{diag}{}(\lambda)\cdot V$
# - [ ] $A=\lambda^{-1}\cdot V\cdot\lambda$
# - [ ] $A=V^{-1}\cdot V\cdot\text{diag}(\lambda)$

# %% [markdown]
# **K03**. Nhận định nào sau đây là đúng về khai triển Taylor
# - [ ] Ứng dụng tính tích phân và xác định nguyên hàm
# - [ ] Xác định tính liên tục của hàm số
# - [x] Được ứng dụng tính giới hạn hàm số
# - [ ] Sử dụng các hàm tuyến tính để xấp sỉ mọi dạng hàm phức tạp hơn

# %% [markdown]
# **K04**. Trong cơ sở R2 có 2 cơ sở E = {(1, 1), (2, 3)} và F = {(1, -1), (1, 0)}. Biết rằng tọa độ của X trong cơ sở E là (-1, 2). Tìm tọa độ của X trong cơ sở F
# - [ ] (8, -5)
# - [ ] (-2, 1)
# - [ ] (1, 2)
# - [x] (-5, 8)

# %% [markdown]
# **K05**. Trong không gian vector V cho họ M = {x, y, z, t} có hạng bằng 2. Nhận định nào sau đây luôn đúng
# - [ ] M sinh ra không gian 3 chiều
# - [ ] {2x} không là tổ hợp tuyến tính của {x, y}
# - [ ] {x, y} độc lập tuyến tính
# - [x] {x, y, x+z} phụ thuộc tuyến tính

# %% [markdown]
# **K06**. Khi hàm loss có dạng tuyến tính (dạng đường thẳng hoặc mặt phẳng).
# Nhận định nào sau đây là đúng về ma trận Jacobian và ma trận Hessian
# - [ ] Ma trận Jacobian bao gồm các giá trị đều lớn hơn 0, ma trận Hessian bao gồm các giá trị đều nhỏ hơn 0
# - [x] Ma trận Jacobian bao gồm các giá trị đều bằng 0, ma trận Hessian bao gồm các giá trị đều bằng 0
# - [ ] Ma trận Jacobian bao gồm các giá trị đều nhỏ hơn 0, ma trận Hessian bao gồm các giá trị đều nhỏ hơn 0
# - [ ] Ma trận Jacobian bao gồm các giá trị đều bằng 0, ma trận Hessian bao gồm các giá trị đều lớn hơn 0

# %% [markdown]
# **K07**. First Order Gradient descent sẽ không phù hợp triển khai khi hàm loss có hình dạng nào trong số các dạng như hình
#
# <img src='attachment:3cbf2c03-90b4-4c3c-9476-731ff55ad3d7.png' style='height:200px'>
#
# - [ ] (A)
# - [x] (B)
# - [ ] (C)
# - [ ] Không hình nào (đều phù hợp)

# %% [markdown]
# **K08**. Phép logic nào sau đây là đúng
# - [ ] A XOR B = (A AND NOT B) OR (B AND NOT A)
# - [ ] A XOR B = (A OR B) AND (B OR NOT A)
# - [ ] A XOR B = (NOT A AND B) OR (NOT A OR B)
# - [ ] A XOR B = (NOT A AND B) AND B

# %% [markdown]
# **K09**. Hình trên biểu thị phép chiếu của một vật lên mặt phẳng. Bóng của vật tạo bởi các tia sáng mặt trời song song với nhau, đại diện bởi vector s = (s1, s2, s3) trong hệ quy chiếu (e1, e2, e3).
# Một điểm trong không gian 3 chiều được biểu diễn bằng vector r, bóng của vật này trên mặt đất được biểu diễn bằng vector r', khi đó r' = r + lambda*s. Hệ số lamba bằng bao nhiêu?
#
# <img src='attachment:9e738d4a-acd1-4ccd-8ad6-401d3607ed2b.png' style='height:300px'>
#
# - [ ] -1
# - [ ] 1
# - [ ] -e3/s3
# - [ ] e3/s3

# %% [markdown]
# **K10**. Cho ma trận A cấp n với n>=2, nhận xét nào sau đây là đúng
# - [ ] det(3A) = 3 det(A)
# - [ ] det(3A) = -3 det(A)
# - [ ] Nếu n chẵn, det(A)*det(-A) >= 0
# - [ ] Nếu det(A) = 0, các vector của A là độc lập tuyến tính

# %% [markdown]
# **K11**. Phương pháp Newton-Raphson sử dụng để tìm nghiệm xấp sỉ của một phương trình. Một điểm x0 được khởi tạo ngẫu nhiên, sau đó tính đạo hàm f'(x0) và di chuyển đến điểm x1. Tiếp tục tính x2 từ x1 cho đến khi hội tụ đến nghiệm của phương trình. Công thức xác định x1 từ x0 nào sau đây là hợp lý?
#
# <img src='attachment:d30730aa-2db9-4694-9eb5-3047d60f68ad.png' style='height:250px'>
#
# - [ ] x1 = x0 - f'(x0)/f(x0)
# - [ ] x1 = x0 - f(x0)/f'(x0)
# - [ ] x1 = x0 + f(x0)/f'(x0)
# - [ ] x1 = x0 + f'(x0)/f(x0)
