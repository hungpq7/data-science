# %% [markdown]
# # 1. Working with operating system

# %% [markdown]
# ## 1.1. Directory
# The absolute path begins from the root folder. The relative path begins from the working folder.

# %%
# absolute path
'E:/Documents/Data Science/Python/Notes/data/anscombe.xlsx'
# Out:
# 'E:/Documents/Data Science/Python/Notes/data/anscombe.xlsx'

# %%
# relative path
'data/anscombe.xlsx'
# Out:
# 'data/anscombe.xlsx'

# %%
# the parent folder
'..'
# Out:
# '..'

# %% [markdown]
# ## 1.2. Opearting system

# %%
import os
from sspipe import p as f, px as p

# %% [markdown]
# The `os.listdir` function returns all files and folder in the given folder. If no folders was passed, it takes the current folder as default.

# %%
os.listdir('image')
# Out:
# ['confusion_matrix.png',
#  'cross_validation.png',
#  'draft.pptx',
#  'matplotlib_color_names.png',
#  'svm_kernel.png',
#  'goodness_of_fit.png',
#  'mean_shift.gif',
#  'dbscan.gif',
#  'svm_soft.png',
#  'confusion_matrix_binary.png',
#  'svm_hard.png']

# %%
sorted(os.listdir())
# Out:
# ['.DS_Store',
#  '.git',
#  '.ipynb_checkpoints',
#  '01. [Python] Basic Concepts.ipynb',
#  '02. [Python] Classes.ipynb',
#  '03. [Python] Data Structures.ipynb',
#  '04. [Python] Objects and Functions.ipynb',
#  '05. [Python] External Sources.ipynb',
#  '07. [NumPy] Arrays.ipynb',
#  '08. [Matplotlib] Graph Construction.ipynb',
#  '09. [NumPy] Linear Algebra.ipynb',
#  '10. [NumPy] Probability.ipynb',
#  '11. [NumPy] Statistics.ipynb',
#  '12. [Scipy] Hypothesis Testing.ipynb',
#  '13. [Pandas] Data Exploratory.ipynb',
#  '14. [Pandas] Data Cleaning.ipynb',
#  '15. [Pandas] Data Transformation.ipynb',
#  '16. [Pandas] Time Series Techniques.ipynb',
#  '17. [PySpark] Data Exploratory.ipynb',
#  '18. [PySpark] Data Cleaning.ipynb',
#  '19. [PySpark] Data Transformation.ipynb',
#  '20. [Seaborn] Data Visualization.ipynb',
#  '21. [Plotly] Interactive Visualization.ipynb',
#  '22. [Scikit-learn] Machine Learning.ipynb',
#  '23. [Scikit-learn] Feature Engineering.ipynb',
#  '25. [Scikit-learn] Clustering.ipynb',
#  '26. [Scikit-learn] Classification.ipynb',
#  '27. [Scikit-learn] Regression.ipynb',
#  '28. [Scikit-learn] Ensemble Learning.ipynb',
#  '32. [PySpark] Machine Learning.ipynb',
#  '[working] 06. [BeautifulSoup] Web Scraping.ipynb',
#  '[working] 24. [Scikit-learn] Dimensionality Reduction.ipynb',
#  '[working] 29. [Scikit-learn] Hyperparameters Optimization.ipynb',
#  '[working] 30. [Scikit-learn] Recommendation.ipynb',
#  '[working] 31. [Sciki-learn] Anomaly Detection.ipynb',
#  '[working] 33. [NLTK] Text Mining.ipynb',
#  '[working] 34. [TensorFlow] Deep Learning.ipynb',
#  '[working] 35. [PyTorch] Deep Learning.ipynb',
#  'data',
#  'dataset',
#  'image',
#  'readme.md',
#  'utilities']

# %%
os.listdir('..')
# Out:
# ['Google_S2T.ipynb',
#  '.DS_Store',
#  'Python',
#  'Untitled.ipynb',
#  'ner_solution.ipynb',
#  'Projects',
#  'Project Euler.ipynb',
#  'R',
#  'Others',
#  'AI Academy']

# %%
# automatically creat path using suitable slashes
os.path.join('data', 'anscombe.xlsx')
# Out:
# 'data/anscombe.xlsx'

# %%
# convert a relative path to the absolute path
os.path.abspath('data')
# Out:
# '/Users/hungpq/Documents/Data Science/Jupyter/Python/data'

# %%
# check whether a path exists
os.path.isdir(r'data/anaconda')
# Out:
# False

# %% [markdown]
# # 2. Connecting to SQL

# %% [markdown]
# ## 2.1. SQL Server
# The `pyodbc` library is used to connect to SQL Server.

# %%
import pandas as pd
import pyodbc

# %% [markdown]
# #### Connecting
# For local database, use a trusted connection. Otherwise, provide username and password.

# %%
# local database information
driver = 'SQL Server Native Client 11.0'
server = ''
database = ''

# connect
connect = pyodbc.connect(
    f'Driver={{{driver}}};'
    f'Server={server};'
    f'Database={database};'
    f'Trusted_Connection=yes;'
)
cursor = connect.cursor()

# %%
# database with username and password
driver = 'SQL Server'
server = '116.118.119.204,8433'
database = 'PMS_CON'
username = 'aivn_dbuser'
password = 'ai@lgp2020'

# connect
connect = pyodbc.connect(
    f'Driver={{{driver}}};'
    f'Server={server};'
    f'Database={database};'
    f'UID={username};'
    f'PWD={password};'
)
cursor = connect.cursor()

# %% [markdown]
# #### Listing all tables

# %%
cursor.execute('''
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'dbo'
''')

[table[0] for table in cursor.fetchall()]

# %% [markdown]
# #### Running a query

# %%
query = '''
SELECT TOP 5 *
FROM PROJECT_BUDGET_ADJ
'''

pd.read_sql_query(query, connect)

# %% [markdown]
# #### Reading an entire table

# %%
table = ''

pd.read_sql_query(f'SELECT * FROM {table}', connect)

# %% [markdown]
# ## 2. Postgre SQL
# The `psycopg2` library is used to connect to Postgre SQL.

# %% [markdown]
# #### Connecting

# %%
import pandas as pd
import psycopg2

# %%
# database information
host = '101.96.116.82'
port = '8182'
database = 'tintuc_haisan'
username = 'mp_quantri'
password = 'asdaw@23423das'

# connect
connect = psycopg2.connect(host=host, port=port, dbname=database, user=username, password=password)
cursor = connect.cursor()

# %% [markdown]
# #### Listing all tables

# %%
cursor.execute('''
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public'
AND table_name != 'user'
''')

[table[0] for table in cursor.fetchall()]

# %% [markdown]
# #### Running a query

# %%
query = '''
SELECT *
FROM bow
LIMIT 5
'''

pd.read_sql_query(query, connect)

# %% [markdown]
# #### Reading an entire table

# %%
table = ''

pd.read_sql_query(f'SELECT * FROM {table}', connect)

# %% [markdown]
# # 3. Connecting to APIs
# This section demonstrates the usage of [Clash Royal API](https://developer.clashroyale.com/#/documentation).
# - Go to the Clash Royale API site and register an account.
# - Find the device's *public IP address* by searching for "my ip" or "what is my ip" on Google. It is sometimes called *external IP*, and should not be confused with *local/internal IP*. Another way is to run `curl ifconfig.me` on either a macOS terminal or a Windows terminal.
# - Open account settings and create a new key, using the *public IP* found earlier. This is the method Clash Royale API uses for authorizing the requests. After finished, copy the *token* associated with the key.
# - Use Python's `requests` library to connect to the API and get response data.

# %%
# !curl ifconfig.me
# Out:
# 113.190.142.191

# %%
import pandas as pd
import requests
import json
pd.options.display.max_rows = 200

# %%
url = 'https://api.clashroyale.com/v1/players/%232082RVQQ'
token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..76SeixMPS88yFVHMSI-TuzOueWBGhB2d4vHr1a5t3UaJa8YQor1vYygaXU8JB9vkdxL7AYQpt2lhgSqMvLfxJA'
headers = {
    'Accept': 'application/json',
    'Authorization': f'Bearer {token}'}

# %%
response = requests.get(url=url, headers=headers)
response = response.json()
data = response['cards']
data = {i: data[i] for i in range(len(data))}

# %%
rarity = {13: 'Common', 11: 'Rare', 8: 'Epic', 5: 'Legendary'}

df = pd.DataFrame.from_dict(data, orient='index')
df = df.assign(rarity=df.maxLevel.map(rarity))
df = df.assign(starLevel=df.starLevel.fillna(0).astype(int))
df = df.assign(level=df.level+13-df.maxLevel)
df = df.assign(rarity=pd.Categorical(df.rarity, categories=['Common', 'Rare', 'Epic', 'Legendary']))
df = df.drop(columns=['iconUrls', 'maxLevel'])
df = df[['id', 'rarity', 'name', 'level', 'starLevel', 'count']]

df = df.sort_values(by=['rarity', 'level'])
df = df.reset_index(drop=True)

df
# Out:
#            id     rarity              name  level  starLevel  count
# 0    26000010     Common         Skeletons     13          1      0
# 1    26000084     Common    Electro Spirit     13          1      0
# 2    26000019     Common     Spear Goblins     13          1      0
# 3    27000000     Common            Cannon     13          3      0
# 4    28000018     Common    Royal Delivery     13          1      0
# 5    27000002     Common            Mortar     13          1      0
# 6    26000001     Common           Archers     13          1      0
# 7    26000031     Common       Fire Spirit     13          1      0
# 8    26000022     Common      Minion Horde     13          1      0
# 9    28000017     Common    Giant Snowball     13          1      0
# 10   26000080     Common  Skeleton Dragons     13          1      0
# 11   26000047     Common    Royal Recruits     13          1      0
# 12   26000043     Common  Elite Barbarians     13          1      0
# 13   26000013     Common            Bomber     13          1      0
# 14   26000002     Common           Goblins     13          1      0
# 15   26000056     Common   Skeleton Barrel     13          1      0
# 16   26000053     Common           Rascals     13          1      0
# 17   26000030     Common        Ice Spirit     13          1      0
# 18   26000064     Common       Firecracker     13          1      0
# 19   26000008     Common        Barbarians     13          1      0
# 20   26000049     Common              Bats     13          1      0
# 21   26000005     Common           Minions     13          1      0
# 22   26000024     Common       Royal Giant     13          1      0
# 23   26000000     Common            Knight     13          1      0
# 24   27000006     Common             Tesla     13          1      0
# 25   26000041     Common       Goblin Gang     13          1      0
# 26   28000001     Common            Arrows     13          3      0
# 27   28000008     Common               Zap     13          1      0
# 28   28000016       Rare       Heal Spirit     13          1      0
# 29   26000039       Rare       Mega Minion     13          1      0
# 30   27000001       Rare        Goblin Hut     13          1      0
# 31   28000000       Rare          Fireball     13          2      0
# 32   26000021       Rare         Hog Rider     13          3      0
# 33   26000014       Rare         Musketeer     13          2      0
# 34   26000059       Rare        Royal Hogs     13          1      0
# 35   27000007       Rare  Elixir Collector     13          1      0
# 36   26000003       Rare             Giant     13          1      0
# 37   27000005       Rare     Barbarian Hut     13          1      0
# 38   27000004       Rare        Bomb Tower     13          1      0
# 39   26000018       Rare    Mini P.E.K.K.A     13          1      0
# 40   26000040       Rare       Dart Goblin     13          1      0
# 41   26000028       Rare  Three Musketeers     13          1      0
# 42   27000010       Rare           Furnace     13          1      0
# 43   26000068       Rare     Battle Healer     13          1      0
# 44   27000012       Rare       Goblin Cage     13          1      0
# 45   27000009       Rare         Tombstone     13          1      0
# 46   26000067       Rare      Elixir Golem     13          1      0
# 47   28000014       Rare        Earthquake     13          3      0
# 48   26000052       Rare           Zappies     13          1      0
# 49   26000057       Rare    Flying Machine     13          1      0
# 50   27000003       Rare     Inferno Tower     13          1      0
# 51   26000011       Rare          Valkyrie     13          1      0
# 52   26000017       Rare            Wizard     13          1      0
# 53   26000038       Rare         Ice Golem     13          1      0
# 54   28000003       Rare            Rocket     13          3      0
# 55   26000036       Rare        Battle Ram     13          2      0
# 56   27000013       Epic      Goblin Drill     12          0      0
# 57   26000060       Epic      Goblin Giant     13          3      0
# 58   28000012       Epic           Tornado     13          1      0
# 59   26000012       Epic     Skeleton Army     13          3      0
# 60   26000006       Epic           Balloon     13          3      0
# 61   26000027       Epic       Dark Prince     13          1      0
# 62   26000007       Epic             Witch     13          2      0
# 63   28000005       Epic            Freeze     13          1      0
# 64   28000015       Epic  Barbarian Barrel     13          2      0
# 65   26000025       Epic            Guards     13          2      0
# 66   28000002       Epic              Rage     13          1      0
# 67   26000058       Epic     Wall Breakers     13          3      0
# 68   26000016       Epic            Prince     13          1      0
# 69   26000009       Epic             Golem     13          2      0
# 70   27000008       Epic             X-Bow     13          3      0
# 71   28000006       Epic            Mirror     13          3      0
# 72   26000020       Epic    Giant Skeleton     13          3      0
# 73   26000044       Epic            Hunter     13          3      0
# 74   26000054       Epic       Cannon Cart     13          3      0
# 75   28000013       Epic             Clone     13          1      0
# 76   26000045       Epic       Executioner     13          2      0
# 77   26000063       Epic    Electro Dragon     13          1      0
# 78   26000034       Epic            Bowler     13          2      0
# 79   26000085       Epic     Electro Giant     13          1      0
# 80   28000004       Epic     Goblin Barrel     13          3      0
# 81   28000007       Epic         Lightning     13          1      0
# 82   26000015       Epic       Baby Dragon     13          2      0
# 83   26000004       Epic         P.E.K.K.A     13          2      0
# 84   28000009       Epic            Poison     13          1      0
# 85   26000032  Legendary             Miner     13          2      0
# 86   26000048  Legendary       Night Witch     13          2      0
# 87   26000023  Legendary        Ice Wizard     13          1      0
# 88   26000033  Legendary            Sparky     13          1      0
# 89   26000035  Legendary        Lumberjack     13          1      0
# 90   26000029  Legendary        Lava Hound     13          2      0
# 91   26000061  Legendary         Fisherman     13          1      0
# 92   28000010  Legendary         Graveyard     13          3      0
# 93   28000011  Legendary           The Log     13          1      0
# 94   26000026  Legendary          Princess     13          1      0
# 95   26000051  Legendary         Ram Rider     13          1      0
# 96   26000037  Legendary    Inferno Dragon     13          3      0
# 97   26000055  Legendary       Mega Knight     13          2      0
# 98   26000083  Legendary      Mother Witch     13          1      0
# 99   26000062  Legendary      Magic Archer     13          3      0
# 100  26000042  Legendary    Electro Wizard     13          1      0
# 101  26000046  Legendary            Bandit     13          1      0
# 102  26000050  Legendary       Royal Ghost     13          1      0

# %% [markdown]
# ---
# *&#9829; By Quang Hung x Thuy Linh &#9829;*
