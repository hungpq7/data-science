# %% [markdown]
# # 1. Overview
# There are basically two ways to scrape data from websites, one is via HTML responses (server-side) and the other is via JSON responses (client-side).
# - In the first method, we extract structured data from user interface, which is friendly for human eyes but not for computers. Because we scrape what we see, data will be availale most of the time except for cases such as when website owners protect their data using images rather than raw text. This crawling approach requires some basic knowledge of HTML.
# - In the second method, we try to crawl REST API responses, which is only available in specific website that use this protocol. The advantage is that the returned data is in JSON format, so they can be easily extracted and processed. Crawling data this way is much easier, so we are going to start with it.

# %% [markdown]
# ## 1.1. Requests
# Instead of accessing websites using a browser such as Google Chrome, we can use the [Requests] library to download the raw content of that page and interact with it.
#
# [Requests]: https://github.com/psf/requests

# %% [markdown]
# ## 1.2. API crawling

# %%
import requests

# %% [markdown]
# ### Public APIs

# %%
OWNER = 'psf'
REPO = 'requests'

url = f'https://api.github.com/repos/{OWNER}/{REPO}'
headers = {
    'Accept': 'application/vnd.github+json',
    'Authorization': 'Bearer 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',
    'X-GitHub-Api-Version': '2022-11-28',
}
response = requests.get(url)
response.json()['owner']
# Out:
# {'login': 'psf',
#  'id': 50630501,
#  'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUwNjMwNTAx',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/50630501?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/psf',
#  'html_url': 'https://github.com/psf',
#  'followers_url': 'https://api.github.com/users/psf/followers',
#  'following_url': 'https://api.github.com/users/psf/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/psf/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/psf/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/psf/subscriptions',
#  'organizations_url': 'https://api.github.com/users/psf/orgs',
#  'repos_url': 'https://api.github.com/users/psf/repos',
#  'events_url': 'https://api.github.com/users/psf/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/psf/received_events',
#  'type': 'Organization',
#  'site_admin': False}

# %%
url
# Out:
# 'https://api.github.com/repos/hungpq7/courses'

# %%
OWNER = 'hungpq7'
REPO = 'courses'

url = f'https://api.github.com/repos/{OWNER}/{REPO}'
headers = {
    'Accept': 'application/vnd.github+json',
    'Authorization': 'Bearer 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',
    'X-GitHub-Api-Version': '2022-11-28',
}
response = requests.get(url, headers=headers)
response.json()
# Out:
# {'message': 'Not Found',
#  'documentation_url': 'https://docs.github.com/rest/reference/repos#get-a-repository'}

# %% [markdown]
# ### Authenication

# %%
data = '''^[^{^\^"operationName^\^":^\^"SearchProductQueryV4^\^",^\^"variables^\^":^{^\^"params^\^":^\^"device=desktop&navsource=&ob=23&page=1&q=White^%^20Linen^%^20Shirt&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start=0&topads_bucket=true&unique_id=2f4091dc2e8de466e113561c8ce8b631&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=12210375&variants=^\^"^},^\^"query^\^":^\^"query SearchProductQueryV4(^$params: String^!) ^{^\^\n  ace_search_product_v4(params: ^$params) ^{^\^\n    header ^{^\^\n      totalData^\^\n      totalDataText^\^\n      processTime^\^\n      responseCode^\^\n      errorMessage^\^\n      additionalParams^\^\n      keywordProcess^\^\n      componentId^\^\n      __typename^\^\n    ^}^\^\n    data ^{^\^\n      banner ^{^\^\n        position^\^\n        text^\^\n        imageUrl^\^\n        url^\^\n        componentId^\^\n        trackingOption^\^\n        __typename^\^\n      ^}^\^\n      backendFilters^\^\n      isQuerySafe^\^\n      ticker ^{^\^\n        text^\^\n        query^\^\n        typeId^\^\n        componentId^\^\n        trackingOption^\^\n        __typename^\^\n      ^}^\^\n      redirection ^{^\^\n        redirectUrl^\^\n        departmentId^\^\n        __typename^\^\n      ^}^\^\n      related ^{^\^\n        position^\^\n        trackingOption^\^\n        relatedKeyword^\^\n        otherRelated ^{^\^\n          keyword^\^\n          url^\^\n          product ^{^\^\n            id^\^\n            name^\^\n            price^\^\n            imageUrl^\^\n            rating^\^\n            countReview^\^\n            url^\^\n            priceStr^\^\n            wishlist^\^\n            shop ^{^\^\n              city^\^\n              isOfficial^\^\n              isPowerBadge^\^\n              __typename^\^\n            ^}^\^\n            ads ^{^\^\n              adsId: id^\^\n              productClickUrl^\^\n              productWishlistUrl^\^\n              shopClickUrl^\^\n              productViewUrl^\^\n              __typename^\^\n            ^}^\^\n            badges ^{^\^\n              title^\^\n              imageUrl^\^\n              show^\^\n              __typename^\^\n            ^}^\^\n            ratingAverage^\^\n            labelGroups ^{^\^\n              position^\^\n              type^\^\n              title^\^\n              url^\^\n              __typename^\^\n            ^}^\^\n            componentId^\^\n            __typename^\^\n          ^}^\^\n          componentId^\^\n          __typename^\^\n        ^}^\^\n        __typename^\^\n      ^}^\^\n      suggestion ^{^\^\n        currentKeyword^\^\n        suggestion^\^\n        suggestionCount^\^\n        instead^\^\n        insteadCount^\^\n        query^\^\n        text^\^\n        componentId^\^\n        trackingOption^\^\n        __typename^\^\n      ^}^\^\n      products ^{^\^\n        id^\^\n        name^\^\n        ads ^{^\^\n          adsId: id^\^\n          productClickUrl^\^\n          productWishlistUrl^\^\n          productViewUrl^\^\n          __typename^\^\n        ^}^\^\n        badges ^{^\^\n          title^\^\n          imageUrl^\^\n          show^\^\n          __typename^\^\n        ^}^\^\n        category: departmentId^\^\n        categoryBreadcrumb^\^\n        categoryId^\^\n        categoryName^\^\n        countReview^\^\n        customVideoURL^\^\n        discountPercentage^\^\n        gaKey^\^\n        imageUrl^\^\n        labelGroups ^{^\^\n          position^\^\n          title^\^\n          type^\^\n          url^\^\n          __typename^\^\n        ^}^\^\n        originalPrice^\^\n        price^\^\n        priceRange^\^\n        rating^\^\n        ratingAverage^\^\n        shop ^{^\^\n          shopId: id^\^\n          name^\^\n          url^\^\n          city^\^\n          isOfficial^\^\n          isPowerBadge^\^\n          __typename^\^\n        ^}^\^\n        url^\^\n        wishlist^\^\n        sourceEngine: source_engine^\^\n        __typename^\^\n      ^}^\^\n      violation ^{^\^\n        headerText^\^\n        descriptionText^\^\n        imageURL^\^\n        ctaURL^\^\n        ctaApplink^\^\n        buttonText^\^\n        buttonType^\^\n        __typename^\^\n      ^}^\^\n      __typename^\^\n    ^}^\^\n    __typename^\^\n  ^}^\^\n^}^\^\n^\^"^}^]'''

# %%
payload = {
    "operationName": "SearchProductQueryV4",
    "variables": {
      "params": "device=desktop&navsource=&ob=23&page=1&q=White%20Linen%20Shirt&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start=0&topads_bucket=true&unique_id=2f4091dc2e8de466e113561c8ce8b631&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=12210375&variants="
    },
    "query": "query SearchProductQueryV4($params: String!) {\n  ace_search_product_v4(params: $params) {\n    header {\n      totalData\n      totalDataText\n      processTime\n      responseCode\n      errorMessage\n      additionalParams\n      keywordProcess\n      componentId\n      __typename\n    }\n    data {\n      banner {\n        position\n        text\n        imageUrl\n        url\n        componentId\n        trackingOption\n        __typename\n      }\n      backendFilters\n      isQuerySafe\n      ticker {\n        text\n        query\n        typeId\n        componentId\n        trackingOption\n        __typename\n      }\n      redirection {\n        redirectUrl\n        departmentId\n        __typename\n      }\n      related {\n        position\n        trackingOption\n        relatedKeyword\n        otherRelated {\n          keyword\n          url\n          product {\n            id\n            name\n            price\n            imageUrl\n            rating\n            countReview\n            url\n            priceStr\n            wishlist\n            shop {\n              city\n              isOfficial\n              isPowerBadge\n              __typename\n            }\n            ads {\n              adsId: id\n              productClickUrl\n              productWishlistUrl\n              shopClickUrl\n              productViewUrl\n              __typename\n            }\n            badges {\n              title\n              imageUrl\n              show\n              __typename\n            }\n            ratingAverage\n            labelGroups {\n              position\n              type\n              title\n              url\n              __typename\n            }\n            componentId\n            __typename\n          }\n          componentId\n          __typename\n        }\n        __typename\n      }\n      suggestion {\n        currentKeyword\n        suggestion\n        suggestionCount\n        instead\n        insteadCount\n        query\n        text\n        componentId\n        trackingOption\n        __typename\n      }\n      products {\n        id\n        name\n        ads {\n          adsId: id\n          productClickUrl\n          productWishlistUrl\n          productViewUrl\n          __typename\n        }\n        badges {\n          title\n          imageUrl\n          show\n          __typename\n        }\n        category: departmentId\n        categoryBreadcrumb\n        categoryId\n        categoryName\n        countReview\n        customVideoURL\n        discountPercentage\n        gaKey\n        imageUrl\n        labelGroups {\n          position\n          title\n          type\n          url\n          __typename\n        }\n        originalPrice\n        price\n        priceRange\n        rating\n        ratingAverage\n        shop {\n          shopId: id\n          name\n          url\n          city\n          isOfficial\n          isPowerBadge\n          __typename\n        }\n        url\n        wishlist\n        sourceEngine: source_engine\n        __typename\n      }\n      violation {\n        headerText\n        descriptionText\n        imageURL\n        ctaURL\n        ctaApplink\n        buttonText\n        buttonType\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
}

# %%
url = 'https://gql.tokopedia.com/graphql/SearchProductQueryV4'
headers = {
    # "authority": "gql.tokopedia.com",
    # "accept": "*/*",
    # "accept-language": "en,vi;q=0.9",
    # "content-type": "application/json",
    # "origin": "https://www.tokopedia.com",
    # "referer": "https://www.tokopedia.com/search?st=product&q=White^%^20Linen^%^20Shirt&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&navsource=",
    # "sec-ch-ua": '''^\^"Not?A_Brand^\^";v=^\^"8^\^", ^\^"Chromium^\^";v=^\^"108^\^", ^\^"Google Chrome^\^";v=^\^"108^\^"''',
    # "sec-ch-ua-mobile": "?0",
    # "sec-ch-ua-platform": '''^\^"Windows^\^"''',
    # "sec-fetch-dest": "empty",
    # "sec-fetch-mode": "cors",
    # "sec-fetch-site": "same-site",
    # "tkpd-userid": "0",
    # "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36",
    # "x-device": "desktop-0.0",
    # "x-source": "tokopedia-lite",
    # "x-tkpd-lite-service": "zeus",
    # "x-version": "505bf79",
}
response = requests.post(url, json=payload)

response.json()
# Out:
# {'data': {'ace_search_product_v4': {'header': {'totalData': 2488,
#     'totalDataText': '2.488',
#     'processTime': 0.11293385,
#     'responseCode': 0,
#     'errorMessage': '',
#     'additionalParams': '',
#     'keywordProcess': '4',
#     'componentId': '02.01.00.00',
#     '__typename': 'AceSearchUnifyHeader'},
#    'data': {'banner': {'position': 0,
#      'text': '',
#      'imageUrl': '',
#      'url': '',
#      'componentId': '',
#      'trackingOption': 0,
#      '__typename': 'AceSearchUnifyBanner'},
#     'backendFilters': '',
#     'isQuerySafe': True,
#     'ticker': {'text': '',
#      'query': '',
#      'typeId': 0,
#      'componentId': '',
#      'trackingOption': 0,
#      '__typename': 'AceSearchUnifyTicker'},
#     'redirection': {'redirectUrl': '',
#      'departmentId': 0,
#      '__typename': 'AceSearchUnifyRedirection'},
#     'related': {'position': 0,
#      'trackingOption': 0,
#      'relatedKeyword': '',
#      'otherRelated': [],
#      '__typename': 'AceSearchUnifyRelated'},
#     'suggestion': {'currentKeyword': 'white linen shirt',
#      'suggestion': '',
#      'suggestionCount': 0,
#      'instead': '',
#      'insteadCount': 0,
#      'query': '',
#      'text': '',
#      'componentId': '',
#      'trackingOption': 0,
#      '__typename': 'AceSearchUnifySuggestion'},
#     'products': [{'id': 6901597645,
#       'name': 'EXCLUSIVE KEMEJA PRIA LENGAN PANJANG WHITE PURE LINEN SLUB ORIGINAL',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 104,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/arnad/exclusive-kemeja-pria-lengan-panjang-white-pure-linen-slub-original-bw-hardbox-s',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/1/30/fe5f9cae-6a7a-42a3-8688-3ff4c4dde374.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 100+',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp250.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.8',
#       'shop': {'shopId': 9964262,
#        'name': 'ARNAD',
#        'url': 'https://www.tokopedia.com/arnad',
#        'city': 'Jakarta Barat',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/arnad/exclusive-kemeja-pria-lengan-panjang-white-pure-linen-slub-original-bw-hardbox-s?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6846478011,
#       'name': 'Joie Linen Stripes Shirt Light Blue White Long Sleeve',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 20,
#       'customVideoURL': '',
#       'discountPercentage': 43,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/tenuedeattire/joie-linen-stripes-shirt-light-blue-white-long-sleeve-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/10/28/3b083420-dc73-4d4e-8c7c-8d70f3881d7d.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 60+',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp289.000',
#       'price': 'Rp164.888',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.8',
#       'shop': {'shopId': 7716068,
#        'name': 'TenuedeAttire',
#        'url': 'https://www.tokopedia.com/tenuedeattire',
#        'city': 'Jakarta Selatan',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/tenuedeattire/joie-linen-stripes-shirt-light-blue-white-long-sleeve-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6846598409,
#       'name': 'Joie Linen Camp Collar Stripes Shirt White Cream Short Sleeve',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 24,
#       'customVideoURL': '',
#       'discountPercentage': 43,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/tenuedeattire/joie-linen-camp-collar-stripes-shirt-white-cream-short-sleeve-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/10/29/23cf7036-3d7d-4d1e-a8f9-0de610a74f83.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 80+',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp289.000',
#       'price': 'Rp164.888',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.8',
#       'shop': {'shopId': 7716068,
#        'name': 'TenuedeAttire',
#        'url': 'https://www.tokopedia.com/tenuedeattire',
#        'city': 'Jakarta Selatan',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/tenuedeattire/joie-linen-camp-collar-stripes-shirt-white-cream-short-sleeve-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 5022100468,
#       'name': 'H&M Slim Fit Linen Blend Short Sleeve Shirt Ivory White',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 64,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/sangkilco/h-m-slim-fit-linen-blend-short-sleeve-shirt-ivory-white-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/7/26/e5c5cb6a-74d7-4f0f-9002-49888ce25959.jpg',
#       'labelGroups': [{'position': 'gimmick',
#         'title': 'Sisa 3',
#         'type': 'textDarkRed',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'},
#        {'position': 'price',
#         'title': 'Cashback',
#         'type': 'lightGreen',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'},
#        {'position': 'integrity',
#         'title': 'Terjual 100+',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp179.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.9',
#       'shop': {'shopId': 2143211,
#        'name': 'Sangkilco',
#        'url': 'https://www.tokopedia.com/sangkilco',
#        'city': 'Tangerang',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/sangkilco/h-m-slim-fit-linen-blend-short-sleeve-shirt-ivory-white-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6846499421,
#       'name': 'Joie Linen Camp Collar Stripes Shirt Light Blue White Short Sleeve',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 12,
#       'customVideoURL': '',
#       'discountPercentage': 43,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/tenuedeattire/joie-linen-camp-collar-stripes-shirt-light-blue-white-short-sleeve-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/12/23/8879a32e-b1b0-4d25-a3cc-f46b4c5705b7.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 30+',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp289.000',
#       'price': 'Rp164.888',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.8',
#       'shop': {'shopId': 7716068,
#        'name': 'TenuedeAttire',
#        'url': 'https://www.tokopedia.com/tenuedeattire',
#        'city': 'Jakarta Selatan',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/tenuedeattire/joie-linen-camp-collar-stripes-shirt-light-blue-white-short-sleeve-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6846550074,
#       'name': 'Joie Linen Stripes Shirt White Cream Long Sleeve',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 12,
#       'customVideoURL': '',
#       'discountPercentage': 43,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/tenuedeattire/joie-linen-stripes-shirt-white-cream-long-sleeve-m',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/10/28/60a65653-7a62-44df-9c57-cdf6e997fc4b.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 30+',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp289.000',
#       'price': 'Rp164.888',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.7',
#       'shop': {'shopId': 7716068,
#        'name': 'TenuedeAttire',
#        'url': 'https://www.tokopedia.com/tenuedeattire',
#        'city': 'Jakarta Selatan',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/tenuedeattire/joie-linen-stripes-shirt-white-cream-long-sleeve-m?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 4881483250,
#       'name': 'Original H&m Linen Short Sleeve Shirt size S, M, L, XL, XXL White',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 7,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/koleksiyahud/original-h-m-linen-short-sleeve-shirt-size-s-m-l-xl-xxl-white-s',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/10/16/407b745e-4ef8-4274-bab2-8b8ebd0ecbe6.jpg',
#       'labelGroups': [{'position': 'gimmick',
#         'title': 'Sisa 3',
#         'type': 'textDarkRed',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'},
#        {'position': 'price',
#         'title': 'Cashback',
#         'type': 'lightGreen',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'},
#        {'position': 'integrity',
#         'title': 'Terjual 28',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp175.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.7',
#       'shop': {'shopId': 3361769,
#        'name': 'koleksiyahud',
#        'url': 'https://www.tokopedia.com/koleksiyahud',
#        'city': 'Jakarta Pusat',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/koleksiyahud/original-h-m-linen-short-sleeve-shirt-size-s-m-l-xl-xxl-white-s?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 2372851762,
#       'name': 'Benhill Kemeja Pria Linen Lengan Pendek Light White 27313-16102',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 55,
#       'customVideoURL': '',
#       'discountPercentage': 60,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/benhill-1/benhill-kemeja-pria-linen-lengan-pendek-light-white-27313-16102-s',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2021/11/4/9da2e51e-c70a-4a08-9501-7945a86a92d1.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 90+',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp399.800',
#       'price': 'Rp159.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.8',
#       'shop': {'shopId': 8562858,
#        'name': 'Benhill_Official_Shop',
#        'url': 'https://www.tokopedia.com/benhill-1',
#        'city': 'Surabaya',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/benhill-1/benhill-kemeja-pria-linen-lengan-pendek-light-white-27313-16102-s?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 3576693743,
#       'name': 'KEMEJA ATASAN PRIA Shawl Shirt Men GTS-07 Linen Look White - Gantari',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 2,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/lakonofficial/kemeja-atasan-pria-shawl-shirt-men-gts-07-linen-look-white-gantari-s',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/4/16/125c89f5-7a93-4b4d-9c87-77c509e7fcea.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 5',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp329.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '5.0',
#       'shop': {'shopId': 8373234,
#        'name': 'LAKON Official Store',
#        'url': 'https://www.tokopedia.com/lakonofficial',
#        'city': 'Jakarta Utara',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/lakonofficial/kemeja-atasan-pria-shawl-shirt-men-gts-07-linen-look-white-gantari-s?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6846440387,
#       'name': 'Joie Linen Stripes Shirt Cream White Short Sleeve',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 10,
#       'customVideoURL': '',
#       'discountPercentage': 43,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/tenuedeattire/joie-linen-stripes-shirt-cream-white-short-sleeve-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/10/28/8b0b227e-8270-4daa-a83a-68fb2c29668a.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 19',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp289.000',
#       'price': 'Rp164.888',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.9',
#       'shop': {'shopId': 7716068,
#        'name': 'TenuedeAttire',
#        'url': 'https://www.tokopedia.com/tenuedeattire',
#        'city': 'Jakarta Selatan',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/tenuedeattire/joie-linen-stripes-shirt-cream-white-short-sleeve-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6981327335,
#       'name': 'Tweltree Kemeja Ordival Linen Mandarin Long White',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 283,
#       'customVideoURL': '',
#       'discountPercentage': 18,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/tweltree/tweltree-kemeja-ordival-linen-mandarin-long-white-mint-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/10/22/fd73a5c6-43bf-4461-a168-14b06553f751.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 500+',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp170.000',
#       'price': 'Rp139.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.7',
#       'shop': {'shopId': 2334358,
#        'name': 'tweltree',
#        'url': 'https://www.tokopedia.com/tweltree',
#        'city': 'Bandung',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/tweltree/tweltree-kemeja-ordival-linen-mandarin-long-white-mint-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 3022413848,
#       'name': 'Kemeja Koko Pria Panjang Linen Band Collar Broken White By SCHOUTEN',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 24,
#       'customVideoURL': '',
#       'discountPercentage': 59,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/schouten/kemeja-koko-pria-panjang-linen-band-collar-broken-white-by-schouten-m',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/5/27/882e6852-76c4-4082-bebb-a3b0fd92868b.png',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 50+',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp314.000',
#       'price': 'Rp129.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '5.0',
#       'shop': {'shopId': 1301520,
#        'name': 'SCHOUTEN OFFICIAL SHOP',
#        'url': 'https://www.tokopedia.com/schouten',
#        'city': 'Bandung',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/schouten/kemeja-koko-pria-panjang-linen-band-collar-broken-white-by-schouten-m?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6846397283,
#       'name': 'Joie Linen Stripes Shirt Navy White Grey Patch Long Sleeve',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 3,
#       'customVideoURL': '',
#       'discountPercentage': 43,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/tenuedeattire/joie-linen-stripes-shirt-navy-white-grey-patch-long-sleeve-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/10/28/02e785ca-ed22-4735-b5e0-47a2855c0e1c.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 10',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp289.000',
#       'price': 'Rp164.888',
#       'priceRange': '',
#       'rating': 4,
#       'ratingAverage': '4.0',
#       'shop': {'shopId': 7716068,
#        'name': 'TenuedeAttire',
#        'url': 'https://www.tokopedia.com/tenuedeattire',
#        'city': 'Jakarta Selatan',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/tenuedeattire/joie-linen-stripes-shirt-navy-white-grey-patch-long-sleeve-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 7117812556,
#       'name': 'Tweltree Kemeja Trukey Linen Texture Long Off White',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 1,
#       'customVideoURL': '',
#       'discountPercentage': 26,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/tweltree/tweltree-kemeja-trukey-linen-texture-long-off-white-s-ad0e',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/12/2/9307414e-2f12-49bf-8826-4af86b1330a9.png',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 6',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp200.000',
#       'price': 'Rp149.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '5.0',
#       'shop': {'shopId': 2334358,
#        'name': 'tweltree',
#        'url': 'https://www.tokopedia.com/tweltree',
#        'city': 'Bandung',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/tweltree/tweltree-kemeja-trukey-linen-texture-long-off-white-s-ad0e?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 2884510789,
#       'name': 'Kemeja Casual Lengan Pendek Linen Cotton Premium Warna Putih the MNLY',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 2,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/themnly/kemeja-casual-lengan-pendek-linen-cotton-premium-warna-putih-the-mnly-black-m',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/2/5/e7b4aad6-2912-4eaa-97f8-385d6a696503.jpg',
#       'labelGroups': [{'position': 'price',
#         'title': 'Grosir',
#         'type': 'lightGreen',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'},
#        {'position': 'integrity',
#         'title': 'Terjual 2',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp139.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '5.0',
#       'shop': {'shopId': 3545501,
#        'name': 'the MNLY',
#        'url': 'https://www.tokopedia.com/themnly',
#        'city': 'Depok',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/themnly/kemeja-casual-lengan-pendek-linen-cotton-premium-warna-putih-the-mnly-black-m?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6930041088,
#       'name': 'UNIQLO Premium Linen Stands Collar Long Sleeve Shirt - White',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 1,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/duplove/uniqlo-premium-linen-stands-collar-long-sleeve-shirt-white-s',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/11/10/282cb6ea-90b7-4b7a-ae04-1972708520da.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 4',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp248.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '5.0',
#       'shop': {'shopId': 880429,
#        'name': 'Duplove',
#        'url': 'https://www.tokopedia.com/duplove',
#        'city': 'Jakarta Selatan',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/duplove/uniqlo-premium-linen-stands-collar-long-sleeve-shirt-white-s?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 7017875415,
#       'name': 'MARKS & SPENCER - Kemeja Pria - Pure Linen Revere Shirt - White',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 1,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/marksspencer/marks-spencer-kemeja-pria-pure-linen-revere-shirt-white-white-int-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/11/21/4ffd54b9-ba44-46c8-9f95-473db33970af.jpg',
#       'labelGroups': [{'position': 'price',
#         'title': 'Cashback',
#         'type': 'lightGreen',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'},
#        {'position': 'integrity',
#         'title': 'Terjual 5',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp749.900',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '5.0',
#       'shop': {'shopId': 8421881,
#        'name': 'MARKS & SPENCER',
#        'url': 'https://www.tokopedia.com/marksspencer',
#        'city': 'Kab. Bogor',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/marksspencer/marks-spencer-kemeja-pria-pure-linen-revere-shirt-white-white-int-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6915319545,
#       'name': 'ARNOLD PALMER KEMEJA LINEN PRIA PUTIH - P-AIGE50-A1',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 3,
#       'customVideoURL': '',
#       'discountPercentage': 30,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/arnoldpalmer/arnold-palmer-kemeja-linen-pria-putih-p-aige50-a1-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/11/8/efc06c12-8494-4ad2-a2b6-de2bdbeb3b89.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 4',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp499.900',
#       'price': 'Rp349.930',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '5.0',
#       'shop': {'shopId': 10992914,
#        'name': 'ARNOLD PALMER',
#        'url': 'https://www.tokopedia.com/arnoldpalmer',
#        'city': 'Jakarta Timur',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/arnoldpalmer/arnold-palmer-kemeja-linen-pria-putih-p-aige50-a1-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6785857783,
#       'name': 'kemeja Uniqlo Linen stand collar white original',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 2,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/kemejaquiksilver/kemeja-uniqlo-linen-stand-collar-white-original-s',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/10/19/a4bb9a1e-2f82-4f85-808f-d52b02a732f9.jpg',
#       'labelGroups': [{'position': 'price',
#         'title': 'Cashback',
#         'type': 'lightGreen',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'},
#        {'position': 'integrity',
#         'title': 'Terjual 6',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp175.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '5.0',
#       'shop': {'shopId': 1491608,
#        'name': 'luky hakim online shop',
#        'url': 'https://www.tokopedia.com/kemejaquiksilver',
#        'city': 'Kab. Bekasi',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/kemejaquiksilver/kemeja-uniqlo-linen-stand-collar-white-original-s?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 1797915785,
#       'name': 'Osella Baju Pria Kemeja Polos Putih Linen Look',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 5,
#       'customVideoURL': '',
#       'discountPercentage': 60,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/osella/osella-baju-pria-kemeja-polos-putih-linen-look-s',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/product-1/2021/4/26/4202188/4202188_77bb04ce-969d-4132-9beb-eb60ceedf276.jpeg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 8',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp399.900',
#       'price': 'Rp159.960',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.8',
#       'shop': {'shopId': 4202188,
#        'name': 'Osella Official Store',
#        'url': 'https://www.tokopedia.com/osella',
#        'city': 'Jakarta Utara',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/osella/osella-baju-pria-kemeja-polos-putih-linen-look-s?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 5907254912,
#       'name': 'BEACH WEAR WHITE LINEN SHIRT (MOTIF BAMBU)',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 2,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/arnad/beach-wear-white-linen-shirt-motif-bambu-xl',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/9/4/fe31a7cc-ed2b-4561-8536-e8e4b3b686fe.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 6',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp215.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '5.0',
#       'shop': {'shopId': 9964262,
#        'name': 'ARNAD',
#        'url': 'https://www.tokopedia.com/arnad',
#        'city': 'Jakarta Barat',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/arnad/beach-wear-white-linen-shirt-motif-bambu-xl?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 2216908072,
#       'name': 'Kemeja Casual Lengan Panjang Linen Cotton Premium Warna Putih the MNLY',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 6,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/themnly/kemeja-casual-lengan-panjang-linen-cotton-premium-warna-putih-the-mnly-dark-navy-xl',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2021/9/27/947ae0a9-db1f-4c26-a34a-ff82a5921d79.jpg',
#       'labelGroups': [{'position': 'price',
#         'title': 'Grosir',
#         'type': 'lightGreen',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'},
#        {'position': 'integrity',
#         'title': 'Terjual 12',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp149.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.8',
#       'shop': {'shopId': 3545501,
#        'name': 'the MNLY',
#        'url': 'https://www.tokopedia.com/themnly',
#        'city': 'Depok',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/themnly/kemeja-casual-lengan-panjang-linen-cotton-premium-warna-putih-the-mnly-dark-navy-xl?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 4789701354,
#       'name': 'Kemeja Lengan Panjang Pria Polos Putih Bahan Linen Katun Ukuran M-XL',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 9,
#       'customVideoURL': '',
#       'discountPercentage': 32,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/defaultstore-322/kemeja-lengan-panjang-pria-polos-putih-bahan-linen-katun-ukuran-m-xl-m',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/7/26/882594eb-b97a-4cc6-b87a-b99d646aa18f.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 22',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp220.000',
#       'price': 'Rp149.900',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.9',
#       'shop': {'shopId': 3046087,
#        'name': 'DEFAULT-322',
#        'url': 'https://www.tokopedia.com/defaultstore-322',
#        'city': 'Kab. Bandung',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/defaultstore-322/kemeja-lengan-panjang-pria-polos-putih-bahan-linen-katun-ukuran-m-xl-m?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 3531516460,
#       'name': 'Giordano Short Sleeve Linen Cotton Shirt White Pria',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 1,
#       'customVideoURL': '',
#       'discountPercentage': 11,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/giordanoid/giordano-short-sleeve-linen-cotton-shirt-white-pria-white-xl',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/4/12/dffd1d3e-2f2b-49ba-b0b0-21e27e6efe7b.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 3',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp699.000',
#       'price': 'Rp619.200',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '5.0',
#       'shop': {'shopId': 8171364,
#        'name': 'Giordano Indonesia',
#        'url': 'https://www.tokopedia.com/giordanoid',
#        'city': 'Bekasi',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/giordanoid/giordano-short-sleeve-linen-cotton-shirt-white-pria-white-xl?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 2279834396,
#       'name': 'KEMEJA PRIA REMEDY LENGAN PENDEK 100% LINEN PREMIUM PUTIH',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 7,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/remedyresortwear/kemeja-pria-remedy-lengan-pendek-100-linen-premium-putih-xl',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2021/10/13/892c5f3f-8c9d-4f6a-b949-ff38be9d78f4.jpg',
#       'labelGroups': [{'position': 'price',
#         'title': 'Cashback',
#         'type': 'lightGreen',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'},
#        {'position': 'integrity',
#         'title': 'Terjual 17',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp429.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.9',
#       'shop': {'shopId': 8167257,
#        'name': 'REMEDY RESORT WEAR',
#        'url': 'https://www.tokopedia.com/remedyresortwear',
#        'city': 'Jakarta Pusat',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
# ...
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 0,
#       'customVideoURL': '',
#       'discountPercentage': 11,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/giordanoid/giordano-short-sleeve-linen-cotton-white-shirt-pria-white-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/4/12/c37b2cb7-837c-4a3d-9a93-fa6dca4913d3.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 2',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp699.000',
#       'price': 'Rp619.200',
#       'priceRange': '',
#       'rating': 0,
#       'ratingAverage': '',
#       'shop': {'shopId': 8171364,
#        'name': 'Giordano Indonesia',
#        'url': 'https://www.tokopedia.com/giordanoid',
#        'city': 'Bekasi',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/giordanoid/giordano-short-sleeve-linen-cotton-white-shirt-pria-white-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6843064084,
#       'name': 'KEMEJA PRIA KASUAL PUTIH KANTONG DUA 2 LENGAN PENDEK BAHAN KATUN LINEN',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/power_merchant_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 0,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/zeebera/kemeja-pria-kasual-putih-kantong-dua-2-lengan-pendek-bahan-katun-linen',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/10/28/fea47b02-b520-4594-8679-6f14d1e64f27.jpg',
#       'labelGroups': [],
#       'originalPrice': '',
#       'price': 'Rp170.000',
#       'priceRange': '',
#       'rating': 0,
#       'ratingAverage': '',
#       'shop': {'shopId': 14657830,
#        'name': 'zeebera',
#        'url': 'https://www.tokopedia.com/zeebera',
#        'city': 'Jakarta Timur',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/zeebera/kemeja-pria-kasual-putih-kantong-dua-2-lengan-pendek-bahan-katun-linen?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 3341068165,
#       'name': 'Peternation kemeja kerah basic pure linen broken white regular fit',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 10,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/peternation/peternation-kemeja-kerah-basic-pure-linen-broken-white-regular-fit-s',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/3/25/cf8363d8-6741-4cd9-be09-4fc612ed7601.jpg',
#       'labelGroups': [{'position': 'price',
#         'title': 'Cashback',
#         'type': 'lightGreen',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'},
#        {'position': 'integrity',
#         'title': 'Terjual 18',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp315.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.8',
#       'shop': {'shopId': 8398529,
#        'name': 'PETERNATION',
#        'url': 'https://www.tokopedia.com/peternation',
#        'city': 'Jakarta Barat',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/peternation/peternation-kemeja-kerah-basic-pure-linen-broken-white-regular-fit-s?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 5135490186,
#       'name': 'Cod Kemeja Linen Pria (Formal & Casual) White Arnad',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/power_merchant_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 0,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/ekanshop/cod-kemeja-linen-pria-formal-casual-white-arnad-xl',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/7/31/b71140af-975b-44ef-86db-e64cb96902f0.jpg',
#       'labelGroups': [],
#       'originalPrice': '',
#       'price': 'Rp316.050',
#       'priceRange': '',
#       'rating': 0,
#       'ratingAverage': '',
#       'shop': {'shopId': 13980033,
#        'name': 'eka_nshop',
#        'url': 'https://www.tokopedia.com/ekanshop',
#        'city': 'Jakarta Selatan',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/ekanshop/cod-kemeja-linen-pria-formal-casual-white-arnad-xl?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6816827276,
#       'name': 'Ethan White Kemeja Pria Lengan Pendek Linen Pure White',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 0,
#       'customVideoURL': '',
#       'discountPercentage': 50,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/ethanwhite/ethan-white-kemeja-pria-lengan-pendek-linen-pure-white-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/10/25/01281003-7b05-4379-8443-86568ceb50ca.jpg',
#       'labelGroups': [],
#       'originalPrice': 'Rp776.000',
#       'price': 'Rp388.000',
#       'priceRange': '',
#       'rating': 0,
#       'ratingAverage': '',
#       'shop': {'shopId': 14142768,
#        'name': 'Ethan White',
#        'url': 'https://www.tokopedia.com/ethanwhite',
#        'city': 'Jakarta Selatan',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/ethanwhite/ethan-white-kemeja-pria-lengan-pendek-linen-pure-white-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 3555363359,
#       'name': 'Kemeja linen peternation kerah sanghai panjang warna putih regular fit',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Power Merchant Pro Badge',
#         'imageUrl': 'https://images.tokopedia.net/img/goldmerchant/pm_activation/badge/PM%20Pro%20Small.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 6,
#       'customVideoURL': '',
#       'discountPercentage': 0,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/peternation/kemeja-linen-peternation-kerah-sanghai-panjang-warna-putih-regular-fit-s',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2022/4/15/76df417c-f082-4744-8566-27cb653ec449.jpg',
#       'labelGroups': [{'position': 'price',
#         'title': 'Cashback',
#         'type': 'lightGreen',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'},
#        {'position': 'integrity',
#         'title': 'Terjual 11',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': '',
#       'price': 'Rp225.000',
#       'priceRange': '',
#       'rating': 5,
#       'ratingAverage': '4.5',
#       'shop': {'shopId': 8398529,
#        'name': 'PETERNATION',
#        'url': 'https://www.tokopedia.com/peternation',
#        'city': 'Jakarta Barat',
#        'isOfficial': False,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/peternation/kemeja-linen-peternation-kerah-sanghai-panjang-warna-putih-regular-fit-s?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 3530161503,
#       'name': 'Giordano Short Sleeve Eyelet Linen Cotton Shirt Pria White',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 0,
#       'customVideoURL': '',
#       'discountPercentage': 12,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/giordanoid/giordano-short-sleeve-eyelet-linen-cotton-shirt-pria-white-white-xxl',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/4/12/edcaf51c-4d54-4ad3-8fdc-76dd08fdeb75.jpg',
#       'labelGroups': [],
#       'originalPrice': 'Rp799.000',
#       'price': 'Rp699.200',
#       'priceRange': '',
#       'rating': 0,
#       'ratingAverage': '',
#       'shop': {'shopId': 8171364,
#        'name': 'Giordano Indonesia',
#        'url': 'https://www.tokopedia.com/giordanoid',
#        'city': 'Bekasi',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/giordanoid/giordano-short-sleeve-eyelet-linen-cotton-shirt-pria-white-white-xxl?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6816891838,
#       'name': 'Ethan White Kemeja Pria Lengan Pendek Linen Spring Green',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 0,
#       'customVideoURL': '',
#       'discountPercentage': 50,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/ethanwhite/ethan-white-kemeja-pria-lengan-pendek-linen-spring-green-m',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/10/25/721f75c3-efcf-45ba-8067-9bf6bec3e244.jpg',
#       'labelGroups': [{'position': 'integrity',
#         'title': 'Terjual 1',
#         'type': 'textDarkGrey',
#         'url': '',
#         '__typename': 'AceSearchUnifyLabelGroup'}],
#       'originalPrice': 'Rp776.000',
#       'price': 'Rp388.000',
#       'priceRange': '',
#       'rating': 0,
#       'ratingAverage': '',
#       'shop': {'shopId': 14142768,
#        'name': 'Ethan White',
#        'url': 'https://www.tokopedia.com/ethanwhite',
#        'city': 'Jakarta Selatan',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/ethanwhite/ethan-white-kemeja-pria-lengan-pendek-linen-spring-green-m?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'},
#      {'id': 6816170455,
#       'name': 'Ethan White Kemeja Pria Lengan Pendek Linen Bluish Green',
#       'ads': {'adsId': '',
#        'productClickUrl': '',
#        'productWishlistUrl': '',
#        'productViewUrl': '',
#        '__typename': 'AceSearchUnifyAds'},
#       'badges': [{'title': 'Official Store',
#         'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#         'show': True,
#         '__typename': 'AceSearchUnifyBadge'}],
#       'category': 3579,
#       'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#       'categoryId': 1759,
#       'categoryName': 'Fashion Pria',
#       'countReview': 0,
#       'customVideoURL': '',
#       'discountPercentage': 50,
#       'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/ethanwhite/ethan-white-kemeja-pria-lengan-pendek-linen-bluish-green-l',
#       'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/10/25/8a08c8d5-55fa-4468-ae2f-76f46a91b58b.jpg',
#       'labelGroups': [],
#       'originalPrice': 'Rp776.000',
#       'price': 'Rp388.000',
#       'priceRange': '',
#       'rating': 0,
#       'ratingAverage': '',
#       'shop': {'shopId': 14142768,
#        'name': 'Ethan White',
#        'url': 'https://www.tokopedia.com/ethanwhite',
#        'city': 'Jakarta Selatan',
#        'isOfficial': True,
#        'isPowerBadge': True,
#        '__typename': 'AceSearchUnifyShop'},
#       'url': 'https://www.tokopedia.com/ethanwhite/ethan-white-kemeja-pria-lengan-pendek-linen-bluish-green-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#       'wishlist': False,
#       'sourceEngine': '0',
#       '__typename': 'AceSearchUnifyProduct'}],
#     'violation': {'headerText': '',
#      'descriptionText': '',
#      'imageURL': '',
#      'ctaURL': '',
#      'ctaApplink': '',
#      'buttonText': '',
#      'buttonType': '',
#      '__typename': 'AceSearchUnifyViolation'},
#     '__typename': 'AceSearchUnifyData'},
#    '__typename': 'AceSearchUnifyResponse'}}}

# %%
response.json()['data']['ace_search_product_v4']['data']['products'][2]
# Out:
# {'id': 6846598409,
#  'name': 'Joie Linen Camp Collar Stripes Shirt White Cream Short Sleeve',
#  'ads': {'adsId': '',
#   'productClickUrl': '',
#   'productWishlistUrl': '',
#   'productViewUrl': '',
#   '__typename': 'AceSearchUnifyAds'},
#  'badges': [{'title': 'Official Store',
#    'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png',
#    'show': True,
#    '__typename': 'AceSearchUnifyBadge'}],
#  'category': 3579,
#  'categoryBreadcrumb': 'fashion-pria/atasan-pria/kemeja-pria',
#  'categoryId': 1759,
#  'categoryName': 'Fashion Pria',
#  'countReview': 24,
#  'customVideoURL': '',
#  'discountPercentage': 43,
#  'gaKey': '/searchproduct/fashion-pria/atasan-pria/kemeja-pria/white+linen+shirt/tenuedeattire/joie-linen-camp-collar-stripes-shirt-white-cream-short-sleeve-l',
#  'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/10/29/23cf7036-3d7d-4d1e-a8f9-0de610a74f83.jpg',
#  'labelGroups': [{'position': 'integrity',
#    'title': 'Terjual 80+',
#    'type': 'textDarkGrey',
#    'url': '',
#    '__typename': 'AceSearchUnifyLabelGroup'}],
#  'originalPrice': 'Rp289.000',
#  'price': 'Rp164.888',
#  'priceRange': '',
#  'rating': 5,
#  'ratingAverage': '4.8',
#  'shop': {'shopId': 7716068,
#   'name': 'TenuedeAttire',
#   'url': 'https://www.tokopedia.com/tenuedeattire',
#   'city': 'Jakarta Selatan',
#   'isOfficial': True,
#   'isPowerBadge': True,
#   '__typename': 'AceSearchUnifyShop'},
#  'url': 'https://www.tokopedia.com/tenuedeattire/joie-linen-camp-collar-stripes-shirt-white-cream-short-sleeve-l?extParam=ivf%3Dfalse%26src%3Dsearch',
#  'wishlist': False,
#  'sourceEngine': '0',
#  '__typename': 'AceSearchUnifyProduct'}

# %%
requests.post?
# Out:
# Signature: requests.post(url, data=None, json=None, **kwargs)
# Docstring:
# Sends a POST request.
#
# :param url: URL for the new :class:`Request` object.
# :param data: (optional) Dictionary, list of tuples, bytes, or file-like
#     object to send in the body of the :class:`Request`.
# :param json: (optional) json data to send in the body of the :class:`Request`.
# :param \*\*kwargs: Optional arguments that ``request`` takes.
# :return: :class:`Response <Response>` object
# :rtype: requests.Response
# File:      c:\users\hungpq5\appdata\roaming\python\python39\site-packages\requests\api.py
# Type:      function

# %%
url = 'https://techcrunch.com/wp-json/tc/v1/magazine?page=1&_embed=true&cachePrevention=0'
response = requests.get(url)

# %%
response.json()[0].keys()
# Out:
# dict_keys(['id', 'date', 'date_gmt', 'guid', 'modified', 'modified_gmt', 'slug', 'status', 'type', 'link', 'title', 'content', 'excerpt', 'author', 'featured_media', 'comment_status', 'ping_status', 'sticky', 'template', 'format', 'meta', 'categories', 'tags', 'crunchbase_tag', 'tc_stories_tax', 'tc_ec_category', 'tc_event', 'tc_regions_tax', 'jetpack_featured_media_url', 'parsely', 'shortlink', 'parselyMeta', 'rapidData', 'premiumContent', 'premiumCutoffPercent', 'featured', 'subtitle', 'editorialContentProvider', 'tc_cb_mapping', 'associatedEvent', 'event', 'authors', 'hide_featured_image', 'canonical_url', 'primary_category', '_links', '_embedded'])

# %%
data
# Out:
# '{"@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage"},"dateModified":"2023-01-05T02:23:52+00:00","description":"Nearly a year after Sony and Honda shared plans to jointly make and sell electric vehicles, the two companies revealed a prototype under the brand name Afeela. The four-door sedan was driven onstage at CES Wednesday as Kenichiro Yoshida, the CEO of Sony, talked through the company&#8217;s mobility philosophy, which prioritizes building vehicles that have [&hellip;]","speakable":{"@type":"SpeakableSpecification","cssSelector":[".alpha","#speakable-summary"]},"publisher":{"@type":"Organization","name":"TechCrunch","logo":{"@type":"imageObject","url":"https:\\/\\/techcrunch.com\\/wp-content\\/themes\\/techcrunch-2017\\/images\\/logo-json-ld.png","width":"600","height":"60"}}}'

# %%
response.json()[0]['parselyMeta']
# Out:
# {'parsely-title': 'Sony and Honda reveal Afeela, their joint EV brand, at CES',
#  'parsely-link': 'https://techcrunch.com/2023/01/04/sony-and-honda-reveal-afeela-their-joint-ev-brand-at-ces/',
#  'parsely-type': 'post',
#  'parsely-pub-date': '2023-01-05T02:23:52+00:00',
#  'parsely-image-url': 'https://techcrunch.com/wp-content/uploads/2023/01/Honda-Sony-Afeela-CES2023-4.jpeg?w=680',
#  'parsely-author': ['Rebecca Bellan'],
#  'parsely-section': 'Transportation',
#  'parsely-tags': '@post-id:2465033,ces,ces 2023,honda,sony',
#  'parsely-metadata': '{"@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage"},"dateModified":"2023-01-05T02:23:52+00:00","description":"Nearly a year after Sony and Honda shared plans to jointly make and sell electric vehicles, the two companies revealed a prototype under the brand name Afeela. The four-door sedan was driven onstage at CES Wednesday as Kenichiro Yoshida, the CEO of Sony, talked through the company&#8217;s mobility philosophy, which prioritizes building vehicles that have [&hellip;]","speakable":{"@type":"SpeakableSpecification","cssSelector":[".alpha","#speakable-summary"]},"publisher":{"@type":"Organization","name":"TechCrunch","logo":{"@type":"imageObject","url":"https:\\/\\/techcrunch.com\\/wp-content\\/themes\\/techcrunch-2017\\/images\\/logo-json-ld.png","width":"600","height":"60"}}}'}

# %%
for element in response.json():
    print(element['id'])
    print()
# Out:
# 2465033
# 2464751
# 2465031
# 2465029
# 2464075
# 2463175
# 2464961
# 2464604
# 2457917
# 2464588
# 2464279
# 2464867
# 2464718
# 2464852
# 2464750
# 2464023
# 2464706
# 2464559
# 2464545
# 2464377

# %%
print(response.headers)
# Out:
# {'Server': 'ATS', 'Date': 'Thu, 05 Jan 2023 03:00:03 GMT', 'Content-Type': 'application/json; charset=UTF-8', 'Content-Length': '87935', 'X-Robots-Tag': 'noindex', 'Link': '<https://techcrunch.com/wp-json/>; rel="https://api.w.org/"', 'X-Content-Type-Options': 'nosniff', 'Access-Control-Expose-Headers': 'X-WP-Total, X-WP-TotalPages, Link', 'Access-Control-Allow-Headers': 'Authorization, X-WP-Nonce, Content-Disposition, Content-MD5, Content-Type', 'X-WP-Total': '234736', 'X-WP-TotalPages': '11737', 'Cache-Control': 'max-age=60', 'Allow': 'GET', 'X-rq': 'sea1 0 2 9980', 'Content-Encoding': 'gzip', 'Age': '56', 'X-Cache': 'hit', 'Vary': 'Accept-Encoding, Origin', 'Accept-Ranges': 'bytes', 'Strict-Transport-Security': 'max-age=31536000', 'Connection': 'keep-alive', 'Expect-CT': 'max-age=31536000, report-uri="http://csp.yahoo.com/beacon/csp?src=yahoocom-expect-ct-report-only"', 'Referrer-Policy': 'no-referrer-when-downgrade', 'X-XSS-Protection': '1; mode=block', 'X-Frame-Options': 'SAMEORIGIN'}

# %% [markdown]
# ## Hidden APIs

# %% [markdown]
# # 2. Basic HTML

# %% [markdown]
# ## 2.1. HTML concepts
#
# ```html
# <html>
# <head>...</head>
# <body>
# ...
# <form id="loginForm">
# <input name="name" type="text" value="First Name" />
# <input name="name" type="text" value="Last Name" />
# <input name="email" type="text" value="Business Email" />
# <input name="password" type="password" />
# <input name="continue" type="submit" value="Sign Me Up" />
# </form>
# </body>
# </html>
# ```

# %% [markdown]
# ## 2.2. Element locating

# %% [markdown]
# ### ID and class

# %% [markdown]
# ### XPath

# %% [markdown]
# ### CSS selector

# %% [markdown]
# # 3. HTML parser

# %% [markdown]
# # 4. Web driver

# %% [markdown]
# ---
# *&#9829; By Quang Hung x Thuy Linh &#9829;*
