# %%
import tabula
from tabula import read_pdf

# %%
df=read_pdf("sfpc1210.pdf",pages='all',multiple_tables=True)
# Out:
# Got stderr: Jun 13, 2020 2:50:54 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 1.8.0_161
# Jun 13, 2020 2:50:54 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# Jun 13, 2020 2:50:54 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# Jun 13, 2020 2:50:54 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# Jun 13, 2020 2:50:54 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# Jun 13, 2020 2:50:54 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")

# %%
len(df)
# Out:
# 12

# %%
df[0]
# Out:
#                            Tuesday, December 10, 2019  \
# 0                                                 NaN
# 1                                                 NaN
# 2                 Wild, Gulf of Mexico Wild, Mexican,
# 3                                       Domestic No 1
# 4                   Ct/lb Brown White Brown * White *
# 5           <10 14.55-14.65 14.50-14.60 - 14.30-14.50
# 6   <12 13.00-13.10 12.75-12.85 10.50-10.70 10.50-...
# 7         <15 9.35-9.45 8.85-8.95 7.25-7.45 7.15-7.35
# 8       16-20 7.10-7.20 6.85-6.95 6.25-6.45 6.15-6.35
# 9       21-25 6.55-6.65 6.35-6.45 5.50-5.70 5.40-5.60
# 10              26-30 6.25-6.35 5.85-5.95 - 5.15-5.35
# 11                      31-35 5.55-5.65 5.25-5.35 - -
# 12                      36-40 5.00-5.10 4.60-4.70 - -
# 13                      41-50 4.00-4.10 4.20-4.30 - -
# 14                              51-60 3.40-3.50 - - -
# 15               61-70 3.10-3.20 -   *Ex-Warehouse WC
# ...

# %%
df=read_pdf("sfpc1210.pdf",pages=[1], multiple_tables=True,stream=True)
            
            #lattice=True)
# Out:
# Got stderr: Jun 13, 2020 3:10:25 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 1.8.0_161
# Jun 13, 2020 3:10:25 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# Jun 13, 2020 3:10:25 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# Jun 13, 2020 3:10:25 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# Jun 13, 2020 3:10:25 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# Jun 13, 2020 3:10:25 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#                            Tuesday, December 10, 2019  \
# 0                                                 NaN
# 1                                                 NaN
# 2                 Wild, Gulf of Mexico Wild, Mexican,
# 3                                       Domestic No 1
# 4                   Ct/lb Brown White Brown * White *
# 5           <10 14.55-14.65 14.50-14.60 - 14.30-14.50
# 6   <12 13.00-13.10 12.75-12.85 10.50-10.70 10.50-...
# 7         <15 9.35-9.45 8.85-8.95 7.25-7.45 7.15-7.35
# 8       16-20 7.10-7.20 6.85-6.95 6.25-6.45 6.15-6.35
# 9       21-25 6.55-6.65 6.35-6.45 5.50-5.70 5.40-5.60
# 10              26-30 6.25-6.35 5.85-5.95 - 5.15-5.35
# 11                      31-35 5.55-5.65 5.25-5.35 - -
# 12                      36-40 5.00-5.10 4.60-4.70 - -
# 13                      41-50 4.00-4.10 4.20-4.30 - -
# 14                              51-60 3.40-3.50 - - -
# 15               61-70 3.10-3.20 -   *Ex-Warehouse WC
# ...

# %%
top=0.22
left=2.38#2.07
bottom=3.49
right=5.0

# %%
y1=top*72 # convert in to points
x1=left*72
y2=(bottom)*72
x2=(right)*72

# %%
df=read_pdf("sfpc1210.pdf",pages=[1],area=(x1,y1,x2,y2))
#multiple_tables=True,stream=True)

# %%
#df[0].to_csv('test1.csv')

# %%
df[0]
# Out:
#     Ct/lb        Brown        White      Brown *           White *  \
# 0     <10  14.55-14.65  14.50-14.60            -       14.30-14.50
# 1     <12  13.00-13.10  12.75-12.85  10.50-10.70       10.50-10.70
# 2     <15    9.35-9.45    8.85-8.95    7.25-7.45         7.15-7.35
# 3   16-20    7.10-7.20    6.85-6.95    6.25-6.45         6.15-6.35
# 4   21-25    6.55-6.65    6.35-6.45    5.50-5.70         5.40-5.60
# 5   26-30    6.25-6.35    5.85-5.95            -         5.15-5.35
# 6   31-35    5.55-5.65    5.25-5.35            -                 -
# 7   36-40    5.00-5.10    4.60-4.70            -                 -
# 8   41-50    4.00-4.10    4.20-4.30            -                 -
# 9   51-60    3.40-3.50            -            -                 -
# 10  61-70    3.10-3.20            -          NaN  *Ex-Warehouse WC
# 11  71-80            -            -          NaN               NaN
# 12  81-90            -            -          NaN               NaN
#
#         White.1
# ...

# %%
top=3.5
left=2.06
bottom=7.32
right=5.0
y1=top*72 # convert in to points
x1=left*72
y2=(bottom)*72
x2=(right)*72
df=read_pdf("sfpc1210.pdf",pages=[1],area=(x1,y1,x2,y2))
#multiple_tables=True,stream=True)

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#    Unnamed: 0 Unnamed: 1 Farmed Unnamed: 2 Farmed IQF  \
# 0         NaN        NaN  White        NaN      Asian
# 1       Ct/lb     Lat Am    NaN      Asian        EZP
# 2         2-4        NaN    NaN        NaN          -
# 3         4-6        NaN    NaN        NaN          -
# 4         6-8        NaN    NaN        NaN          -
# 5        8-12        NaN    NaN        NaN  8.35-8.45
# 6       13-15        NaN      -  6.30-6.40  6.15-6.25
# 7       16-20  5.20-5.30      -  4.90-5.00  4.90-5.00
# 8       21-25  4.80-4.90      -  4.35-4.45  4.45-4.55
# 9       26-30  4.05-4.15    NaN  3.60-3.70  3.85-3.95
# 10      31-35  3.80-3.90      -  3.35-3.45        NaN
# 11      36-40  3.55-3.65      -  3.20-3.30        NaN
# 12      31-40        NaN    NaN        NaN  3.50-3.60
# 13      41-50  3.40-3.50      -  3.10-3.20  3.40-3.50
# 14      51-60  3.10-3.20    NaN          -  3.25-3.35
# 15      61-70  2.80-2.90    NaN          -          -
# ...

# %%
top=7.32
left=2.06
bottom=8.25
right=5.0
y1=top*72 # convert in to points
x1=left*72
y2=(bottom)*72
x2=(right)*72
df=read_pdf("sfpc1210.pdf",pages=[1],area=(x1,y1,x2,y2))
#multiple_tables=True,stream=True)

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#                Unnamed: 0        Farmed
# 0                     NaN  (HOSO) White
# 1                   Ct/kg     ** Lat Am
# 2                   20-30             -
# 3                   30-40     3.25-3.35
# 4                   40-50   2.95-3.05 +
# 5                   50-60     2.75-2.85
# 6                   60-70     2.50-2.60
# 7                     NaN           NaN
# 8                   70-80     2.25-2.35
# 9                  80-100     2.15-2.25
# 10                    NaN           NaN
# 11  **Ct per kg, $ per lb           NaN

# %%
top=0.2
left=5.49#5.20
bottom=8.51
right=7.81
y1=top*72 # convert in to points
x1=left*72
y2=(bottom)*72
x2=(right)*72
df=read_pdf("sfpc1210.pdf",pages=[1],area=(x1,y1,x2,y2))
#multiple_tables=True,stream=True)

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Ct/lb  Black Tiger       White Unnamed: 0    White.1 Black Tiger.1  \
# 0       6-8            -           -        NaN          -   18.70-18.90
# 1      8-12            -           -        NaN          -   11.80-12.00
# 2     13-15  11.95-12.05  9.90-10.00          +          -     8.85-8.95
# 3     16-20    8.20-8.30   7.35-7.45          +          -     6.85-6.95
# 4     21-25    6.85-6.95   6.25-6.35          +          -     5.65-5.75
# 5     26-30    5.80-5.90   5.70-5.80          +          -     5.00-5.10
# 6     31-40    5.00-5.10   4.95-5.05        NaN  4.65-4.75             -
# 7     41-50    4.80-4.90   4.80-4.90        NaN  4.55-4.65             -
# 8     51-60            -   4.60-4.70        NaN  4.45-4.55             -
# 9     61-70            -   4.20-4.30        NaN  4.30-4.40             -
# 10    71-90            -   4.10-4.20        NaN  4.20-4.30             -
# 11   91-110            -           -        NaN  4.15-4.25             -
# ...
