# %% [markdown]
# Applied Math (4 big ones)
# 1) Numerical methods (summary / index)
#
# You’re right: details live in LA/Calc/Opt, but Applied Math can hold the “unified view.”
#
# Floating point & error
#
# Numerical linear algebra highlights (conditioning, stability)
#
# Numerical integration / differentiation (high level)
#
# Solving ODEs (high level)
#
# Optimization algorithms overview (high level)
#
# Think of this as a map and “what to use when,” not repeating every proof.
#
# 2) Random methods (applied probability)
#
# Rename this slightly to avoid scope creep. Good names:
#
# Stochastic Processes & Simulation
#
# Stochastic Modeling
#
# Randomized Methods
#
# Then split it into two sub-branches so it never becomes a dump:
#
# A) Stochastic processes (models over time)
#
# Markov chains (discrete-time)
#
# Random walks (often a special case / application of Markov chains; can be a subtopic)
#
# Poisson process (and maybe “birth–death / queues” later if you care)
#
# B) Simulation (compute with randomness)
#
# Monte Carlo estimation (integration, expectation)
#
# Variance reduction (only if you use MC seriously)
#
# MCMC (only if/when you need sampling from a hard distribution)
#
# This keeps it sane: “processes” vs “simulation.”
#
# Note: Random walk fits perfectly under Markov chains, but it’s popular enough to also get its own page if you like.
#
# 3) Game theory
#
# Keep it inside Applied Math as you planned (or also as top-level later).
#
# Zero-sum games (minimax vibe)
#
# General-sum games (Nash equilibrium)
#
# Learning in games (regret / best response dynamics) (optional)
# This fits Applied Math because it’s “math for interacting decision-makers,” and it connects naturally to optimization + probability.
#
# 4) Signal processing
#
# Great Applied Math pillar.
#
# Convolution, filtering
#
# Fourier transform / frequency domain
#
# Sampling basics
#
# Spectral viewpoint (ties to linear algebra)
# This stays nicely separated from probability and optimization while still linking to both.
