# %% [markdown]
# - [Textbook](https://faculty.ksu.edu.sa/sites/default/files/rosen_discrete_mathematics_and_its_applications_7th_edition.pdf)
# - [Python](https://colab.research.google.com/drive/1vGYrfTyTM2QF3bVeSj_UStaRKwkTFCCm#scrollTo=aSh0bpboPoVn)
# - [Calculator](https://www.desmos.com/scientific)

# %% [markdown]
# - A connected multigraph with at least two vertices has an Euler circuit if and only if each of its vertices has even degree.
# - A connected multigraph has an Euler path but not an Euler circuit if and only if it has exactly two vertices of odd degree.

# %% [markdown]
# ## 10.3 - Graph Representation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# > **68.** How many nonisomorphic directed simple graphs are there with $n$ vertices, when $n$ is: a) 2? b) 3? c) 4?

# %% [markdown]
# ## 10.4 - Connectivity

# %% [markdown]
# ***
# > **26.** *Find the number of paths between $c$ and $d$ in the graph in Figure 1 of each length from 2 to 7.*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# > **27.** *Find the number of paths from $a$ to $e$ in the directed graph in Exercise 2 of length from 2 to 7.*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# > **28.** *Show that every connected graph with $n$ vertices has at least $n - 1$ edges.*

# %% [markdown]
# ## 10.5 - Euler and Hammington path

# %% [markdown]
# In Exercises 18–23 determine whether the directed graph shown has an Euler circuit. Construct an Euler circuit if one exists. If no Euler circuit exists, determine whether the directed graph has an Euler path. Construct an Euler path if one exists.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 10.6 - Shortest path problems

# %% [markdown]
# ![image.png](attachment:image.png)
