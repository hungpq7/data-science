# %% [markdown]
# <h1><center>Chữa bài tập chương II + III</center></h1>

# %% [markdown]
# # Problem 2.11

# %% [markdown]
# In Sect. 2.7, an interpretation for a model with systematic component $ \mu = E[\log y] = \beta_0 + \beta_1x$ was discussed.
# 1. Use a Taylor series expansion of $\log y$ about $\mu = E[y]$.
# 2. Find the expected value of both sides of this equation, and hence show
# that $E[\log y] ≈ \log E[y] = \log \mu$.
# 3. Using this information, show that an increase in the value of $x$ by 1 is
# associated (approximately) with a change in $\mu$ by a factor of $exp(\beta_1)$.
#
# ---
# Trong phần 2.7, một cách diễn giải cho mô hình với thành phần hệ thống $ \mu=E[log y]=\beta_0 + \beta_1x$ đã được thảo luận.
# 1. Sử dụng khai triển chuỗi Taylor của $\log y$ về $\mu = E[y]$.
# 2. Tìm giá trị kỳ vọng của cả hai vế của phương trình này, và từ đó chứng minh rằng $E[\log y] ≈ \log E[y] = \log \mu$.
# 3. Sử dụng thông tin này để chứng minh rằng khi $x$ tăng thêm 1 đơn vị sẽ liên quan (xấp xỉ) với sự thay đổi trong $\mu$ theo một hệ số nhân là $exp(\beta_1)$.

# %% [markdown]
# ## ***Solution 2.11.1. Sử dụng khai triển chuỗi Taylor của log y về μ = E[y].***

# %% [markdown]
# Công thức khai triển Taylor của một hàm $f(x)$ tại điểm $x_0$ được biểu diễn như sau:
#
#
# $f(x) = \sum_{n=0}^\infty \frac{f^{(n)}(x_0)}{n!} (x-x_0)^n$
#
# <!-- > $= f(x_0) + \frac{f'(x_0)}{1!} (x-x_0) + \frac{f''(x_0)}{2!} (x-x_0)^2 + \frac{f^{(3)}(x_0)}{3!} (x-x_0)^3 + ...$ -->
# > $= f(x_0) + f'(x_0)(x-x_0) + \frac{f''(a)}{2}(x-x_0)^2 + \frac{f^{(3)}(x_0)}{3!}(x-x_0)^3 + ...$
#
# Áp dụng khai triển Taylor với hàm  $\log y$ quanh $\mu$, ta có:
#
# $
# f(y) = \log(y) = f(\mu) + f'(\mu)(y-\mu) + \frac{f''(\mu)}{2!}(y-\mu)^2 + \dots
# $
#
# >>> $= \log(\mu) + \frac{1}{\mu}(y - \mu) - \frac{1}{2\mu^2}(y - \mu)^2 + \dots $

# %% [markdown]
# ## ***Solution 2.11.2. Tìm giá trị kỳ vọng của cả hai vế của phương trình này, và từ đó chứng minh rằng $𝐸[\log𝑦]≈\log𝐸[𝑦]=\log\mu$.***

# %% [markdown]
# Lấy giá trị kỳ vọng \(E\) của hai vế phương trình, ta có:
#
# > $E[\log(y)] = E[log(\mu)] + E[\frac{1}{\mu}(y-\mu)] - E[\frac{1}{2\mu^2}(y-\mu)^2] + ...$
#
# Triển khai từng thành phần:
# 1. Vì $ \mu $ là hằng số, nên $ E[\log(\mu)] = \log(\mu) $.
# 2. Mặt khác $E[y - \mu] = 0$, vì $ \mu = E[y]$
#
# >$=> E\left[\frac{1}{\mu}(y - \mu)\right] = \frac{1}{\mu}E[y - \mu] = 0 $
#
# 3. Hơn nữa, $E[(y - \mu)^2] = var(y)$
#
# >$=> E\left[\frac{-1}{2\mu^2}(y - \mu)^2\right] = \frac{-1}{2\mu^2}E[(y - \mu)^2] = \frac{-1}{2\mu^2} \text{var}(y) $.
#
# Kết quả:
# > $E[\log(y)] = \log(\mu) - \frac{1}{2\mu^2} \text{var}(y) + \dots $
#
# Nói cách khác:
# > $E[\log(y)] \approx \log(\mu)$ (đpcm)

# %% [markdown]
# ## ***Solution 2.11.3. Chứng minh khi $x$ tăng thêm 1 đơn vị, giá trị kỳ vọng $\mu$ sẽ được nhân lên xấp xỉ $e^\beta_1$ lần***

# %% [markdown]
# Biết rằng $E[\log(y)] \approx \log\mu \approx \beta_0 + \beta_1x$
#
# Để xem xét sự thay đổi của $\mu$, ta lấy $e$ mũ cho cả hai vế:
#
# > $e^{\log \mu} = \mu \approx e^{\beta_0 + \beta_1x}$
#
# Xét mô hình tuyến tính:
# $\mu = e^{\beta_0 + \beta_1x}$
#
# Khi $x$ tăng 1 đơn vị, ta có:
# >$\mu_{new} = e^{\beta_0 + \beta_1(x+1)} = e^{\beta_0 + \beta_1x} . e^{\beta_1} = \mu .e^{\beta_1}$
#
# Như vậy, khi $x$ tăng thêm 1 đơn vị, giá trị kỳ vọng $\mu$ sẽ được tăng lên xấp xỉ $e^{\beta_1}$ lần.

# %% [markdown]
# # Problem 2.12

# %% [markdown]
# 2.12. Using R, produce a vector of 30 random numbers y from a standard normal distribution (use rnorm()). Generate a second vector of 30 random numbers x from a standard normal distribution. Find the P -value for testing if the explanatory variable x is significantly related to y using the regression model lm(y ~ x).
#
# Repeat the process a large number of times, say 1000 times. What propor- tion of the P -values are less than 5%? Less than 10%? What is the lesson?
#
# ---
#
# 2.12. Sử dụng R, tạo một vector gồm 30 số ngẫu nhiên y từ phân phối chuẩn (sử dụng hàm rnorm()). Tạo một vector thứ hai gồm 30 số ngẫu nhiên x từ phân phối chuẩn. Tìm giá trị P -value để kiểm tra xem biến x có liên quan đáng kể đến y hay không bằng cách sử dụng mô hình hồi quy lm(y ~ x).
#
# Lặp lại quá trình này nhiều lần, ví dụ 1000 lần. Tính tỷ lệ phần trăm các giá trị P-value nhỏ hơn 5%? Nhỏ hơn 10%? Bài học rút ra là gì?

# %%
# Lặp lại 1000 lần và tính tỷ lệ P-value
set.seed(123)  # Đảm bảo kết quả tái lập
n_iterations <- 1000
p_values <- numeric(n_iterations)

for (i in 1:n_iterations) {
  y <- rnorm(30) # Vector y từ phân phối chuẩn chuẩn
  x <- rnorm(30) # Vector x từ phân phối chuẩn chuẩn
  model <- lm(y ~ x)
  p_values[i] <- summary(model)$coefficients[2, 4]
  #Chọn hàng thứ 2 trong bảng hệ số, tương ứng với biến x (biến độc lập). Chọn cột thứ 4, tức là P-value cho hệ số hồi quy của biến x.
}

# Tính tỷ lệ P-value nhỏ hơn 5% và 10%
prop_less_5 <- mean(p_values < 0.05)
cat("Tỷ lệ P-value nhỏ hơn 5%:", prop_less_5 * 100, "%\n")

prop_less_10 <- mean(p_values < 0.1)
cat("Tỷ lệ P-value nhỏ hơn 10%:", prop_less_10 * 100, "%\n")
# Out:
# Tỷ lệ P-value nhỏ hơn 5%: 5.5 %
# Tỷ lệ P-value nhỏ hơn 10%: 10.7 %

# %%
summary(model)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8021 -0.6180  0.1308  0.5395  2.1499
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.20919    0.18296   1.143    0.263
# x           -0.06953    0.21878  -0.318    0.753
#
# Residual standard error: 1.002 on 28 degrees of freedom
# Multiple R-squared:  0.003594,	Adjusted R-squared:  -0.03199
# F-statistic: 0.101 on 1 and 28 DF,  p-value: 0.753

# %%
hist(p_values, main = "Histogram of P-values",
     xlab = "P-value", col = "lightblue", breaks = 20)
abline(v = 0.05, col = "red", lwd = 2)           # Đường mức ý nghĩa 5%
abline(v = 0.10, col = "red", lwd = 2, lty = 2)  # Đường mức ý nghĩa 10%
# Out:
# Plot with title “Histogram of P-values”

# %% [markdown]
# Bài học rút ra:
# 1. Cần thận trọng với kết quả bị bác bỏ. Khi một giả thuyết gốc bị bác bỏ (p-value thấp hơn mức ý nghĩa), điều đó không đảm bảo kết luận về giả thuyết nghiên cứu là đúng. Để kiểm tra giả thuyết một cách đúng đắn:
#   * Cần kiểm soát nhiều yếu tố trong nghiên cứu (như thiết kế thực nghiệm, điều kiện).
#   * Lặp lại thử nghiệm trong nhiều bối cảnh khác nhau để đảm bảo tính khái quát.
# 2. Số lượng lớn kiểm định có thể dẫn đến bác bỏ sai. Nếu thực hiện nhiều kiểm định (trong trường hợp này là 1000 lần), ngay cả khi không có mối quan hệ thật giữa 𝑥 và 𝑦, một tỷ lệ nhất định các kiểm định vẫn sẽ trả về p-value thấp hơn 0.05 (hoặc 0.10) một cách ngẫu nhiên. Đây chính là sai lầm loại I (false positive).

# %% [markdown]
# # Problem 2.13

# %% [markdown]
# A study [7] exposed sleeping people (males and females) of various ages to four different fire cues (a crackling noise, a shuffling noise, a flickering light, an unpleasant smell), and recorded the response time (in seconds) for the people to wake. Use the partially complete anova table (Table 2.7) to answer the following questions
#
# ---
# Một nghiên cứu [7] đã  nnghiên cứu hững người đang ngủ (nam và nữ) ở nhiều độ tuổi khác nhau tiếp xúc với bốn tín hiệu cháy khác nhau (tiếng nổ lách tách, tiếng xáo trộn, ánh sáng nhấp nháy, mùi khó chịu) và ghi lại thời gian phản ứng (tính bằng giây) để mọi người thức dậy. Sử dụng bảng anova hoàn thành một phần (Bảng 2.7) để trả lời các câu hỏi sau
#
# \
#
# **Bảng 2.7**
#
# | Source of Variation | df | SS |
# |---------------------|----|----|
# | Cue | ? | 117,793|
# | Sex | ? | 2,659 |
# | Age | 3 | 22,850 |
# | Residual | 60 | 177,639 |

# %% [markdown]
# ## ***Solution 2.13.1. Xác định các bậc tự do bị loại khỏi Bảng 2.7.***

# %% [markdown]
# Chúng ta có 4 (4 nhóm) tín hiệu cháy và 2 nhóm giới tính (nam - nữ) (Between Groups). Phương trình cơ bản của chúng ta về bậc tự do cho một yếu tố với $levels = l$ là $df = l-1$.
# \
# Vì vậy, ở đây, $df_{cue} = 4-1=3$ và $df_{sex}=2-1=1$.

# %% [markdown]
# ## ***Solution 2.13.2. Xác định các quan sát được sử dụng để phân tích***

# %% [markdown]
# Chúng ta có tổng 67 bậc tự do, chúng ta có thể sử dụng công thức rằng:
# $df_{total} = n-1$ \
# Do đó, tổng cộng số quan sát sẽ là: $n=df_{total}+1 = 67+1 = 68$.

# %% [markdown]
# ## ***Solution 2.13.3. Tìm ước lượng unbiased của $\sigma^2$***

# %% [markdown]
# $SS_{residual} = \sum_{i=1}^{N} (y_{i} - \hat{y_{i}})^2$

# %% [markdown]
# $\hat{\sigma}^2 = \frac{Residual Sum of Squares (RSS)}{Residual Degrees of Freedom (df)} = \frac{SS_{residual}}{df_{residual}} = \frac{1777639}{60} = 2960.65$

# %% [markdown]
# ## ***Solution 2.13.4. Xác định biến giải thích nào có ý nghĩa thống kê trong việc dự đoán thời gian phản hồi, sử dụng $F-test$ tuần tự.***

# %% [markdown]
# 1. Công thức tính toán
# Mean Square (MS):
# $MS = \frac{SS}{df}$
#
# 2. F-statistic (F):
# $F = \frac{MS_{factor}}{MS_{residual}}$
#
# 3. p-value: Dựa trên phân phối $F$ với $df_{factor}$ và $df_{residual}$.
#
#
# | Source of Variation | df | SS | MS | F | p |
# |---------------------|----|----|----|---|---|
# | Cue | 3 | 117,793 | 39,264.33 | 4.42 | 0.01 |
# | Sex | 1 | 2,659 | 2,659 | 0.90 | 0.35 |
# | Age | 3 | 22,850 | 7,616.67 | 2.57 | 0.06 |
# | Residual | 60 | 177,639 | 2,960.65 | NA | NA |
#
#
#
# ---
# Nhận xét:
# - Biến Cue có ý nghĩa thống kê ($p = 0.01$), cho thấy đây là yếu tố quan trọng trong việc dự đoán thời gian phản hồi.
# - Biến Sex không có ý nghĩa thống kê (
# $p=0.35$), cho thấy giới tính không phải là yếu tố quan trọng.
# - Biến Age có ($p=0.06$), gần đạt mức ý nghĩa nhưng chưa đủ để kết luận đây là yếu tố quan trọng ở mức $α=0.05$.
# - Residual đại diện cho phần sai số không giải thích được bởi các yếu tố đã xét.

# %%
# Giá trị F-statistic và bậc tự do
F_values <- c(4.42, 0.90, 2.57) # Các giá trị F từ bảng
df1 <- c(3, 1, 3)               # Bậc tự do của yếu tố (numerator df)
df2 <- 60                       # Bậc tự do phần dư (denominator df)

# Tính p-value cho từng yếu tố
p_values <- pf(F_values, df1, df2, lower.tail = FALSE)

# Hiển thị kết quả
result <- data.frame(
  Source_of_Variation = c("Cue", "Sex", "Age"),
  df1 = c(3,1,3),
  F_statistic = F_values,
  p_value = p_values
)
print(result)
# Out:
#   Source_of_Variation df1 F_statistic    p_value
# 1                 Cue   3        4.42 0.00712168
# 2                 Sex   1        0.90 0.34658727
# 3                 Age   3        2.57 0.06256922

# %% [markdown]
# # Problem 2.14

# %% [markdown]
# Numerous studies have shown an association between seasonal ambient temperature (in ◦C) and blood pressure (in mm Hg). A study of 574 rural Ghanaian men aged between 18 and 65 studied this relationship [9] (and also included a number of extraneous variables) using a linear regression model, producing the results in Table 2.8.
#
# ---
#
# Nhiều nghiên cứu đã chỉ ra mối liên hệ giữa nhiệt độ môi trường theo mùa (tính bằng ◦C) và huyết áp (tính bằng mm Hg). Một nghiên cứu về 574 nam giới vùng nông thôn Ghana trong độ tuổi từ 18 đến 65 đã nghiên cứu mối quan hệ này [9] (và cũng bao gồm một số biến ngoại lai) bằng cách sử dụng mô hình hồi quy tuyến tính, đưa ra kết quả trong Bảng 2.8.
#
# **Bảng 2.8 Ước tính tham số và lỗi chuẩn trong mô hình hồi quy tuyến tính để ước tính huyết áp tâm thu (tính bằng mm Hg) ở nam giới Ghana trong độ tuổi từ 18 đến 65 (Bài toán 2.14)**
#
# |Explanatory variable|$\hat{\beta}_j$|se($\hat{\beta}_j$)|
# |--------------------|---------------|-------------------|
# |Constant|100.812|13.096|
# |Age(in years|0.332|0.062|
# |Waist circumference (in cm)|0.411|0.090|
# |Alcohol (yes:1; no:0)|-3.003|1.758|
# |Smoking (yes:1; no:0)|-0.362|2.732|
# |Ambient temperature (in ◦C)|-0.521|0.262|

# %% [markdown]
# ##  ***Solution 2.14.1.Tính giá trị $p$ cho từng thành phần trong mô hình và nhận xét.***

# %% [markdown]
# Sử dụng công thức: $$ T = \frac{\hat{𝛽} - 𝛽_0}{se(\hat{𝛽})}$$
#
# Nếu  giả thuyết $H_0$  là đúng, thì $t \sim t(df=n-p', \mu=0, \sigma=se(\hat{\beta}))$; Sau đó tra bảng phân phối $t$ để xác định $p-value$.

# %%
d <- data.frame("Explanatory variable" = c("Constant", "Age", "Waist", "Alcohol", "Smoking", "Temp"),
                "beta" = c(100.812, 0.332, 0.411, -3.003, -0.362, -0.521),
                "se" = c(13.096, 0.062, 0.090, 1.758, 2.732, 0.262))

d
# Out:
#   Explanatory.variable beta    se
# 1 Constant             100.812 13.096
# 2 Age                    0.332  0.062
# 3 Waist                  0.411  0.090
# 4 Alcohol               -3.003  1.758
# 5 Smoking               -0.362  2.732
# 6 Temp                  -0.521  0.262

# %% [markdown]
# ## ***Solution 2.14.2. Sau khi điều chỉnh theo độ tuổi, vòng eo, lượng rượu tiêu thụ và thói quen hút thuốc, hãy mô tả mối quan hệ giữa nhiệt độ môi trường và huyết áp.***

# %% [markdown]
# Tính toán $t-stat$ cho từng loại và mặc định $𝛽_0 = 0$ với mọi trường hợp.

# %%
d$T.stat <- round(d$beta / d$se, 4)
d
# Out:
#   Explanatory.variable beta    se     T.stat
# 1 Constant             100.812 13.096  7.6979
# 2 Age                    0.332  0.062  5.3548
# 3 Waist                  0.411  0.090  4.5667
# 4 Alcohol               -3.003  1.758 -1.7082
# 5 Smoking               -0.362  2.732 -0.1325
# 6 Temp                  -0.521  0.262 -1.9885

# %% [markdown]
# Chúng ta có thể tính gần đúng các giá trị $p$, nhưng chúng ta cần biết bậc tự do. Hãy nhớ rằng bậc tự do được tính bằng:
# $$v= n - p',$$
# trong đó
# - $n$ là số lượng quan sát.
# - $p'$ là số tham số trong mô hình.
#
# Thật không may, câu hỏi này có phần hơi mơ hồ. Chúng ta được biết rằng $n = 574$, và bảng cung cấp cho chúng ta 6 tham số; tuy nhiên, đề bài nói rằng phân tích sử dụng "một số biến phụ (extraneous variables)". Ta không chắc liệu "biến phụ" có bao gồm toàn bộ các biến đã được đưa ra hay có một số biến đã bị loại khỏi bảng. Tuy nhiên, ta sẽ giả định rằng tất cả các biến được cung cấp là toàn bộ tập hợp biến; ngay cả khi không phải vậy, điều này ít có khả năng gây ảnh hưởng đáng kể đến ước lượng của chúng ta.

# %%
df <- 574 - 6

d$p.values <- round(2*(1-pt(abs(d$T.stat), df)),4)

d
# Out:
#   Explanatory.variable beta    se     T.stat  p.values
# 1 Constant             100.812 13.096  7.6979 0.0000
# 2 Age                    0.332  0.062  5.3548 0.0000
# 3 Waist                  0.411  0.090  4.5667 0.0000
# 4 Alcohol               -3.003  1.758 -1.7082 0.0881
# 5 Smoking               -0.362  2.732 -0.1325 0.8946
# 6 Temp                  -0.521  0.262 -1.9885 0.0472

# %% [markdown]
# ## ***Solution 2.14.3. Vẽ đường thẳng mô tả mối quan hệ giữa nhiệt độ môi trường và huyết áp  đối với nam giới 30 tuổi không hút thuốc, uống rượu và có vòng eo là 100 cm. Các tác giả nêu rằng***

# %% [markdown]
# ## ***Solution 2.14.4. Tính khoảng tin cậy 95% cho tham số hồi quy đối với nhiệt độ môi trường.***

# %% [markdown]
# ## ***Solution 2.14.5. Diễn giải mối quan hệ giữa nhiệt độ môi trường và tất cả các biến trong phương trình hồi quy.***

# %% [markdown]
# ## ***Solution 2.14.6. Dự đoán huyết áp trung bình của nam giới Ghana 35 tuổi (không hút thuốc, uống rượu và có vòng eo là 100 cm) khi nhiệt độ môi trường là 30◦C.***

# %% [markdown]
# # Problem 2.15

# %% [markdown]
# 2.15. An experiment was conducted [11] to determine how to maximize Mermaid meadowfoam flower production (Table 2.9; data set: flowers) for extraction as vegetable oil.
#
# **Table 2.9** *The average number of flowers per meadowfoam plant (based on ten seedlings) exposed to various levels of lighting at two different times: at photoperiodic floral induction (PFI) or 24 days before PFI. These data are consistent with the results in [11]*
#
# ---
#
# 2.15. Một thí nghiệm đã được thực hiện [11] để xác định cách tối đa hóa sản lượng hoa của cây cỏ đồng tiên Mermaid (Mermaid meadowfoam) (Bảng 2.9; tập dữ liệu: flowers) nhằm mục đích chiết xuất dầu thực vật.
#
# **Bảng 2.9** Số lượng hoa trung bình trên mỗi cây cỏ đồng tiên (dựa trên mười cây con) khi tiếp xúc với các mức độ ánh sáng khác nhau vào hai thời điểm: tại giai đoạn cảm ứng hoa theo chu kỳ ánh sáng (PFI) hoặc 24 ngày trước giai đoạn PFI. Các dữ liệu này phù hợp với kết quả trong [11].
#
#
# \
#
# | Timing  | LI|       |       |       |       |       |       |
# |---------|------------------------------------------------------------------|-------|-------|-------|-------|-------|-------|
# |         | 150   | 300   | 450   | 600   | 750   | 900   |
# | At PFI  | 62.4  | 77.1  | 55.7  | 54.2  | 49.5  | 62.0  | 39.3  | 45.3  | 30.9  | 45.2  | 36.8  | 42.2  |
# | Before PFI | 77.7  | 75.4  | 68.9  | 78.2  | 57.2  | 70.9  | 62.9  | 52.1  | 60.2  | 45.6  | 52.5  | 44.1  |
#
# *LI* stands for "Light intensity (in $\mu \text{mol} m^{-2} s^{-1}$)
#
# \

# %%
install.packages("GLMsData")
library(GLMsData)

# Load the flowers dataset
data(flowers)
d <- flowers

# Show structure of the dataset
str(d)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# 'data.frame':	24 obs. of  3 variables:
#  $ Flowers: num  62.4 77.1 77.7 75.4 55.7 54.2 68.9 78.2 49.5 62 ...
#  $ Light  : int  150 150 150 150 300 300 300 300 450 450 ...
#  $ Timing : Factor w/ 2 levels "Before","PFI": 2 2 1 1 2 2 1 1 2 2 ...

# %%
# Summary statistics of the data
summary(d)

# Check the relationship between the variables
table(d$Timing, d$Light)  # Create a distribution table for the Timing and Light factors
# Out:
#     Flowers          Light        Timing
#  Min.   :30.90   Min.   :150   Before:12
#  1st Qu.:45.27   1st Qu.:300   PFI   :12
#  Median :54.95   Median :525
#  Mean   :56.10   Mean   :525
#  3rd Qu.:64.40   3rd Qu.:750
#  Max.   :78.20   Max.   :900
#
#          150 300 450 600 750 900
#   Before   2   2   2   2   2   2
#   PFI      2   2   2   2   2   2

# %% [markdown]
# ## ***Solution 2.15.1. Vẽ biểu đồ số lượng hoa trung bình trên mỗi cây theo cường độ ánh sáng, phân biệt hai thời điểm. Bình luận.***

# %%
library(ggplot2)

ggplot(d, aes(x = Light, y = Flowers, color = Timing)) +
  geom_point() +  # Plot the data points
  geom_smooth(method = "lm", aes(group = Timing), se = FALSE) +  # Add linear regression line for each Timing group
  labs(title = "Average Number of Flowers vs. Light Intensity",
       x = "Light Intensity",
       y = "Average Number of Flowers per Plant") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# **Nhận xét:**
# - ***PFI*** có sự giảm số hoa mạnh mẽ hơn khi cường độ ánh sáng tăng, trong khi ở ***Before***, cây dường như có khả năng phát triển hoa tốt hơn dù có ánh sáng mạnh hơn.
# - Phản ánh mối quan hệ nghịch đảo giữa cường độ ánh sáng và số hoa trung bình, nghĩa là khi cường độ ánh sáng tăng thì số hoa trung bình giảm ⇒ Cường độ ánh sáng mạnh hơn có thể không thúc đẩy sự hình thành hoa mà còn làm giảm số hoa trung bình, đặc biệt là ở nhóm cây trong điều kiện ***PFI.***
#
# ⇒ Kết luận:  Timing là một yếu tố quan trọng ảnh hưởng đến cách cây phát triển dưới các mức ánh sáng khác nhau.

# %% [markdown]
# ## ***Solution 2.15.2. Nếu một mô hình có thành phần $Flowers \sim Light + Timing$ được sử dụng, thành phần hệ thống này ám chỉ mối quan hệ giữa các biến như thế nào?***

# %% [markdown]
# Mô hình này có nghĩa là số hoa (Flowers) được mô hình hóa dựa trên sự cộng tác giữa cường độ ánh sáng (Light) và thời gian (Timing). Mô hình này giả định rằng mối quan hệ giữa số hoa và cường độ ánh sáng là độc lập với thời gian (Timing) và ngược lại. Điều này có nghĩa là mỗi yếu tố Light và Timing đóng góp vào sự thay đổi số hoa một cách riêng biệt, không có sự phụ thuộc lẫn nhau giữa chúng.
#
# Cụ thể, mô hình này có thể được biểu diễn dưới dạng:
#
# $$
# \textit{Flowers} = \alpha + \beta_L \cdot \textit{Light} + \beta_T \cdot \textit{Timing}
# $$
#
# Trong đó:
# - α là hằng số
# - $\beta_L$ là hệ số tác động của cường độ ánh sáng.
# - $\beta_T$ là hệ số tác động của thời gian Timing.
#
# Mô hình này giả định rằng sự thay đổi trong số hoa có thể được giải thích hoàn toàn bởi cường độ ánh sáng và thời gian một cách độc lập, nghĩa là không có sự tương tác giữa chúng.

# %%
## Linear model with Light and Timing (no interaction)
model1 <- lm(Flowers ~ Light + Timing, data = d)

# # Summarize the model results
summary(model1)
# Out:
# Call:
# lm(formula = Flowers ~ Light + Timing, data = d)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -10.040  -3.930  -1.819   5.587  11.866
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  83.399167   3.289525  25.353  < 2e-16 ***
# Light        -0.040490   0.005157  -7.851 1.11e-07 ***
# TimingPFI   -12.091667   2.642210  -4.576 0.000164 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.472 on 21 degrees of freedom
# Multiple R-squared:  0.7973,	Adjusted R-squared:  0.778
# F-statistic: 41.29 on 2 and 21 DF,  p-value: 5.279e-08

# %% [markdown]
# ## ***Solution 2.15.3. Nếu một mô hình có thành phần $Flowers \sim Light \times Timing$ được sử dụng, thành phần hệ thống này ám chỉ mối quan hệ giữa các biến như thế nào?***

# %% [markdown]
# Mô hình `Flowers ~ Light * Timing` mô tả mối quan hệ giữa số hoa (Flowers), cường độ ánh sáng (Light), và thời gian (Timing). Dấu (\*) trong mô hình này không chỉ bao gồm các tác động riêng biệt của **Light** và **Timing**, mà còn chỉ ra sự **tương tác** giữa chúng. Điều này có nghĩa là sự ảnh hưởng của Light lên số hoa có thể khác biệt tùy vào Timing, và ngược lại.

# %% [markdown]
# $$
# \text{Flowers} = \alpha + \beta_L \cdot \text{Light} + \beta_T \cdot \text{Timing} + \beta_{LT} \cdot \text{Light} \cdot \text{Timing}
# $$
#
# - $\alpha$: Hằng số (Intercept).
# - $\beta_L$: Hệ số tác động của Light.
# - $\beta_T$: Hệ số tác động của Timing.
# - $\beta_{LT}$: Hệ số tác động của mối quan hệ tương tác giữa Light và Timing.

# %%
# # Linear model with interaction between Light and Timing
# model2 <- lm(Flowers ~ Light * Timing, data = d)

# # Summarize the model results
# summary(model2)

# %% [markdown]
# ## ***Solution 2.15.4. Fit hai mô hình hồi quy tuyến tính với các thành phần hệ thống đã nêu. Mô hình nào mang lại kết quả ổn định hơn?***

# %% [markdown]
# Fit Linear model trong câu 2.15.2.

# %%
# Linear model with Light and Timing (no interaction)
model1 <- lm(Flowers ~ Light + Timing, data = d)

# Summarize the model results
summary(model1)
# Out:
# Call:
# lm(formula = Flowers ~ Light + Timing, data = d)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -10.040  -3.930  -1.819   5.587  11.866
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  83.399167   3.289525  25.353  < 2e-16 ***
# Light        -0.040490   0.005157  -7.851 1.11e-07 ***
# TimingPFI   -12.091667   2.642210  -4.576 0.000164 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.472 on 21 degrees of freedom
# Multiple R-squared:  0.7973,	Adjusted R-squared:  0.778
# F-statistic: 41.29 on 2 and 21 DF,  p-value: 5.279e-08

# %% [markdown]
# Fit Linear Model trong câu 2.15.3.

# %%
# Linear model with interaction between Light and Timing
model2 <- lm(Flowers ~ Light * Timing, data = d)

# Summarize the model results
summary(model2)
# Out:
# Call:
# lm(formula = Flowers ~ Light * Timing, data = d)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -9.919 -3.991 -1.698  5.446 11.664
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      83.116667   4.364515  19.044 2.75e-14 ***
# Light            -0.039952   0.007471  -5.347 3.11e-05 ***
# TimingPFI       -11.526667   6.172356  -1.867   0.0766 .
# Light:TimingPFI  -0.001076   0.010566  -0.102   0.9199
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.63 on 20 degrees of freedom
# Multiple R-squared:  0.7974,	Adjusted R-squared:  0.767
# F-statistic: 26.24 on 3 and 20 DF,  p-value: 3.898e-07

# %%
AIC(model1, model2)
# Out:
#        df AIC
# model1 4  162.5441
# model2 5  164.5316

# %% [markdown]
# ## ***Solution 2.15.5. Sử dụng tất cả các trọng số trước là $w_i = 10$ cho mọi $i$. Điều gì sẽ khác nếu không định nghĩa trọng số trước (khi đó `R` giả định $w_i = 1$)?***

# %%
summary(model1)
# Out:
# Call:
# lm(formula = Flowers ~ Light + Timing, data = d)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -10.040  -3.930  -1.819   5.587  11.866
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  83.399167   3.289525  25.353  < 2e-16 ***
# Light        -0.040490   0.005157  -7.851 1.11e-07 ***
# TimingPFI   -12.091667   2.642210  -4.576 0.000164 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.472 on 21 degrees of freedom
# Multiple R-squared:  0.7973,	Adjusted R-squared:  0.778
# F-statistic: 41.29 on 2 and 21 DF,  p-value: 5.279e-08

# %%
# Model 2: all prior weights as  wi=10  for all  i
m1w <- lm(Flowers ~ Light + Timing, data = d, weights = rep(10, nrow(d)))
summary(m1w)
# Out:
# Call:
# lm(formula = Flowers ~ Light + Timing, data = d, weights = rep(10,
#     nrow(d)))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -31.748 -12.428  -5.753  17.668  37.524
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  83.399167   3.289525  25.353  < 2e-16 ***
# Light        -0.040490   0.005157  -7.851 1.11e-07 ***
# TimingPFI   -12.091667   2.642210  -4.576 0.000164 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 20.47 on 21 degrees of freedom
# Multiple R-squared:  0.7973,	Adjusted R-squared:  0.778
# F-statistic: 41.29 on 2 and 21 DF,  p-value: 5.279e-08

# %%
AIC(model1, m1w)
# Out:
#        df AIC
# model1 4  162.5441
# m1w    4  162.5441

# %% [markdown]
# **Kết luận**: Không có sự khác biệt

# %% [markdown]
# ## ***Solution 2.15.6. Vẽ thành phần hệ thống của mô hình hồi quy được ưa chuộng lên dữ liệu.***

# %%
# MODEL 1
#m1 <- lm(Flowers ~ Light + Timing, data = d)

plot(Flowers ~ Light, data = d[d$Timing == "Before",],
     main = "Model 1",
     xlab = "Light indensity", ylab = "Average Number of Flowers per Plant",
     col = "blue", pch = 19)

# Plot "PFI"
points(Flowers ~ Light, data = d[d$Timing == "PFI",],
       col = "red", pch = 19)

# BPFI
abline(coef(model1)[1], coef(model1)[2], lty = 2, col = "blue")

# PFI
abline(coef(model1)[1] + coef(model1)[3], coef(model1)[2], lty = 1, col = "red")
# Out:
# Plot with title “Model 1”

# %% [markdown]
# ## ***Solution 2.15.7. Diễn giải mô hình***

# %% [markdown]
# Mô hình hồi quy tuyến tính giữa Flowers, Light, và Timing chỉ ra rằng:
# - Light có ảnh hưởng giảm dần đến số lượng hoa (Flowers), và tác động này là đồng nhất dưới cả hai điều kiện thời gian Before và RFI. Điều này có nghĩa là số lượng hoa giảm đều khi cường độ ánh sáng tăng lên, không phụ thuộc vào nhóm thời gian.
# - Timing cũng có ảnh hưởng đáng kể đến số lượng hoa, với nhóm RFI cho kết quả ít hoa hơn so với nhóm Before. Điều này chỉ ra rằng yếu tố thời gian, cụ thể là khi được phân loại là RFI, có tác động ức chế đối với sự phát triển của hoa so với điều kiện Before.
# **→ Mô hình này cho thấy rằng ánh sáng và thời gian đều có ảnh hưởng riêng biệt đến số lượng hoa.**

# %% [markdown]
# # Problem 2.16

# %% [markdown]
# 2.16. A study of babies [1] hypothesized that babies would take longer to
# learn to crawl in colder months because the extra clothing restricts their
# movement. From 1988–1991, the babies’ first crawling age and the average
# monthly temperature six months after birth *(when “infants presumably enter the window of locomotor readiness”; p. 72)* were recorded. The parents reported the birth month, and age when their baby first crept or crawled a distance of four feet in one minute. Data were collected at the University of Denver Infant Study Center on 208 boys and 206 girls, and summarized by the birth month (Table 2.10; data set: crawl).
#
# ---
#
# 2.16. Một nghiên cứu đã giả thuyết rằng trẻ sơ sinh sẽ mất nhiều thời gian hơn để học bò vào những tháng lạnh hơn vì quần áo dày hạn chế khả năng vận động. Trong giai đoạn 1988–1991, độ tuổi bắt đầu bò của trẻ sơ sinh và nhiệt độ trung bình hàng tháng sáu tháng sau khi sinh (thời điểm "trẻ sơ sinh có khả năng sẵn sàng vận động"; tr. 72) đã được ghi nhận.
#
# Cha mẹ của trẻ cung cấp thông tin về tháng sinh và độ tuổi khi trẻ bắt đầu bò hoặc bò được khoảng cách bốn feet trong vòng một phút. Dữ liệu được thu thập tại Trung tâm Nghiên cứu Trẻ sơ sinh của Đại học Denver, bao gồm 208 bé trai và 206 bé gái, và được tóm tắt theo tháng sinh (Bảng 2.10; tập dữ liệu: crawl).
#
# 1. Vẽ biểu đồ dữ liệu. Những giả định nào có thể bị vi phạm?
# 2. Giải thích tại sao mô hình hồi quy có trọng số là phù hợp với dữ liệu.
# 3. Khớp một mô hình hồi quy tuyến tính có trọng số với dữ liệu và diễn giải các hệ số hồi quy.
# 4. Kiểm định chính thức giả thuyết mà các nhà nghiên cứu đã đưa ra.
# 5. Tìm khoảng tin cậy 90% cho hệ số góc của đường hồi quy được khớp, và diễn giải.
# 6. Khớp mô hình hồi quy không trọng số, sau đó vẽ cả hai đường hồi quy trên biểu đồ dữ liệu. Nhận xét sự khác biệt.
# 7. Tính khoảng tin cậy 95% cho các giá trị được khớp từ đường hồi quy có trọng số, và vẽ các khoảng tin cậy này trên biểu đồ.
# 8.Diễn giải mô hình.

# %% [markdown]
# <a href="https://colab.research.google.com/drive/1zpBJ_F7RUFMmkTVaWHcP398a0gRs3-sR?usp=sharing#scrollTo=YiJa6J7CK7zG">Solution here</a>

# %%
install.packages("GLMsData")
library(GLMsData)

data(crawl)
d <- crawl
d
# ?crawl
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#    BirthMonth Age   SD   SampleSize Temp
# 1  January    29.84 7.08 32         66
# 2  February   30.52 6.96 36         73
# 3  March      29.70 8.33 23         72
# 4  April      31.84 6.21 26         63
# 5  May        28.58 8.07 27         52
# 6  June       31.44 8.10 29         39
# 7  July       33.64 6.91 21         33
# 8  August     32.82 7.61 45         30
# 9  September  33.83 6.93 38         33
# 10 October    33.35 7.29 44         37
# 11 November   33.38 7.42 49         48
# 12 December   32.32 5.71 44         57

# %% [markdown]
# **Bảng 2.10:** cung cấp thông tin về tháng sinh và độ tuổi khi trẻ bắt đầu bò hoặc bò được khoảng cách bốn feet trong vòng một phút. Dữ liệu được thu thập tại Trung tâm Nghiên cứu Trẻ sơ sinh của Đại học Denver, bao gồm 208 bé trai và 206 bé gái, và được tóm tắt theo tháng sinh.
#
# **Nhận Xét**:
#   - Birth Month: Tháng sinh
#   - Age: Tuổi trung bình bắt đầu bò (tuần)
#   - SD: Kích thước mẫu
#   - Nhiệt độ trung bình 6 tháng sau khi sinh (°F)

# %% [markdown]
# ## ***Solution 2.16.1. Vẽ biểu đồ dữ liệu. Những giả định nào có thể bị vi phạm?***

# %%
par(mfrow=c(2,1), mar=c(1,1,1,1))

for(i in 1:2){
  sim_dat <- list()
  for(r in 1:nrow(d)){
    sim_dat[[r]] <- rnorm(n=d[r, "SampleSize"], mean=d[r, "Age"], sd=d[r, "SD"])
  }
  plot(Age ~ Temp, data=d, ylim=c(0, 60), xlim=c(25, 75), pch=19)
  segments(x0=d$Temp, y0=d$Age+(d$SD), x1=d$Temp, y1=d$Age-(d$SD), col="black")
  for(r in 1:length(sim_dat)){
    temp_values <- rep(d[r, "Temp"], length(sim_dat[[r]]))
    jittered_temp <- jitter(temp_values, amount = 2.5)
    points(sim_dat[[r]] ~ jittered_temp, col="grey")
  }
  points(d$Temp, d$Age, pch=19)
  segments(x0=d$Temp, y0=d$Age+(d$SD), x1=d$Temp, y1=d$Age-(d$SD), col="black")
}
# Out:
# plot without title

# %% [markdown]
# Trong nghiên cứu trẻ sơ sinh này, các nhà nghiên cứu sử dụng hồi quy tuyến tính để xem liệu có mối liên hệ nào giữa tuổi bắt đầu bò (Age) và nhiệt độ trung bình sau 6 tháng sinh (Temp). Một số giả định quan trọng cần được kiểm tra trong mô hình hồi quy thông thường bao gồm:
#
# * Phương sai đồng nhất (Homoscedasticity): Phương sai của tuổi bắt đầu bò (Age) cần phải đồng đều với mọi giá trị của nhiệt độ trung bình (Temp). Điều này nghĩa là sai số không được thay đổi đáng kể giữa các nhóm nhiệt độ khác nhau.
#
# * Phân phối chuẩn của phần dư (Residuals): Sai số giữa giá trị dự đoán và giá trị thực tế cần phải phân phối chuẩn.
#
# Trong trường hợp này, dường như phương sai của Age thay đổi đối với các giá trị khác nhau của Temp, dẫn đến vi phạm giả định về phương sai đồng nhất. Điều này có thể thấy rõ hơn khi quan sát các tập dữ liệu mô phỏng.

# %% [markdown]
# ## ***Solution 2.16.2. Giải thích tại sao mô hình hồi quy có trọng số là phù hợp với dữ liệu.***

# %% [markdown]
#   - Kích thước mẫu khác nhau giữa các tháng sinh (cột SampleSize).
#   - Khi kích thước mẫu lớn hơn, độ tin cậy của giá trị trung bình cao hơn. Do đó, nên sử dụng hồi quy có trọng số, với trọng số tỷ lệ thuận với kích thước mẫu.

# %% [markdown]
# ## ***Solution 2.16.3. Khớp một mô hình hồi quy tuyến tính có trọng số với dữ liệu và diễn giải các hệ số hồi quy.***

# %%
m <- lm(Age ~ Temp, data=d)
summary(m)
(m_confint <- round(confint(m, level=0.95)["Temp",],4))
print("#--------------------------------------------------------------------------")
m_wtd1 <- lm(Age ~ Temp, weights=SD, data=d)
summary(m_wtd1)
(m_wtd1_confint <- round(confint(m_wtd1, level=0.95)["Temp",],4))
print("#--------------------------------------------------------------------------")
m_wtd2 <- lm(Age ~ Temp, weights=SampleSize, data=d)
summary(m_wtd2)
(m_wtd2_confint <- round(confint(m_wtd2, level=0.95)["Temp",],4))
# Out:
# Call:
# lm(formula = Age ~ Temp, data = d)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.0556 -0.5712  0.5221  0.8029  1.4334
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 35.67806    1.31753  27.080 1.09e-10 ***
# Temp        -0.07774    0.02510  -3.097   0.0113 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.319 on 10 degrees of freedom
# Multiple R-squared:  0.4896,	Adjusted R-squared:  0.4386
# F-statistic: 9.592 on 1 and 10 DF,  p-value: 0.01131
#   2.5 %  97.5 %
# -0.1337 -0.0218
# [1] "#--------------------------------------------------------------------------"
# Call:
# lm(formula = Age ~ Temp, data = d, weights = SD)
#
# Weighted Residuals:
#    Min     1Q Median     3Q    Max
# -8.444 -1.366  1.597  2.238  4.121
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 35.64533    1.33792   26.64 1.28e-10 ***
# ...

# %%
new_data <- data.frame(Temp = seq(25, 75, length.out = 100))
predictions_m <- predict(m, newdata = new_data, interval = "confidence", type="response", level = 0.95)
predictions_m_wtd1 <- predict(m_wtd1, newdata = new_data, interval = "confidence", type="response", level = 0.95)
predictions_m_wtd2 <- predict(m_wtd2, newdata = new_data, interval = "confidence", type="response", level = 0.95)


par(mfrow=c(1,1))

for(i in 1:1){
  sim_dat <- list()
  for(r in 1:nrow(d)){
    sim_dat[[r]] <- rnorm(n=d[r, "SampleSize"], mean=d[r, "Age"], sd=d[r, "SD"])
  }
  plot(Age ~ Temp, data=d, ylim=c(0, 60), xlim=c(25, 75), pch=19)
  segments(x0=d$Temp, y0=d$Age+(d$SD), x1=d$Temp, y1=d$Age-(d$SD), col="black")
  for(r in 1:length(sim_dat)){
    temp_values <- rep(d[r, "Temp"], length(sim_dat[[r]]))
    jittered_temp <- jitter(temp_values, amount = 2.5)
    points(sim_dat[[r]] ~ jittered_temp, col="grey")
  }
  points(d$Temp, d$Age, pch=19)
  segments(x0=d$Temp, y0=d$Age+(d$SD), x1=d$Temp, y1=d$Age-(d$SD), col="black")

  abline(m, col="red", lty=1, lwd=3)
  polygon(c(new_data$Temp, rev(new_data$Temp)),
          c(predictions_m[, "lwr"], rev(predictions_m[, "upr"])),
          col = rgb(1, 0, 0, 0.2), border = NA)

  abline(m_wtd1, col="green", lty=2, lwd=2)
  polygon(c(new_data$Temp, rev(new_data$Temp)),
          c(predictions_m_wtd1[, "lwr"], rev(predictions_m_wtd1[, "upr"])),
          col = rgb(0, 1, 0, 0.2), border = NA)

  abline(m_wtd2, col="blue", lty=3, lwd=1)
  polygon(c(new_data$Temp, rev(new_data$Temp)),
          c(predictions_m_wtd2[, "lwr"], rev(predictions_m_wtd2[, "upr"])),
          col = rgb(0, 0, 1, 0.2), border = NA)
}
# Out:
# plot without title

# %% [markdown]
# # Problem 2.17

# %% [markdown]
# 2.17. For a sample of 64 grazing Merino castrated male sheep (wethers) [5,
# 14, 17], the daily energy requirements and weight was recorded (Table 2.11;
# data set: sheep).
# 1. Fit a linear regression model to model the daily energy requirement from
# the weight.
# 2. Plot the data, plus the systematic component of the fitted model and the
# 95% confidence intervals about the fitted values.
# 3. Interpret the model.
# 4. Which assumptions, if any, appear to be violated? Explain.
#
# **Table 2.11** *The energy requirements (in Mcal/day) and weight (in kg) for a sample of 64 Merino wethers*
#
# | Weight | Energy | Weight | Energy | Weight | Energy | Weight | Energy | Weight | Energy | Weight | Energy |
# |-------------|--------------------|-------------|--------------------|-------------|--------------------|-------------|--------------------|-------------|--------------------|-------------|--------------------|
# | 22.1        | 1.31               | 25.1        | 1.00               | 25.7        | 1.20               | 25.9        | 1.36               | 26.2        | 1.27               | 27.0        | 1.41               |
# | 27.0        | 1.46               | 30.0        | 1.23               | 30.2        | 1.01               | 30.6        | 1.12               | 33.2        | 1.25               | 33.2        | 1.32               |
# | 33.2        | 1.47               | 33.9        | 1.03               | 33.8        | 1.46               | 34.3        | 1.14               | 34.9        | 1.00               | 42.6        | 1.81               |
# | 43.7        | 1.73               | 44.9        | 1.93               | 49.0        | 1.78               | 49.2        | 2.53               | 51.8        | 1.87               | 51.8        | 1.92               |
# | 52.5        | 1.65               | 52.6        | 1.70               | 53.3        | 2.22               | 51.8        | 1.46               | 53.3        | 1.26               | 27.6        | 1.39               |
# | 28.4        | 1.27               | 28.9        | 1.74               | 29.3        | 1.54               | 29.7        | 1.44               | 31.0        | 1.47               | 31.9        | 1.50               |
# | 32.0        | 1.34               | 32.6        | 1.75               | 33.1        | 1.46               | 34.2        | 1.59               | 44.4        | 3.33               | 44.6        | 2.25               |
# | 52.1        | 2.67               | 52.4        | 2.28               | 52.7        | 3.15               | 53.1        | 2.73               | 52.6        | 3.73               | 46.7        | 2.21               |
# | 31.8        | 1.39               | 36.1        | 1.79               | 28.6        | 2.13               | 29.2        | 1.80               | 26.2        | 1.05               | 45.9        | 2.36               |
# | 36.8        | 2.31               | 34.4        | 1.85               | 34.4        | 1.63               | 26.4        | 1.27               | 27.5        | 0.94               |
#
# \
#
# ---
#
# Một mẫu gồm 64 con cừu đực bị thiến (Merino wethers) được ghi nhận về nhu cầu năng lượng hàng ngày và cân nặng (Bảng 2.11; tập dữ liệu: sheep).
#
# 1. Xây dựng mô hình hồi quy tuyến tính để dự đoán nhu cầu năng lượng hàng ngày dựa trên cân nặng.
# 2. Vẽ biểu đồ dữ liệu, bao gồm thành phần hệ thống (systematic component) của mô hình đã khớp và khoảng tin cậy 95% cho các giá trị dự đoán.
# 3. Diễn giải mô hình.
# 4. Những giả định nào của mô hình, nếu có, bị vi phạm? Giải thích.

# %% [markdown]
# <a href = "https://colab.research.google.com/drive/1zZwkbChOnvEcJAydUJ3cnQjI8fNlvfSs?usp=sharing">Solution here</a>

# %% [markdown]
# # Problem 2.18

# %% [markdown]
# 2.18. Children were asked to build towers out of cubical and cylindrical
# blocks as high as they could [8, 12], and the number of blocks used and
# the time taken were recorded (Table 2.12; data set: blocks). In this Problem, we focus on the time taken to build the towers. (The number of blocks used to build towers is studied in Problem 10.19.)
#
# ---
#
# 2.18. Trẻ em được yêu cầu xây tháp bằng các khối hình lập phương và hình trụ cao nhất có thể [8, 12].
#
# Số lượng khối được sử dụng và thời gian hoàn thành đã được ghi nhận (Bảng 2.12; tập dữ liệu: blocks). Trong bài toán này, chúng ta tập trung vào thời gian để xây dựng tháp. (Số lượng khối được sử dụng để xây tháp sẽ được nghiên cứu trong Bài toán 10.19.)

# %% [markdown]
# <a href = "https://colab.research.google.com/drive/1zpBJ_F7RUFMmkTVaWHcP398a0gRs3-sR?usp=sharing">Solution here</a>

# %% [markdown]
# # Problem 2.19

# %% [markdown]
# 2.19. The data in Table 2.13 (data set: sharpener) come from a study to
# make a point
#
# ---
#
# 2.19. Dữ liệu trong Bảng 2.13 (tập dữ liệu: sharpener) xuất phát từ một nghiên cứu nhằm minh họa một điểm.

# %% [markdown]
# 1. Sử dụng quy trình hồi quy tiến (forward regression procedure) (mục 2.12.2, trang 73), tìm một mô hình hồi quy tuyến tính phù hợp (không tương tác) để dự báo y từ biến giải thích, dựa theo tiêu chí AIC.
# * Tiêu chí AIC (Akaike Information Criterion) là tiêu chí dùng để đánh giá mô hình thống kê, giúp đảm bảo mô hình phù hợp nhất với dữ liệu, tránh hiện tượng overfit (mục 2.11, trang 70).
# * Công thức $AIC = nlog(RSS/n) +2p'$. Trong đó $p'$ là tham số phạt (penalty). Mô hình có AIC càng thấp càng tốt.
# <br><br>
# * Hồi quy tiến là một phương pháp tự động xây dựng mô hình, bằng việc lần lượt thêm từng biến giải thích vào mô hình. Nếu việc thêm biến giải thích giúp làm tăng ý nghĩa mô hình, biến đó sẽ được giữ lại và tiếp tục thêm các biến khác.
# * Phương pháp này sử dụng tiêu chí AIC để lựa chọn mô hình, mô hình có AIC tốt nhất (có điểm thấp nhất) sẽ được chọn.

# %%
# Cài đặt bộ dữ liệu sharpener
install.packages('GLMsData')
data("sharpener", package = "GLMsData")

sharpener
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#    Y     X1   X2   X3   X4   X5   X6   X7   X8   X9   X10
# 1   9.87 0.64 0.22 0.83 0.41 0.64 0.88 0.22 0.41 0.38 0.02
# 2   8.86 0.16 0.55 0.71 0.25 0.61 0.68 0.93 0.95 0.15 0.00
# 3   7.82 0.14 0.00 0.97 0.54 0.25 0.46 0.71 0.90 0.13 0.18
# 4  10.77 0.53 0.45 0.80 0.54 0.84 0.39 0.16 0.06 0.72 0.90
# 5   9.53 0.14 0.52 0.13 0.91 0.15 0.52 0.09 0.26 0.12 0.51
# 6   9.60 0.27 0.83 0.22 0.93 0.53 0.58 0.69 0.41 0.85 0.13
# 7  11.04 0.43 0.29 0.57 0.21 0.59 0.03 0.63 0.22 0.40 0.61
# 8   8.94 0.77 0.32 0.30 0.95 0.74 0.86 0.24 0.89 0.16 0.22
# 9   9.96 0.91 0.12 0.16 0.73 0.81 0.20 0.63 0.45 1.00 0.41
# 10 11.27 0.42 0.09 0.40 0.78 0.33 0.86 0.55 0.94 0.64 0.94
# 11 10.35 0.73 0.01 0.45 0.13 0.63 0.70 0.03 0.57 0.20 0.86
# 12  9.57 0.22 0.67 0.44 0.65 0.02 0.15 0.35 0.01 0.81 0.65
# 13  9.72 0.21 0.81 0.46 0.05 0.54 0.79 0.19 0.52 0.78 0.45
# 14 10.67 0.91 0.56 0.78 0.82 0.08 0.47 0.88 0.92 0.05 0.84
# ...

# %% [markdown]
# Sử dụng lệnh step(), với tham số direction = "forward" cho hồi quy tiến, tham số cho tiêu chí AIC đã được cài đặt mặc định (với k = 2)
#
# ```
# step(min.model, direction = "forward", scope = list(lower = min.model, upper = max.model))
# ```

# %%
# đặt mô hình ít biến giải thích nhất có thể làm mức tối thiểu
min.model <- lm(Y ~ 1, data = sharpener)

# đặt mô hình nhiều biến giải thích nhất có thể làm mức tối đa
max.model <- lm(Y ~ X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10, data = sharpener)

auto.forward <- step(min.model, direction = "forward", scope = list(lower = min.model, upper = max.model))
summary(auto.forward)
# Out:
# Start:  AIC=0.1
# Y ~ 1
#
#        Df Sum of Sq     RSS      AIC
# + X10   1    8.0594  5.1597 -12.0077
# + X1    1    1.7339 11.4851  -0.0050
# <none>              13.2190   0.1041
# + X3    1    0.7589 12.4601   1.2172
# + X6    1    0.7444 12.4746   1.2347
# + X8    1    0.6632 12.5558   1.3320
# + X7    1    0.5118 12.7072   1.5118
# + X5    1    0.4365 12.7826   1.6005
# + X2    1    0.3195 12.8995   1.7371
# + X9    1    0.3060 12.9131   1.7529
# + X4    1    0.1909 13.0281   1.8859
#
# Step:  AIC=-12.01
# Y ~ X10
#
#        Df Sum of Sq    RSS     AIC
# + X5    1   0.97157 4.1881 -13.137
# <none>              5.1597 -12.008
# + X1    1   0.45453 4.7051 -11.391
# + X9    1   0.29792 4.8617 -10.900
# + X8    1   0.14097 5.0187 -10.423
# + X3    1   0.11072 5.0489 -10.333
# + X4    1   0.08263 5.0770 -10.250
# + X7    1   0.03018 5.1295 -10.096
# + X2    1   0.01251 5.1472 -10.044
# + X6    1   0.00462 5.1550 -10.021
#
# Step:  AIC=-13.14
# Y ~ X10 + X5
#
# ...

# %% [markdown]
# * Sau khi đã chạy quy trình hồi quy tiến, ta thấy mô hình với hai tham số X5 và X10 có điểm AIC thấp nhất, đạt -13.14, thể hiện mô hình tốt nhất có được.
# * Mô hình có dạng $Y = 8.28 + 0.99*X5 + 2.28*X10$

# %% [markdown]
# 2. Sử dụng quy trình loại bỏ ngược (backward elimination procedure), tìm một mô hình hồi quy tuyến tính phù hợp (không tương tác) để dự báo y từ biến giải thích, dựa theo tiêu chí AIC.
# * Loại bỏ ngược là một phương pháp tự động xây dựng mô hình, bằng việc loại bỏ từng biến giải thích khỏi mô hình. Nếu việc bỏ biến giải thích giúp làm tăng ý nghĩa mô hình, biến đó sẽ bị bỏ và tiếp tục với các biến khác.
# * Phương pháp này sử dụng tiêu chí AIC để lựa chọn mô hình, mô hình có AIC tốt nhất (có điểm thấp nhất) sẽ được chọn.

# %% [markdown]
# Sử dụng lệnh step(), với tham số direction = "backward" cho loại bỏ ngược, tham số cho tiêu chí AIC đã được cài đặt mặc định (với k = 2)
#
#
# ```
# step(max.model, direction = "backward", scope = list(lower = min.model, upper = max.model))
# ```

# %%
auto.backward <- step(max.model, direction = "backward", scope = list(lower = min.model, upper = max.model))
summary(auto.backward)
# Out:
# Start:  AIC=-9.96
# Y ~ X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10
#
#        Df Sum of Sq    RSS      AIC
# - X2    1    0.1478 1.9296 -10.7607
# - X1    1    0.1567 1.9386 -10.6912
# <none>              1.7819  -9.9558
# - X4    1    0.2779 2.0598  -9.7817
# - X5    1    0.4423 2.2241  -8.6303
# - X9    1    0.4879 2.2698  -8.3255
# - X3    1    0.9041 2.6859  -5.8002
# - X6    1    1.4688 3.2507  -2.9377
# - X8    1    1.6261 3.4079  -2.2291
# - X7    1    1.8811 3.6630  -1.1467
# - X10   1    6.9578 8.7397  11.8974
#
# Step:  AIC=-10.76
# Y ~ X1 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10
#
#        Df Sum of Sq    RSS      AIC
# - X1    1    0.2147 2.1443 -11.1785
# - X4    1    0.2462 2.1758 -10.9595
# <none>              1.9296 -10.7607
# - X9    1    0.4384 2.3681  -9.6896
# - X5    1    0.5652 2.4948  -8.9075
# - X3    1    0.7629 2.6926  -7.7632
# - X6    1    1.3906 3.3202  -4.6204
# - X8    1    1.6071 3.5367  -3.6728
# - X7    1    1.8317 3.7614  -2.7490
# ...

# %% [markdown]
# * Sau khi đã chạy quy trình loại bỏ ngược, ta thấy mô hình với tham số X3, X5, X6, X7, X8, X9 và X10 có điểm AIC thấp nhất, đạt -12.43, thể hiện mô hình tốt nhất có được.
# * Mô hình có dạng $Y = 7.45 - 0.82*X3 + 1.53*X5 + 2.14*X6 + 2.54*X7 - 2.39*X8 - 0.82*X9 + 3.10*X10$

# %% [markdown]
# 3. Sử dụng quy trình hồi quy từng bước (step-wise regression procedure), tìm một mô hình hồi quy tuyến tính phù hợp (không tương tác) để dự báo y từ biến giải thích, dựa theo tiêu chí AIC.
# * Hồi quy từng bước là một phương pháp tự động xây dựng mô hình, bằng việc thêm từng biến giải thích nếu không có trong mô hình và loại bỏ từng biến nếu có trong mô hình. Nếu việc thêm, bới biến giúp làm tăng ý nghĩa mô hình, quy trình sẽ tiếp tục với các biến khác.
# * Phương pháp này sử dụng tiêu chí AIC để lựa chọn mô hình, mô hình có AIC tốt nhất (có điểm thấp nhất) sẽ được chọn.

# %% [markdown]
# Sử dụng lệnh step(), với tham số direction = "both" cho hồi quy từng bước, tham số cho tiêu chí AIC đã được cài đặt mặc định (với k = 2)
#
#
# ```
# step(min.model, direction = "both", scope = list(lower = min.model, upper = max.model))
# ```

# %%
auto.both <- step(min.model, direction = "both", scope = list(lower = min.model, upper = max.model))
summary(auto.both)
# Out:
# Start:  AIC=0.1
# Y ~ 1
#
#        Df Sum of Sq     RSS      AIC
# + X10   1    8.0594  5.1597 -12.0077
# + X1    1    1.7339 11.4851  -0.0050
# <none>              13.2190   0.1041
# + X3    1    0.7589 12.4601   1.2172
# + X6    1    0.7444 12.4746   1.2347
# + X8    1    0.6632 12.5558   1.3320
# + X7    1    0.5118 12.7072   1.5118
# + X5    1    0.4365 12.7826   1.6005
# + X2    1    0.3195 12.8995   1.7371
# + X9    1    0.3060 12.9131   1.7529
# + X4    1    0.1909 13.0281   1.8859
#
# Step:  AIC=-12.01
# Y ~ X10
#
#        Df Sum of Sq     RSS      AIC
# + X5    1    0.9716  4.1881 -13.1371
# <none>               5.1597 -12.0077
# + X1    1    0.4545  4.7051 -11.3909
# + X9    1    0.2979  4.8617 -10.8998
# + X8    1    0.1410  5.0187 -10.4232
# + X3    1    0.1107  5.0489 -10.3331
# + X4    1    0.0826  5.0770 -10.2498
# + X7    1    0.0302  5.1295 -10.0957
# + X2    1    0.0125  5.1472 -10.0441
# + X6    1    0.0046  5.1550 -10.0211
# - X10   1    8.0594 13.2190   0.1041
#
# ...

# %% [markdown]
# * Sau khi đã chạy quy trình hồi quy từng bước, ta thấy mô hình với hai tham số X5 và X10 có điểm AIC thấp nhất, đạt -13.14, thể hiện mô hình tốt nhất có được.
# * Mô hình có dạng $Y = 8.28 + 0.99*X5 + 2.28*X10$

# %% [markdown]
# 4. Từ những kết quả trên, rút ra một mô hình (không tương tác) cho dữ liệu.
# * Sau khi đã chạy 3 quy trình, ta thấy mô hình với hai tham số X5 và X10 thể hiện mô hình tốt nhất có được.
# * Mô hình có dạng $Y = 8.28 + 0.99*X5 + 2.28*X10$

# %% [markdown]
# 5. Lặp lại 3 quy trình, nhưng sử dụng tiêu chí BIC để chọn ra một mô hình.
# * Tương tự AIC, tiêu chí BIC (Bayesian Information Criterion) cũng được sử dụng để đánh giá mô hình thống kê. BIC được phát triển từ lý thuyết Bayes. Mức phạt đối với mô hình của BIC lớn AIC, nên thường sinh ra mô hình đơn giản hơn.
# * Công thức $BIC = nlog(RSS/n) + p'log(n)$. Trong đó $p'$ là tham số phạt (penalty). Mô hình có BIC càng thấp càng tốt.

# %% [markdown]
# Sử dụng lệnh step(), với tham số direction = "forward" / "backward" / "both cho cho cả 3 loại quy trình, tham số cho tiêu chí BIC là k = log(n)
#
#
# ```
# step(min.model, direction = "forward", scope = list(lower = min.model, upper = max.model), k = log(n))
# ```

# %%
# hồi quy tiến với tiêu chí BIC
auto.forward2 <- step(min.model, direction = "forward", scope = list(lower = min.model, upper = max.model), k = log(nrow(sharpener)))
summary(auto.forward2)
# Out:
# Start:  AIC=0.81
# Y ~ 1
#
#        Df Sum of Sq     RSS      AIC
# + X10   1    8.0594  5.1597 -10.5916
# <none>              13.2190   0.8122
# + X1    1    1.7339 11.4851   1.4111
# + X3    1    0.7589 12.4601   2.6333
# + X6    1    0.7444 12.4746   2.6508
# + X8    1    0.6632 12.5558   2.7481
# + X7    1    0.5118 12.7072   2.9279
# + X5    1    0.4365 12.7826   3.0166
# + X2    1    0.3195 12.8995   3.1532
# + X9    1    0.3060 12.9131   3.1690
# + X4    1    0.1909 13.0281   3.3020
#
# Step:  AIC=-10.59
# Y ~ X10
#
#        Df Sum of Sq    RSS      AIC
# + X5    1   0.97157 4.1881 -11.0129
# <none>              5.1597 -10.5916
# + X1    1   0.45453 4.7051  -9.2668
# + X9    1   0.29792 4.8617  -8.7756
# + X8    1   0.14097 5.0187  -8.2991
# + X3    1   0.11072 5.0489  -8.2089
# + X4    1   0.08263 5.0770  -8.1257
# + X7    1   0.03018 5.1295  -7.9715
# + X2    1   0.01251 5.1472  -7.9199
# + X6    1   0.00462 5.1550  -7.8970
#
# Step:  AIC=-11.01
# Y ~ X10 + X5
#
# ...

# %%
# loại bỏ ngược với tiêu chí BIC
auto.backward2 <- step(max.model, direction = "backward", scope = list(lower = min.model, upper = max.model), k = log(nrow(sharpener)))
summary(auto.backward2)
# Out:
# Start:  AIC=-2.17
# Y ~ X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10
#
#        Df Sum of Sq    RSS     AIC
# - X2    1    0.1478 1.9296 -3.6802
# - X1    1    0.1567 1.9386 -3.6107
# - X4    1    0.2779 2.0598 -2.7012
# <none>              1.7819 -2.1673
# - X5    1    0.4423 2.2241 -1.5498
# - X9    1    0.4879 2.2698 -1.2450
# - X3    1    0.9041 2.6859  1.2803
# - X6    1    1.4688 3.2507  4.1428
# - X8    1    1.6261 3.4079  4.8514
# - X7    1    1.8811 3.6630  5.9338
# - X10   1    6.9578 8.7397 18.9779
#
# Step:  AIC=-3.68
# Y ~ X1 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10
#
#        Df Sum of Sq    RSS     AIC
# - X1    1    0.2147 2.1443 -4.8061
# - X4    1    0.2462 2.1758 -4.5871
# <none>              1.9296 -3.6802
# - X9    1    0.4384 2.3681 -3.3172
# - X5    1    0.5652 2.4948 -2.5351
# - X3    1    0.7629 2.6926 -1.3907
# - X6    1    1.3906 3.3202  1.7521
# - X8    1    1.6071 3.5367  2.6996
# - X7    1    1.8317 3.7614  3.6235
# ...

# %%
# hồi quy từng bước với tiêu chí BIC
auto.both2 <- step(min.model, direction = "both", scope = list(lower = min.model, upper = max.model), k = log(nrow(sharpener)))
summary(auto.both2)
# Out:
# Start:  AIC=0.81
# Y ~ 1
#
#        Df Sum of Sq     RSS      AIC
# + X10   1    8.0594  5.1597 -10.5916
# <none>              13.2190   0.8122
# + X1    1    1.7339 11.4851   1.4111
# + X3    1    0.7589 12.4601   2.6333
# + X6    1    0.7444 12.4746   2.6508
# + X8    1    0.6632 12.5558   2.7481
# + X7    1    0.5118 12.7072   2.9279
# + X5    1    0.4365 12.7826   3.0166
# + X2    1    0.3195 12.8995   3.1532
# + X9    1    0.3060 12.9131   3.1690
# + X4    1    0.1909 13.0281   3.3020
#
# Step:  AIC=-10.59
# Y ~ X10
#
#        Df Sum of Sq     RSS      AIC
# + X5    1    0.9716  4.1881 -11.0129
# <none>               5.1597 -10.5916
# + X1    1    0.4545  4.7051  -9.2668
# + X9    1    0.2979  4.8617  -8.7756
# + X8    1    0.1410  5.0187  -8.2991
# + X3    1    0.1107  5.0489  -8.2089
# + X4    1    0.0826  5.0770  -8.1257
# + X7    1    0.0302  5.1295  -7.9715
# + X2    1    0.0125  5.1472  -7.9199
# + X6    1    0.0046  5.1550  -7.8970
# - X10   1    8.0594 13.2190   0.8122
# ...

# %% [markdown]
# * Sau khi đã chạy 3 quy trình, ta thấy mô hình với hai tham số X5 và X10 thể hiện mô hình tốt nhất có được, với BIC = -11.01.
# * Mô hình có dạng $Y = 8.28 + 0.99*X5 + 2.28*X10$

# %% [markdown]
# 6. Sau khi đọc phần trợ giúp R cho phần sharpener data (bằng lệnh ?sharpener), nhận xét việc sử dụng phương pháp tự động xây dựng mô hình.

# %%
?sharpener

# %% [markdown]
# <a href = "https://colab.research.google.com/drive/13Xuil9eouJ04FMMmXYWRuDtEpM-ASzld#scrollTo=KuRJ5kEbtvSi">Solution here</a>

# %% [markdown]
# # Problem 3.1

# %% [markdown]
# 3.1: Residual Chuẩn Hóa $r^{'}_i$ đo lường mức độ giảm của tổng sai số bình phương (RSS), chia cho $𝑠^2$, khi quan sát thứ i bị loại khỏi dữ liệu. Hãy thực hiện điều này trong R bằng cách sử dụng dữ liệu lungcap như sau:
#
# 1. Fit mô hình LC.lm (Ví dụ 3.1, trang 97). Tính toán RSS, $s^2$ và các residual chuẩn hóa từ mô hình này.
# 2. Loại bỏ quan sát 1 khỏi dữ liệu lungcap, và điều chỉnh lại mô hình mà không có quan sát 1. Gọi mô hình này là LC.omit1.
# 3. Tính toán sự khác biệt giữa RSS của mô hình đầy đủ LC.lm và mô hình LC.omit1. Chứng minh rằng sự khác biệt này chia cho $s^2$ chính là bình phương của residual chuẩn hóa cho quan sát 1.
#
# Lặp lại quá trình trên cho mọi quan sát i, và chứng minh rằng n sự khác biệt chia cho $s^2$ chính là bình phương của residual chuẩn hóa cho mỗi quan sát.

# %% [markdown]
# <a href = "https://colab.research.google.com/drive/13Xuil9eouJ04FMMmXYWRuDtEpM-ASzld#scrollTo=SwUC0p9JxLfF">Solution here</a>
