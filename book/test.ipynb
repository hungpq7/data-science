# %%
conda list
# Out:
# # packages in environment at /opt/anaconda3/envs/tabular:
# #
# # Name                    Version                   Build  Channel
# _python_abi3_support      1.0                  hd8ed1ab_2    conda-forge
# adwaita-icon-theme        49.0                     unix_0    conda-forge
# alembic                   1.16.5             pyhd8ed1ab_0    conda-forge
# appnope                   0.1.4              pyhd8ed1ab_1    conda-forge
# asttokens                 3.0.0              pyhd8ed1ab_1    conda-forge
# atk-1.0                   2.38.0               h4bec284_2    conda-forge
# autograd                  1.8.0              pyhd8ed1ab_0    conda-forge
# autograd-gamma            0.5.0              pyhd8ed1ab_1    conda-forge
# bleach                    6.2.0              pyh29332c3_4    conda-forge
# bokeh                     3.8.0              pyhd8ed1ab_0    conda-forge
# brotli                    1.1.0                    pypi_0    pypi
# ...
